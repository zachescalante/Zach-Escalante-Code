# %%
import io
import boto3
import sqlalchemy
import pandas as pd
import mysql.connector
from datetime import datetime, timedelta
from collections import OrderedDict

# %% [markdown]
# #### Connect to S3 and download CSV files as Pandas Dataframe

# %%
def get_s3_keys(bucket):
    """Get a list of keys in an S3 bucket."""
    keys = []
    resp = s3.list_objects_v2(Bucket=bucket)
    for obj in resp['Contents']:
        keys.append(obj['Key'])
    return keys

# %%
s3 = boto3.client('s3')

# %%
bucket = 'cms-data-ze'

# %%
files = get_s3_keys(bucket)

# %%
dates = ["2016-01-01", "2019-09-02"]
start, end = [datetime.strptime(_, "%Y-%m-%d") for _ in dates]
file_months = list(OrderedDict(((start + timedelta(_)).strftime(r"%b-%y"), None) for _ in range((end - start).days)).keys())

# %%
file_months[0]
# Out:
# 'Jan-16'

# %%
datetime.strptime(file_months[0], "%b-%y")
# Out:
# datetime.datetime(2016, 1, 1, 0, 0)

# %%
obj = s3.get_object(Bucket= bucket, Key= files[0])

# %%
df = pd.read_csv(obj['Body'], encoding='latin-1')
#initial_df = pd.read_csv(obj['Body'], skiprows=1) # 'Body' is a key word

# %% [markdown]
# #### Data preprocessing steps

# %% [markdown]
# #### 1. Fill all blank values with the column name + '_blank_' so we know that this value was missing

# %%
[df[df.columns[i]].fillna(df.columns[i]+'_blank', inplace=True) for i, _ in enumerate(df.columns)]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# #### 2. Create a unique ID which is 'Contract_ID' + 'Plan_ID' and call that column 'Unique_ID'

# %%
unique_id = df["Contract ID"].map(str) + '-' + df["Plan ID"].map(str)
df.insert(loc=0, column='Unique_ID', value=unique_id)

# %% [markdown]
# #### 3. Put it all together and append dataframe to master contract list

# %%
i = 0
rows = 0
appended_data = []
duplicate_data = []
for file in files:
    print('File name: ', file)
    obj = s3.get_object(Bucket= bucket, Key= file)
    df = pd.read_csv(obj['Body'], encoding='latin-1')
    df['Date'] = datetime.strptime(file_months[i], "%b-%y")
    i += 1
    print('Number of rows: ', df.shape[0])
    rows += df.shape[0]
    print('Filling NA values in columns')
    [df[df.columns[i]].fillna(df.columns[i]+'_blank', inplace=True) for i, _ in enumerate(df.columns)]
    print('Create Unique_ID column')
    unique_id = df["Contract ID"].map(str) + '-' + df["Plan ID"].map(str)
    df.insert(loc=0, column='Unique_ID', value=unique_id.str.split('.').str[0])
    print('Find the duplicated data: ', len(df['Unique_ID'])-len(df['Unique_ID'].drop_duplicates()))
    duplicate_data.append(df[df['Unique_ID'].duplicated()])
    appended_data.append(df)
    
appended_data = pd.concat(appended_data)
duplicate_data = pd.concat(duplicate_data)

print('appended_data size: ', appended_data.shape)
print('Counted number of rows: ', rows)
# Out:
# File name:  CPSC_Contract_Info_2016_01.csv
# Number of rows:  4936
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_02.csv
# Number of rows:  4938
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_03.csv
# Number of rows:  4940
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_04.csv
# Number of rows:  4942
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_05.csv
# Number of rows:  4940
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_06.csv
# Number of rows:  4943
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_07.csv
# Number of rows:  4943
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_08.csv
# Number of rows:  4941
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_09.csv
# Number of rows:  4941
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_10.csv
# Number of rows:  4941
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_11.csv
# Number of rows:  4941
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2016_12.csv
# Number of rows:  4941
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_01.csv
# Number of rows:  4818
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_02.csv
# Number of rows:  4818
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_03.csv
# Number of rows:  4819
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_04.csv
# Number of rows:  4820
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_05.csv
# Number of rows:  4820
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_06.csv
# Number of rows:  4820
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_07.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_08.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_09.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_10.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_11.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2017_12.csv
# Number of rows:  4822
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_01.csv
# Number of rows:  5235
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_02.csv
# Number of rows:  5236
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_03.csv
# Number of rows:  5238
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_04.csv
# Number of rows:  5238
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_05.csv
# Number of rows:  5237
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_06.csv
# Number of rows:  5235
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_07.csv
# Number of rows:  5231
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_08.csv
# Number of rows:  5233
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_09.csv
# Number of rows:  5231
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_10.csv
# Number of rows:  5229
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_11.csv
# Number of rows:  5227
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2018_12.csv
# Number of rows:  5225
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_01.csv
# Number of rows:  6130
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_02.csv
# Number of rows:  6130
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_03.csv
# Number of rows:  6132
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_04.csv
# Number of rows:  6136
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_05.csv
# Number of rows:  6136
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_06.csv
# Number of rows:  6138
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_07.csv
# Number of rows:  6138
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_08.csv
# Number of rows:  6128
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# File name:  CPSC_Contract_Info_2019_09.csv
# Number of rows:  6128
# Filling NA values in columns
# Create Unique_ID column
# Find the duplicated data:  0
# appended_data size:  (235125, 14)
# Counted number of rows:  235125

# %% [markdown]
# #### 4. Drop duplicates (keeping the latest entry for duplicate Unique_ID values) and keep the set of clean contract data

# %%
appended_data.columns
# Out:
# Index(['Unique_ID', 'Contract ID', 'Plan ID', 'Organization Type', 'Plan Type',
#        'Offers Part D', 'SNP Plan', 'EGHP', 'Organization Name',
#        'Organization Marketing Name', 'Plan Name', 'Parent Organization',
#        'Contract Effective Date', 'Date'],
#       dtype='object')

# %%
clean_data = appended_data.sort_values('Date').drop_duplicates('Unique_ID',keep='last')

# %%
clean_data.to_csv('clean_cms_contract_data.csv', index=False)

# %% [markdown]
# ##### Find any duplicated values

# %%
print('Number of Duplicates: ', len(clean_data['Unique_ID'])-len(clean_data['Unique_ID'].drop_duplicates()))
print('Duplicated values: ', clean_data[clean_data['Unique_ID'].duplicated()])
# Out:
# Number of Duplicates:  0
# Duplicated values:  Empty DataFrame
# Columns: [Unique_ID, Contract ID, Plan ID, Organization Type, Plan Type, Offers Part D, SNP Plan, EGHP, Organization Name, Organization Marketing Name, Plan Name, Parent Organization, Contract Effective Date, Date]
# Index: []

# %%
appended_data[appended_data['Unique_ID'] == 'E0654-801.0']
# Out:
#      Unique_ID Contract ID Plan ID                        Organization Type  \
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
# 1  E0654-801.0       E0654     801  Employer/Union Only Direct Contract PDP
#
#                                  Plan Type Offers Part D SNP Plan EGHP  \
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
# 1  Employer/Union Only Direct Contract PDP           Yes       No  Yes
#
#                        Organization Name  \
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
# 1  IBT VOLUNTARY EMPLOYEE BENEFITS TRUST
#
#                          Organization Marketing Name  \
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
# 1  TEAMStar Medicare Part D Prescription Drug Pro...
#
#                                            Plan Name  \
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
# 1  IBT Voluntary Employee Benefits Trust (Employe...
#
#                      Parent Organization Contract Effective Date       Date
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-01-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-02-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-03-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-04-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-05-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-06-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-07-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-08-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-09-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-10-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-11-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2016-12-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-01-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-02-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-03-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-04-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-05-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-06-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-07-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-08-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-09-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-10-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-11-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2017-12-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-01-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-02-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-03-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-04-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-05-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-06-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-07-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-08-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-09-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-10-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-11-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2018-12-01
# 1  IBT Voluntary Employee Benefits Trust      01/01/2007 0:00:00 2019-01-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-02-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-03-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-04-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-05-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-06-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-07-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-08-01
# 1  IBT Voluntary Employee Benefits Trust              01/01/2007 2019-09-01

# %%
subset_data[subset_data['Unique_ID'] == 'H2354-801.0']
# Out:
#         Unique_ID Contract ID Plan ID   Plan Type       Parent Organization
# 1167  H2354-801.0       H2354     801  HMO/HMOPOS    HealthPlus of Michigan
# 1167  H2354-801.0       H2354     801  HMO/HMOPOS  Henry Ford Health System
