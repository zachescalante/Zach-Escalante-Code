# %% [markdown]
# # BeautifulSoup Webscraping Tutorial
#
# #### Table of Contents
#
# 1. <a href='##Introduction'>The Basics of Webscraping With BeautifulSoup</a> <br>
# > 1.a <a href='##urllib'>The urllib package</a> <br>
# > 1.b <a href='##beautiful_soup'>The Beautiful Soup package</a> <br>
# 2. <a href='##example'>Webscrapig Example</a> <br>
# > 2.a <a href='##packages'>Necessary Packages</a> <br>
# > 2.b <a href='##urllib_example'>urllib to grab the website</a> <br>
# > 2.c <a href='##bs4_object'>Create a bs4 object</a> <br>
# 3. <a href='##bs4_parse'>Parsing a Beautiful Soup Object</a> <br>
# > 3.a <a href='##bs4_html'>Creating the right HTML objects to parse</a> <br>
# > 3.b <a href='##bs4_find_html'>Creating nested HTML objects using **find( ) and **find_all( ) methodology</a> <br>
# > 3.c <a href='##pulling_tags'>Parsing the individual movies and pulling the data</a> <br>
# > 3.d <a href='##storing_data'>Storing the data and exporting to CSV</a> <br>

# %% [markdown]
# <a id='#Introduction'></a>
#
# ### The Basics of Webscraping with BeautifulSoup
#
# Beautiful Soup is a lightweight, flexible Python library designed for parsing HTML documents. It provides many great features, such as HTML tree traversal and automatic encoding (incoming documents to Unicode and outgoing documents to UTF-8) (1) which enable the user to focus solely on parsing documents and extracting information. Beautiful Soup itself does not collect webpages - this is left to the urllib package in Python which we'll discuss next. Instead Beauful Soup parses the HTML code, meaning that Beautiful Soup and urllib work hand-in hand.
#
# We'll be working in Python 3 for this tutorial, although Beautiful Soup runs for Python 2 with some simple adjustments to your code. Let's take a look at an example and see if we can get you up and running with parsing your own web pages!
#
# (1) https://www.crummy.com/software/BeautifulSoup/

# %% [markdown]
# <a id='#urllib'></a>
#
# #### The urllib package
#
# The urllib package enables you to access websites via your Python console. With just a few lines of code you can write a program for grabbing objects and saving data from webpages. What's also great about urllib is that it is part of the standard Python libary - so it rarely ever needs to be installed (you already have it upon installing any version of Python). Below are some links to urllib documentation and simple example code:
#
# **Tutorial**:    https://pythonprogramming.net/urllib-tutorial-python-3/ <br>
# **Documentation**: https://docs.python.org/3/library/urllib.html

# %% [markdown]
# <a id='#beautiful_soup'></a>
#
# #### The Beautiful Soup Package
#
# Once we've used urllib to grab an HTML document, then we can deploy Beautiful Soup. Beautiful Soup has built in methods to parse the HTML tree, grab tags and encode incoming/outgoing documents. There have been several iterations of the Beautiful Soup package, the latest of which is **bs4** for Python 3. Below are some relevant links for installing and reading about Beautiful Soup:
#
# **Documentation**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ <br>
# **Installation**: http://www.pythonforbeginners.com/beautifulsoup/beautifulsoup-4-python

# %% [markdown]
# <a id='#example'></a>
#
# #### Let's start a webscraping example
#
# The first thing we need to do is import the relevant packages for our project. These packages are the following: <br>
# * **re** - the regular expressions package for evaluating strings <br>
# * **pandas** - this is a fundamental package for formatting and evaluating data <br>
# * **urllib.request** - HTML reqeusts are handled by the '.request' method in the urllib package <br>
# * **bs4** - we will create an object for parsing using the Beautiful Soup method of the bs4 package <br>

# %% [markdown]
# <a id='#packages'></a>

# %%
import re
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# <a id='#urllib_example'></a>
#
# #### Use urllib to grab the website object

# %%
#Declare the website as a string. For this example, I've decided to grab the data from rottentomatoes website, parse
#the html and save it in a pandas dataframe which we can export to a csv file.
webpage = 'https://www.rottentomatoes.com/'

#Use the 'with-as' method to open the webpage and create an object of the html source code
with urllib.request.urlopen(webpage) as response:
   html = response.read()

# %% [markdown]
# <a id='#bs4_object'></a>
#
# #### Create a Beautiful Soup object
#
# We do this by passing the **html** object to the Beautiful Soup method

# %%
soup = BeautifulSoup(html)
# Out:
# /Users/zacharyescalante/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/zacharyescalante/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# **soup.prettify** displays all the HTML syntax just as it appears on the webpage we took it from. This helps us to determine how to properly search for tags as we parse our tree.

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <!-- salt=lay-def-02-juRm -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews - Rotten Tomatoes</title>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="description"/>
# <link href="https://www.rottentomatoes.com/" rel="canonical"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/images/favicon.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
# <meta content="326803741017" property="fb:app_id"/>
# <meta content="Rotten Tomatoes" property="og:site_name"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" property="og:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.rottentomatoes.com/" property="og:url"/>
# <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" property="og:image"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" name="twitter:image"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:title"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:text:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="twitter:description"/>
# <meta content="@rottentomatoes" name="twitter:site"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/manifest/manifest.json" rel="manifest"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-60.jpg" rel="apple-touch-icon"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-152.jpg" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-167.jpg" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-180.jpg" rel="apple-touch-icon" sizes="180x180"/>
# <!-- JSON+LD -->
# <!-- Google webmaster tools -->
# <meta content="VPPXtECgUUeuATBacnqnCm4ydGO99reF-xgNklSbNbc" name="google-site-verification"/>
# <!-- Bing webmaster tools -->
# <meta content="034F16304017CA7DCF45D43850915323" name="msvalidate.01"/>
# <meta content="#FA320A" name="theme-color"/>
# <!-- DNS prefetch -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//www.rottentomatoes.com" rel="dns-prefetch"/>
# <link href="//www.rottentomatoes.com" rel="preconnect"/>
# <!-- BEGIN: critical-->
# <style id="critical-path">html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}aside,footer,nav,section{display:block}a{background-color:transparent}h1{font-size:2em;margin:.67em 0}small{font-size:80%}img{border:0}svg:not(:root){overflow:hidden}button,input{color:inherit;font:inherit;margin:0}button{overflow:visible}button{text-transform:none}button{-webkit-appearance:button}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}input{line-height:normal}input[type=checkbox]{box-sizing:border-box;padding:0}table{border-collapse:collapse;border-spacing:0}td{padding:0}.glyphicon{position:relative;top:1px;display:inline-block;font-family:'Glyphicons Halflings';font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.glyphicon-search:before{content:"\e003"}.glyphicon-remove:before{content:"\e014"}.glyphicon-chevron-left:before{content:"\e079"}.glyphicon-chevron-right:before{content:"\e080"}.glyphicon-remove-circle:before{content:"\e088"}.container{margin-right:auto;margin-left:auto}.container:after,.container:before{content:" ";display:table}.container:after{clear:both}.row{margin-left:-10px;margin-right:-10px}.row:after,.row:before{content:" ";display:table}.row:after{clear:both}.col-sm-11,.col-sm-12,.col-sm-13,.col-sm-17,.col-sm-18,.col-sm-6,.col-sm-7,.col-xs-11,.col-xs-12,.col-xs-24,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7{position:relative;min-height:1px;padding-left:10px;padding-right:10px}.col-xs-11,.col-xs-12,.col-xs-24,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7{float:left}.col-xs-3{width:12.5%}.col-xs-4{width:16.66667%}.col-xs-5{width:20.83333%}.col-xs-6{width:25%}.col-xs-7{width:29.16667%}.col-xs-11{width:45.83333%}.col-xs-12{width:50%}.col-xs-24{width:100%}@media (min-width:768px){.col-sm-11,.col-sm-12,.col-sm-13,.col-sm-17,.col-sm-18,.col-sm-6,.col-sm-7{float:left}.col-sm-6{width:25%}.col-sm-7{width:29.16667%}.col-sm-11{width:45.83333%}.col-sm-12{width:50%}.col-sm-13{width:54.16667%}.col-sm-17{width:70.83333%}.col-sm-18{width:75%}}*{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}:after,:before{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}html{font-size:10px}body{font-size:16px;line-height:1.25;color:#2a2c32;background-color:#fff}button,input{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#337ab7;text-decoration:none}img{vertical-align:middle}.sr-only{position:absolute;width:1px;height:1px;margin:-1px;padding:0;overflow:hidden;clip:rect(0,0,0,0);border:0}.h2,h1,h2,h3{font-family:inherit;font-weight:700;line-height:1.1;color:#2a2c32}.h2,h1,h2,h3{margin-top:20px;margin-bottom:10px}h1{font-size:24px}.h2,h2{font-size:18px}h3{font-size:14px}p{margin:0 0 10px}small{font-size:75%}.text-center{text-align:center}ol,ul{margin-top:0;margin-bottom:10px}ul ul{margin-bottom:0}.list-unstyled{padding-left:0;list-style:none}.list-inline{padding-left:0;list-style:none;margin-left:-5px}.list-inline>li{display:inline-block;padding-left:5px;padding-right:5px}table{background-color:transparent;border-collapse:collapse}label{display:inline-block;max-width:100%;margin-bottom:5px;font-weight:700}input[type=checkbox]{margin:4px 0 0;line-height:normal}.form-control{display:block;width:100%;height:34px;padding:6px 12px;font-size:16px;line-height:1.25;color:#757a84;background-color:#fff;background-image:none;border:1px solid #ccc;border-radius:4px;-webkit-box-shadow:inset 0 1px 1px rgba(0,0,0,.075);box-shadow:inset 0 1px 1px rgba(0,0,0,.075)}.form-control::-moz-placeholder{color:#999;opacity:1}.form-control:-ms-input-placeholder{color:#999}.form-control::-webkit-input-placeholder{color:#999}.form-control::-ms-expand{border:0;background-color:transparent}.form-group{margin-bottom:15px}.help-block{display:block;margin-top:5px;margin-bottom:10px;color:#747474}.btn{display:inline-block;margin-bottom:0;font-weight:400;text-align:center;ver ...
# <!-- /END: critical-->
# <link as="style" href="/assets/pizza-pie/stylesheets/bundles/global.023bbdf82ab.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="/assets/pizza-pie/stylesheets/bundles/home.184c0867427.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <script>
#         !function(t){"use strict";t.loadCSS||(t.loadCSS=function(){});var e=loadCSS.relpreload={};if(e.support=function(){var e;try{e=t.document.createElement("link").relList.supports("preload")}catch(t){e=!1}return function(){return e}}(),e.bindMediaToggle=function(t){var e=t.media||"all";function a(){t.media=e}t.addEventListener?t.addEventListener("load",a):t.attachEvent&&t.attachEvent("onload",a),setTimeout(function(){t.rel="stylesheet",t.media="only x"}),setTimeout(a,3e3)},e.poly=function(){if(!e.support())for(var a=t.document.getElementsByTagName("link"),n=0;n<a.length;n++){var o=a[n];"preload"!==o.rel||"style"!==o.getAttribute("as")||o.getAttribute("data-loadcss")||(o.setAttribute("data-loadcss",!0),e.bindMediaToggle(o))}},!e.support()){e.poly();var a=t.setInterval(e.poly,500);t.addEventListener?t.addEventListener("load",function(){e.poly(),t.clearInterval(a)}):t.attachEvent&&t.attachEvent("onload",function(){e.poly(),t.clearInterval(a)})}"undefined"!=typeof exports?exports.loadCSS=loadCSS:t.loadCSS=loadCSS}("undefined"!=typeof global?global:this);
#         </script>
# <script>window.RottenTomatoes = {};</script>
# <script>window.RTLocals = {};</script>
# <script>var dataLayer = dataLayer || [];</script>
# <!-- Make dataLayer (GTM) available -->
# <!-- TODO: User Information discussion -->
# <!-- <c:set var="friendCount" value="${empty current.user? 0 : fn:length(current.friends)}" /> -->
# <script id="mps-page-integration">
#       window.mpscall = {"adunits":"Multi Logo|Box Ad|Marquee Banner|Top Banner","cag[score]":null,"cag[certified_fresh]":null,"cag[fresh_rotten]":null,"cag[rating]":null,"cag[release]":null,"cag[movieshow]":null,"cag[genre]":null,"cag[urlid]":null,"cat":"home","field[env]":"production","field[rtid]":null,"path":"/","site":"rottentomatoes-web","title":"Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews","type":"index"};
#       var mpsopts={'host':'mps.nbcuni.com', 'updatecorrelator':1};
#       var mps=mps||{};mps._ext=mps._ext||{};mps._adsheld=[];mps._queue=mps._queue||{};mps._queue.mpsloaded=mps._queue.mpsloaded||[];mps._queue.mpsinit=mps._queue.mpsinit||[];mps._queue.gptloaded=mps._queue.gptloaded||[];mps._queue.adload=mps._queue.adload||[];mps._queue.adclone=mps._queue.adclone||[];mps._queue.adview=mps._queue.adview||[];mps._queue.refreshads=mps._queue.refreshads||[];mps.__timer=Date.now||function(){return+new Date};mps.__intcode="v2";if(typeof mps.getAd!="function")mps.getAd=function(adunit){if(typeof adunit!="string")return false;var slotid="mps-getad-"+adunit.replace(/\W/g,"");if(!mps._ext||!mps._ext.loaded){mps._queue.gptloaded.push(function(){typeof mps._gptfirst=="function"&&mps._gptfirst(adunit,slotid);mps.insertAd("#"+slotid,adunit)});mps._adsheld.push(adunit)}return'<div id="'+slotid+'" class="mps-wrapper" data-mps-fill-slot="'+adunit+'"></div>'};(function(){head=document.head||document.getElementsByTagName("head")[0],mpsload=document.createElement("script");mpsload.src="//"+mpsopts.host+"/fetch/ext/load-"+mpscall.site+".js?nowrite=2";mpsload.id="mps-load";head.insertBefore(mpsload,head.firstChild)})();
#     </script>
# <script>
#     //<!-- TODO: User Information discussion -->
#     //<!-- Set global Krux user id TODO: check if this is still used -->
#     // flix_user_id = "";
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#     function endsWith(str, suffix) {
#         return str.indexOf(suffix, str.length - suffix.length) !== -1;
#     }
#
#     //--Ad Unit Loaded (called for each ad loaded)
#     var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.adload = mps._queue.adload||[];
#     mps._queue.adload.push(function (eo) {
#         if (!eo.isEmpty) {
#             var slotName = eo._mps._slot;
#
#             if ('topbanner' === slotName) {
#                 var leaderboardHeight = eo.size[1];
#                 if (leaderboardHeight > 50){
#
#                     if (leaderboardHeight < 90){
#                         $('.leaderboard_wrapper').css('min-height', leaderboardHeight);
#                     }
#                     $('#top_leaderboard_wrapper').animate({ height: (leaderboardHeight + 10) },1000);
#                 }
#             }
#
#             if ('trendinggraphic' === slotName) {
#                 //Hide Trending bar social section
#                 $('#trending_bar_social').hide();
#                 // Roma version
#                 $('.trending-bar__social').hide();
#                 //Removing padding for trending bar ad
#                 $('.trendingBar > .trendingEl').css('padding','0px');
#                 $('#trending_bar_ad').show();
#
#                 $('a.trendingLink').addClass('trending-link-truncate');
#                 // Roma version
#                 $('.trending-bar__link').addClass('trending-link--truncate');
#             }
#
#             if ('tomatometer' === slotName) {
#                 if (eo.size[0] == 524 && eo.size[1] == 40) {
#                     //Increase score panel margin
#                     $('#scorePanel').css('margin-bottom', '20px');
#                 }
#                 // Only show Tomatometer Sponsorship div if rendered
#                 $('#tomatometer_sponsorship_ad').show();
#             }
#         }
#     });
# </script>
# <!-- Google Tag Manager -->
# <!-- Preinitialize dataLayer before loading GTM to avoid race condition-->
# <script>
#             dataLayer.push({"webVersion":"node","clicktale":true,"rtVersion":3,"pageName":"rt | homepage"});
#         </script>
# <script>
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-M5LKWCR');
#         </script>
# <!-- End Google Tag Manager -->
# </head>
# <body class="body no-touch">
# <div id="emptyPlaceholder"></div>
# <script>
#             !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function()
#             {n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}
#             ;if(!f._fbq)f._fbq=n;
#                 n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                     document,'script','https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '1147905821962466');
#             fbq('track', 'PageView');
#         </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1147905821962466&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script async="" src="//assets.adobedtm.com/launch-EN549327edc13e414a9beb5d61bfd9aac6.min.js"></script>
# <!-- mobile menu -->
# <div aria-labelledby="navMenu" class="modal fade" id="navMenu" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span class="glyphicon glyphicon-remove"></span>
# </button>
# <div class="pull-left">
# <ul class="list-inline social">
# <li><a class="header-facebook-social-link" href="//www.facebook.com/rottentomatoes" rel="noopener" target="_blank"></a></li>
# <li><a class="header-twitter-social-link" href="//twitter.com/rottentomatoes" rel="noopener" target="_blank"></a></li>
# </ul>
# </div>
# <div class="items">
# <div class="item">
# <a class="homeTab unstyled navLink fullLink" href="/">
#                             Home
#                         </a>
# </div>
# <div class="item">
# <a class="boxofficeTab unstyled navLink fullLink" href="/lists/theater/">
#                             Top Box Office
#                         </a>
# </div>
# <div class="item">
# <a class="theatersTab unstyled navLink fullLink" href="/theaters/">
#                             Tickets &amp; Showtimes
#                         </a>
# </div>
# <div class="item">
# <a class="dvdTab unstyled navLink fullLink" href="/lists/dvd/">
#                             DVD &amp; Streaming
#                         </a>
# </div>
# <!-- <c:if test="${'us' eq headerInfo.i18nHeader or 'US' eq headerInfo.i18nHeader or '' eq headerInfo.i18nHeader}"> -->
# <div class="item">
# <a class="tvTab unstyled navLink fullLink" href="/lists/tv/">
#                                 TV
#                             </a>
# </div>
# <!-- </c:if> -->
# <div class="item">
# <a class="newsTab unstyled navLink fullLink" href="https://editorial.rottentomatoes.com/">
#                             News
#                         </a>
# </div>
# <!--
#                     <div class="item">
#                         <a class="newsletterTab unstyled navLink fullLink" href="/newsletter/">
#                             <%--Join Newsletter--%>
#                         </a>
#                     </div>
#                     -->
# </div>
# <div class="loginArea"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="body_main container">
# <div id="header_and_leaderboard">
# <div class="leaderboard_wrapper homepage_leaderboard" id="top_leaderboard_wrapper">
# <div class="leaderboard_helper" id="top_leaderboard_helper">
# <div id="leaderboard_top_ad"></div>
# <script>
#                 //--RESPONSIVE AD SWITCHING (DIFFERENT CONTAINERS)
#                 var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function () {
#                     if (mps.getResponsiveSet() == '0') { //MOBILE
#                         mps.insertAd('#leaderboard_top_ad','mbanner');
#                     } else { //DESKTOP or TABLET
#                         mps.insertAd('#leaderboard_top_ad','topbanner');
#                     }
#                 });
#             </script>
# </div>
# </div>
# </div>
# <!-- global header -->
# <nav class="header_main container" id="header-main">
# <div class="navbar navbar-rt" id="navbar" role="navigation">
# <div class="navbar-header pull-right hidden-xs">
# <div class="header_links">
# <a href="/about#whatisthetomatometer" id="header-whats-the-tomatometer">What's the Tomatometer®?</a>
# <a href="/critics/" id="header-top-bar-critics">Critics</a>
# <div class="js-header-auth__user-section" id="headerUserSection" style="display: inline-block;">
# <a class="signupLink login ctHidden" data-target="#signup" data-toggle="modal" id="header-top-bar-signup">SIGN UP</a> |<a class="loginLink login ctHidden" data-target="#login" data-toggle="modal" id="header-top-bar-login">LOG IN</a>
# </div>
# </div>
# </div>
# <div class="col-sm-13 col-full-xs" id="header_brand_column">
# <div class="hidden-xs desktopNav">
# <!-- Logo -->
# <div class="navbar-brand" id="navbar_brand">
# <a aria-label="header logo" class="header-rt-logo" href="/"><img alt="Rotten Tomatoes Logo" id="original_rt_logo" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/></a>
# <div id="new_logo_ad" style="display:none;"></div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                 mps.rt.insertlogo('#new_logo_ad', 'ploc=rtlogo;');
#             }
#         });
#     </script>
# </div>
# <!-- Search box -->
# <div id="fullscreen-search-desktop-root">
# <form action="" method="get">
# <div class="FullscreenSearch FullscreenSearch--desktop">
# <div class="navbar-searchbox main">
# <div class="input-group">
# <input autocomplete="off" class="form-control" id="fullscreen-search-term" name="search" placeholder="Search movies, TV, actors, more..." type="text" value=""/>
# <div class="input-group-btn">
# <button class="btn btn-default searchBtn what" id="fullscreen-search-desktop-search-btn" type="submit"><em class="glyphicon glyphicon-search"></em></button>
# </div>
# <div class="navbar-close">
# <button class="btn btn-default" type="button"><span class="glyphicon glyphicon-remove"></span></button>
# </div>
# </div>
# <div class="FullscreenSearch__results-container container" id="fullscreen-search-results-container">
# <!-- Results added dynamically here -->
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="mobileNav">
# <div>
# <a>
# <button aria-label="search button" class="pull-right navbar-button searchButton" data-toggle="modal" id="fullscreen-search-show-btn">
# <em class="glyphicon glyphicon-search white"></em>
# </button>
# </a>
# </div>
# <!-- Logo -->
# <div class="navbar-brand">
# <a aria-label="header logo" class="header-rt-logo" href="/"> <img alt="Rotten Tomatoes Logo" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/></a>
# </div>
# <div class="js-mobile-nav__body" id="mobile-nav">
# <div class="mob-nav-bottom clearfix">
# <ul class="nav-list" id="nav-list">
# <li class="nav-item">
# <a class="active" href="/"><i class=" fontelloIcon icon-home"></i>Home</a>
# </li>
# <li class="nav-item">
# <a href="/lists/theater/"><i class=" fontelloIcon icon-boxoffice"></i>Box Office</a>
# </li>
# <li class="nav-item">
# <a href="/lists/tv/"><i class=" fontelloIcon icon-tv2"></i>TV</a>
# </li>
# <li class="nav-item">
# <a href="/lists/dvd/"><i class=" fontelloIcon icon-redeem"></i>DVD</a>
# </li>
# <li class="nav-item">
# <a class="menu-btn js-mobile-nav__more-btn" id="menu-btn">
# <i class=" fontelloIcon icon-more"></i>MORE
#                                 </a>
# </li>
# </ul>
# </div>
# <div class="mobile-nav-overlay" id="mobile-nav-overlay">
# <!--mobile dropdown-->
# <ul class="mobile-menu-panel">
# <li class="nav-item"><a href="//editorial.rottentomatoes.com">News</a></li>
# <li class="nav-item hide js-mobile-nav__menu-my-account"><a href="#">My Account</a></li>
# <li class="nav-item clearfix d-block">
# <div class="login-signup-box pull-left">
# <a class="signupLink login btn-login-signup" data-target="#signup" data-toggle="modal" id="mobile-signup-btn">SIGN UP</a>
# <a class="loginLink login btn-login-signup" data-target="#login" data-toggle="modal" id="mobile-login-btn">LOG IN</a>
# </div>
# <div class="social-media-box pull-right">
# <a href="https://www.facebook.com/rottentomatoes">
# <i aria-hidden="true" class="fontelloIcon icon-facebook-squared"></i>
# </a>
# <a href="https://twitter.com/rottentomatoes">
# <i aria-hidden="true" class="fontelloIcon icon-twitter"></i>
# </a>
# </div>
# </li>
# </ul>
# <!--mobile dropdown end-->
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-nav col-sm-11 hidden-xs" id="menu">
# <ul class="list-inline">
# <li class="menuHeader center dropdown noSpacing" id="movieHeaderMenu">
# <a class="h2 white" href="/browse/opening/" id="movieMenu" role="button">
#                         Movies &amp; DVDs<span class="fontelloIcon icon-down-dir"></span>
# </a>
# <div aria-labelledby="movieMenu" class="dropdown-menu" role="menu">
# <div class="row-sameColumnHeight">
# <div class="col-xs-5 subnav">
# <div class="innerSubnav">
# <h2 class="title">Movies in Theaters</h2>
# <ul class="list-unstyled" id="header-movies-in-theaters">
# <li>
# <a class="unstyled articleLink" href="/browse/opening/">Opening This Week</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/in-theaters/">Top Box Office</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/upcoming/">Coming Soon to Theaters</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="//www.rottentomatoes.com/browse/box-office/">Weekend Earnings</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/cf-in-theaters/">Certified Fresh Movies</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xs-5 subnav">
# <div class="innerSubnav">
# <a class="unstyled articleLink" href="/dvd/"><h2 class="title">On Dvd &amp; Streaming</h2></a>
# <ul class="list-unstyled" id="header-on-dvd-streaming">
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=fandango_now">FandangoNOW</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=netflix_iw">Netflix Streaming</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=itunes">iTunes</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=amazon_prime;amazon">Amazon and Amazon Prime</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/top-dvd-streaming/">Top DVD &amp; Streaming</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-new/">New Releases</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-upcoming/">Coming Soon to DVD</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/cf-dvd-streaming-all/">Certified Fresh Movies</a>
# </li>
# <li>
# <a class="unstyled articleLink" href="/browse/dvd-streaming-all/">Browse All</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-xs-3 subnav">
# <div class="innerSubnav">
# <h2 class="title">More</h2>
# <ul class="list-unstyled" id="header-movies-more">
# <li><a class="unstyled articleLink" href="/top/">Top Movies</a></li>
# <li><a class="unstyled articleLink" href="/trailers/">Trailers</a></li>
# </ul>
# </div>
# </div>
# <div class="col-xs-11 subnav" id="cfp-movies-nav">
# <h2 class="title">Certified Fresh Picks</h2>
# <div class="freshPicks inDropdown" id="header-certified-fresh-picks">
# <div class="cfpItem hidden-xs">
# <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
# <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/hustlers_2019">
# <p class="topText bold"></p>
# <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
# <img alt="Hustlers" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/1Z5dAO4JTiPcxlppytsVXQy1qJA=/fit-in/278x400/v1.bTsxMzE2MTEyMjtqOzE4MjQyOzEyMDA7MTM4MjsyMDQ4" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# </div>
# <div class="movie_content_area">
# <span class="icon tiny certified"></span>
# <span class="tMeterScore">88%</span>
# </div>
# <p class="title noSpacing">Hustlers</p>
# </a>
# </div>
# <div class="cfpItem hidden-xs">
# <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
# <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/ad_astra">
# <p class="topText bold"></p>
# <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
# <img alt="Ad Astra" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/rBk9y2toY3IU_xHL0_iFVhexPbo=/fit-in/278x400/v1.bTsxMzEzMTgyNjtwOzE4MjQxOzEyMDA7OTAwOzEzNTA" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# </div>
# <div class="movie_content_area">
# <span class="icon tiny certified"></span>
# <span class="tMeterScore">83%</span>
# </div>
# <p class="title noSpacing">Ad Astra</p>
# </a>
# </div>
# <div class="cfpItem hidden-xs">
# <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
# <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/john_wick_chapter_3_parabellum">
# <p class="topText bold"></p>
# <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
# <img alt="John Wick: Chapter 3 - Parabellum" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/SewqMJysmUq3SOi65GOBwGcWRJc=/fit-in/278x400/v1.bTsxMzE5NjQyNjtqOzE4MjQyOzEyMDA7MzYwMDs1NDAw" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# </div>
# <div class="movie_content_area">
# <span class="icon tiny certified"></span>
# <span class="tMeterScore">90%</span>
# </div>
# <p class="title noSpacing">John Wick: Chapter 3 - Parabellum</p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="menuHeader center dropdown noSpacing dropdown-toggle">
# <a class="h2" href="//www.rottentomatoes.com/top-tv/" id="tvMenu"> TV<span class="fontelloIcon icon-down-dir"></span></a>
# <div aria-labelledby="tvMenu" class="dropdown-menu" id="tvMenuDropdown" role="menu">
# <div class="row-sameColumnHeight">
# <div class="col-xs-7 subnav">
# <div class="innerSubnav" id="header-tv-col1">
# <h2 class="title">New TV Tonight</h2>
# <table class="movie_list tv_list" id="tv-list-1">
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/couples_therapy/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/couples_therapy/s01">
#
#                 Couples Therapy
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/titans/s02">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">79%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/titans/s02">
#
#                 Titans
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/the_great_british_baking_show/s10">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">71%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_great_british_baking_show/s10">
#
#                 The Great British Baking Show
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/the_politician/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">61%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_politician/s01">
#
#                 The Politician
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/transparent/s05">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">69%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/transparent/s05">
#
#                 Transparent
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/murder_in_the_bayou/s01">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/murder_in_the_bayou/s01">
#
#                 Murder in the Bayou
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/locked_up/s04">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/locked_up/s04">
#
#                 Locked Up (Vis a vis)
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/good_talk_with_anthony_jeselnik/s01">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/good_talk_with_anthony_jeselnik/s01">
#
#                 Good Talk With Anthony Jeselnik
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/fresh_off_the_boat/s06">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/fresh_off_the_boat/s06">
#
#                 Fresh Off the Boat
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/the_big_stage/s01">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_big_stage/s01">
#
#                 The Big Stage
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/masters_of_illusion/s06">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/masters_of_illusion/s06">
#
#                 Masters of Illusion
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/hot_date/s02">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/hot_date/s02">
#
#                 Hot Date
#
#         </a>
# </td>
# </tr>
# </table>
# <div class="header-view-all-wrap">
# <a class="header-view-all-link" href="/browse/tv-list-1/">View All</a>
# </div>
# </div>
# </div>
# <div class="col-xs-7 subnav">
# <div class="innerSubnav" id="header-tv-col2">
# <h2 class="title">Most Popular TV on RT</h2>
# <table class="movie_list tv_list" id="tv-list-2">
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/american_horror_story/s09">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">94%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s09">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/stumptown/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/stumptown/s01">
#
#                 Stumptown
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/fleabag/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/fleabag/s02">
#
#                 Fleabag
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/unbelievable/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/unbelievable/s01">
#
#                 Unbelievable
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/marianne/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marianne/s01">
#
#                 Marianne
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/david_makes_man/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/david_makes_man/s01">
#
#                 David Makes Man
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/the_i_land/s01">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">8%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_i_land/s01">
#
#                 The I-Land
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/emergence/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">91%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/emergence/s01">
#
#                 Emergence
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/undone/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/undone/s01">
#
#                 Undone
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/criminal_uk/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/criminal_uk/s01">
#
#                 Criminal: UK
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/carnival_row/s01">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">56%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/carnival_row/s01">
#
#                 Carnival Row
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvTopListTitle">
# <td class="left_col">
# <a href="/tv/prodigal_son/s01">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">58%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/prodigal_son/s01">
#
#                 Prodigal Son
#
#         </a>
# </td>
# </tr>
# </table>
# <div class="header-view-all-wrap">
# <a class="header-view-all-link" href="/browse/tv-list-2/">View All</a>
# </div>
# </div>
# </div>
# <div class="col-xs-5 subnav">
# <div class="innerSubnav">
# <h2 class="title">More</h2>
# <ul class="list-unstyled" id="header-tv-more">
# <li><a class="unstyled articleLink" href="//www.rottentomatoes.com/top-tv/">Top TV Shows</a></li>
# <li><a class="unstyled articleLink" href="/browse/tv-list-3/">Certified Fresh TV</a></li>
# </ul>
# <h2 class="title" style="margin-top: 20px">Episodic Reviews</h2>
# <ul class="list-unstyled" id="header-tv-episodic-reviews">
# <div class="header-desktop-episode">
# <li><a href="/tv/american_horror_story/s09/#desktopEpisodeList"> American Horror Story: 1984 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/castle_rock/s02/#desktopEpisodeList"> Castle Rock: Season 2 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/fear_the_walking_dead/s05/#desktopEpisodeList"> Fear the Walking Dead: Season 5 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/into_the_dark/s01/#desktopEpisodeList"> Into The Dark: Season 1 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/mr_robot/s04/#desktopEpisodeList"> Mr. Robot: Season 4 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/preacher/s04/#desktopEpisodeList"> Preacher: Season 4 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/succession/s02/#desktopEpisodeList"> Succession: Season 2 </a></li>
# </div>
# <div class="header-desktop-episode">
# <li><a href="/tv/the_walking_dead/s10/#desktopEpisodeList"> The Walking Dead: Season 10 </a></li>
# </div>
# </ul>
# </div>
# </div>
# <div class="col-xs-5 subnav freshPicks inDropdownTv">
# <div class="innerSubnav">
# <h2 class="title cfp-tv-season-title" id="cfp-tv-header-title">Certified Fresh Pick</h2>
# <div class="cfpItem hidden-xs">
# <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
# <a class="unstyled articleLink cfpLinks" href="/tv/unbelievable/s01">
# <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
# <img alt="Unbelievable" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/ZVZPUKkw1ur_-9oHW2mYswAGFAw=/fit-in/278x400/v1.dDs1MzE5OTc7ajsxODIwMjsxMjAwOzEwODA7MTYwMA" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# </div>
# <div class="movie_content_area">
# <span class="icon tiny certified"></span>
# <span class="tMeterScore">96%</span>
# </div>
# <p class="title noSpacing">Unbelievable</p>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="menuHeader center dropdown noSpacing dropdown-toggle" id="newsMenuDropdown">
# <a class="h2" href="https://editorial.rottentomatoes.com/" id="newsMenu">
#                         News<span class="fontelloIcon icon-down-dir"></span>
# </a>
# <div aria-labelledby="newsMenu" class="dropdown-menu" role="menu">
# <div class="row-sameColumnHeight noSpacing">
# <div class="col-xs-4 subnav">
# <div class="innerSubnav" id="header-news-columns">
# <h2 class="title">Columns</h2>
# <ul class="list-unstyled">
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="24 Frames" href="https://editorial.rottentomatoes.com/24-frames/">24 Frames</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="All-Time Lists" href="https://editorial.rottentomatoes.com/all-time-lists/">All-Time Lists</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Binge Guide" href="https://editorial.rottentomatoes.com/binge-guide/">Binge Guide</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Comics on TV" href="https://editorial.rottentomatoes.com/comics-on-tv/">Comics on TV</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Countdown" href="https://editorial.rottentomatoes.com/countdown/">Countdown</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Critics Consensus" href="https://editorial.rottentomatoes.com/critics-consensus/">Critics Consensus</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Five Favorite Films" href="https://editorial.rottentomatoes.com/five-favorite-films/">Five Favorite Films</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Now Streaming" href="https://editorial.rottentomatoes.com/now-streaming/">Now Streaming</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Parental Guidance" href="https://editorial.rottentomatoes.com/parental-guidance/">Parental Guidance</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Red Carpet Roundup" href="https://editorial.rottentomatoes.com/red-carpet-roundup/">Red Carpet Roundup</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Scorecards" href="https://editorial.rottentomatoes.com/movie-tv-scorecards/">Scorecards</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Sub-Cult" href="https://editorial.rottentomatoes.com/sub-cult/">Sub-Cult</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Total Recall" href="https://editorial.rottentomatoes.com/total-recall/">Total Recall</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Video Interviews" href="https://editorial.rottentomatoes.com/video-interviews/">Video Interviews</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Weekend Box Office" href="https://editorial.rottentomatoes.com/weekend-box-office/">Weekend Box Office</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="Weekly Ketchup" href="https://editorial.rottentomatoes.com/weekly-ketchup/">Weekly Ketchup</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="What to Watch" href="https://editorial.rottentomatoes.com/what-to-watch/">What to Watch</a></li>
# <li><a class="unstyled articleLink editorial-header-link" data-pageheader="The Zeros" href="https://editorial.rottentomatoes.com/the-zeros/">The Zeros</a></li>
# </ul>
# </div>
# </div>
# <div class="col-xs-6 subnav">
# <div class="innerSubnav" id="header-news-best-worst">
# <div class="clickForMore">
# <a class="unstyled articleLink" data-pageheader="Best and Worst - Show All" href="https://editorial.rottentomatoes.com/total-recall/">View All <span class="glyphicon"></span></a>
# </div>
# <h2 class="title">Best and Worst</h2>
# <div class="newsContainer">
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/article/sidney-poitiers-7-most-memorable-performances/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2018/01/09155023/Sidney-Poitier-Memorable.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     Sidney Poitier’s 7 Most Memorable Performances
#                                                                 </div>
# </div>
# </a></div>
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/article/total-recall-harry-potter-movies/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2011/07/09155748/Harry-Potter-Movies.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     All Harry Potter Movies Ranked Worst to Best by Tomatometer
#                                                                 </div>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# <div class="col-xs-6 subnav">
# <div class="innerSubnav" id="header-news-guides">
# <div class="clickForMore">
# <a class="unstyled articleLink" data-pageheader="Guides - Show All" href="https://editorial.rottentomatoes.com/rt-hubs/">View All <span class="glyphicon"></span></a>
# </div>
# <h2 class="title">Guides</h2>
# <div class="newsContainer">
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/rt-hub/2019-fall-tv-survey/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2019/09/10140226/RT_FALLTV_600x3141.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     2019 Fall TV Survey
#                                                                 </div>
# </div>
# </a>
# </div>
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/rt-hub/fall-tv/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2018/08/30164254/RT_Fall-TV-Guide_2019_600X314.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     Fall TV
#                                                                 </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6 subnav">
# <div class="innerSubnav" id="header-news-rtnews">
# <div class="clickForMore" style="margin-bottom: 0">
# <a class="unstyled articleLink" data-pageheader="RT News - Show All" href="https://editorial.rottentomatoes.com/news/">View All <span class="glyphicon"></span></a>
# </div>
# <h2 class="title">RT News</h2>
# <div class="newsContainer">
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/article/full-list-of-all-upcoming-marvel-movies/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2019/08/27101053/MCU-Update.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     Your Full List of All Upcoming Marvel Movies — With Key Details!
#                                                                 </div>
# </div>
# </a>
# <div class="newsContainerItem">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/article/spider-man-back-in-the-mcu-disney-and-sony-reach-deal-for-third-film-future-mcu-appearances/">
# <div class="newsPhoto js-lazyLoad" data-bg-image="true" data-src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2019/09/27085041/Spider-Man-3.jpg"></div>
# <div class="newsTitleContainer">
# <div class="newsTitle">
#                                                                     Spider-Man Back in the MCU: Disney and Sony Reach Deal For Third Film, Future MCU Appearances
#                                                                 </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <li class="h2 menuHeader center noSpacing" id="header-tickets-showtimes" style="border-radius: 5px">
# <a class="menuHeader" href="/showtimes/" id="ticketingMenu"> Tickets &amp; Showtimes </a>
# </li>
# </div>
# </div>
# <!-- TRENDING BAR -->
# <div class="trendingBar hidden-xs">
# <div class="fr">
# <ul class="list-inline social" id="trending_bar_social">
# <li><a class="unstyled trendingLink fontelloIcon icon-facebook-squared white" href="//www.facebook.com/rottentomatoes" id="header-facebook-social-link" rel="noopener" target="_blank"></a></li>
# <li><a class="unstyled trendingLink fontelloIcon icon-twitter white" href="//twitter.com/rottentomatoes" id="header-twitter-social-link" rel="noopener" target="_blank"></a></li>
# <li><a class="unstyled trendingLink fontelloIcon icon-instagram white" href="//www.instagram.com/rottentomatoes/" id="header-instagram-social-link" rel="noopener" target="_blank"></a></li>
# <li><a class="unstyled trendingLink fontelloIcon icon-snapchat white" href=" https://www.snapchat.com/add/rottentomatoes" id="header-snapchat-social-link" rel="noopener" target="_blank"></a></li>
# <li><a class="unstyled trendingLink fontelloIcon icon-youtube-play white" href="//www.youtube.com/user/rottentomatoes" id="header-youtube-social-link" rel="noopener" target="_blank"></a></li>
# </ul>
# <div id="trending_bar_ad" style="display: none;"></div>
# <script>
#     var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
# ...
#                                       10 Killer Movie Marketing Campaigns
#                                   </a>
# <br/>
# <span class="home-news-source">– Rotten Tomatoes</span>
# </li>
# </ul>
# </div>
# <br clear="all"/>
# <div class="clickForMore" id="home-top-headlines-view-all">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/publications/">View All</a>
# </div>
# </div>
# </div>
# <div class="col-sm-17 newsList hidden-xs">
# <div class="col-sm-7 center"><!-- Glam medrec for overseas users. glamTarget is set globally in body.tag -->
# <aside class="medrec_ad " id="medrec_bottom_ad" style="width:300px"></aside>
# <script>
#                 var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function () {
#                     if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                         mps.insertAd('#medrec_bottom_ad','boxadone');
#                     } else if (mps.getResponsiveSet() == '0' && 'home' == 'home') {
#                         mps.insertAd('#medrec_bottom_ad','mboxadtwo');
#                     }
#                 });
#             </script>
# </div>
# </div>
# </div>
# </section>
# </section>
# </div>
# <div class="sleaderboard_wrapper hidden-xs mobile-hidden">
# <div id="leaderboard_bottom_ad" style="margin-left:auto;margin-right:auto;display:inline-block"> </div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                 mps.insertAd('#leaderboard_bottom_ad','bottombanner');
#             }
#         });
#     </script>
# </div>
# <!--
#     <c:set var="onloadJs">
#     if(!$("#[skin]_ad").is(":visible")){$("body").removeAttr("style");}
#     </c:set>
#      -->
# <style>#[skin]_ad { height:0px !important; }</style>
# <div id="[skin]_ad"></div>
# <footer class="footer hidden-xs" id="foot">
# <div class="row">
# <div class="col-xs-5 subnav">
# <ul class="unstyled">
# <li><a href="/help_desk/" id="footer-help">Help</a></li>
# <li><a href="/about/" id="footer-about">About Rotten Tomatoes</a></li>
# <li><a href="/about#whatisthetomatometer" id="footer-tomatometer" style="cursor: pointer;">What's the Tomatometer?</a></li>
# <li><a href="https://fandango.az1.qualtrics.com/SE/?SID=SV_cGSHgMIu5ivVwAB" id="footer-feedback" rel="noopener" target="_blank">Feedback</a></li>
# </ul>
# </div>
# <div class="col-xs-4 subnav">
# <ul>
# <li><a href="/help_desk/critics/" id="footer-critics">Critic Submission</a></li>
# <li><a href="/help_desk/licensing/" id="footer-licensing">Licensing</a></li>
# <li><a href="//www.fandango.com/Advertising.aspx" id="footer-advertise">Advertise</a></li>
# <li><a href="//www.fandango.com/careers" id="footer-jobs">Careers</a></li>
# </ul>
# </div>
# <div class="col-xs-7 subnav center">
# <h2><span class="glyphicon glyphicon-envelope envelope"></span>JOIN THE NEWSLETTER</h2>
# <div class="default-half-margin-vertical" id="footer-center-text">
#               Get the freshest reviews, news, and more delivered right to your inbox!
#           </div>
# <div class="default-margin">
# <a class="btn btn-primary" href="/newsletter">Join the Newsletter!</a>
# </div>
# </div>
# <div class="col-xs-8 subnav">
# <h2>Follow Us</h2>
# <div>
# <a class="fontelloIcon icon-facebook-squared footerIcon footer-space" href="//www.facebook.com/rottentomatoes" id="footer-follow-us-facebook"></a>
# <a class="fontelloIcon icon-twitter footerIcon footer-space" href="//twitter.com/rottentomatoes" id="footer-follow-us-twitter"></a>
# <a class="fontelloIcon icon-instagram footerIcon footer-space" href="//www.instagram.com/rottentomatoes/" id="footer-follow-us-instagram"></a>
# <a class="fontelloIcon icon-snapchat footerIcon footer-space" href="https://www.snapchat.com/add/rottentomatoes" id="footer-follow-us-snapchat"></a>
# <a class="fontelloIcon icon-youtube-play footerIcon" href="//www.youtube.com/user/rottentomatoes" id="footer-follow-us-youtube"></a>
# </div>
# </div>
# </div>
# <div class="subtle" style="padding:10px">
#         Copyright © Fandango. All rights reserved. <span class="version">V3</span>
# <a href="//www.fandango.com/PrivacyPolicy" id="footer-privacy">Privacy Policy</a> |
#         <a href="//www.fandango.com/terms-and-policies" id="footer-tos">Terms and Policies</a> |
#         <a href="https://www.fandango.com/policies/cookies-and-tracking#cookie_management">AdChoices</a>
# </div>
# </footer>
# <footer class="footer-mobile visible-xs-block">
# <div class="white">Copyright © Fandango. All rights reserved. <span class="version">V3</span></div>
# <div class="default-margin">
# <a class="btn btn-primary" href="/newsletter">Join Newsletter</a>
# </div>
# <div>
# <a class="footerLinks footer-space" href="//www.fandango.com/terms-and-policies">Terms and Policies</a>
# <a class="footerLinks footer-space" href="//www.fandango.com/PrivacyPolicy">Privacy Policy</a>
# <a class="footerLinks" href="https://fandango.az1.qualtrics.com/SE/?SID=SV_cGSHgMIu5ivVwAB" rel="noopener" target="_blank">Feedback</a>
# </div>
# </footer>
# <div id="fullscreen-search-root" style="display: none;">
# <form id="search-form" method="get">
# <div class="FullscreenSearch FullscreenSearch--mobile">
# <div>
# <div class="FullscreenSearch__top-section">
# <img alt="Rotten Tomatoes Logo" class="FullscreenSearch__top-rt-logo" role="presentation" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/>
# <button class="FullscreenSearch__close-btn" id="fullscreen-search-close-btn" type="button">
# <svg preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 36px; height: 36px;" viewbox="0 0 24 24">
# <g>
# <path d="M19 6.41l-1.41-1.41-5.59 5.59-5.59-5.59-1.41 1.41 5.59 5.59-5.59 5.59 1.41 1.41 5.59-5.59 5.59 5.59 1.41-1.41-5.59-5.59z"></path>
# </g>
# </svg>
# </button>
# <div class="FullscreenSearch__top-section-container container">
# <div class="row">
# <div class="col-xs-24">
# <div class="FullscreenSearch__search-box">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" class="FullscreenSearch__input" id="fullscreen-search-mobile-term" name="search" placeholder="Search movies, TV…" spellcheck="false" value=""/>
# <button class="FullscreenSearch__clear-search-query-btn" id="fullscreen-search-clear-btn" type="button">
# <svg class="FullscreenSearch__clear-search-query-icon" preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 27px; height: 36px;" viewbox="0 0 24 24">
# <path d="M12 2c-5.53 0-10 4.47-10 10s4.47 10 10 10 10-4.47 10-10-4.47-10-10-10zm5 13.59l-1.41 1.41-3.59-3.59-3.59 3.59-1.41-1.41 3.59-3.59-3.59-3.59 1.41-1.41 3.59 3.59 3.59-3.59 1.41 1.41-3.59 3.59 3.59 3.59z"></path>
# </svg>
# </button>
# <button class="FullscreenSearch__search-btn" id="fullscreen-search-search-btn" type="button">
# <svg class="FullscreenSearch__search-icon" preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 27px; height: 36px;" viewbox="0 0 24 24">
# <path d="M15.5 14h-.79l-.28-.27c.98-1.14 1.57-2.62 1.57-4.23 0-3.59-2.91-6.5-6.5-6.5s-6.5 2.91-6.5 6.5 2.91 6.5 6.5 6.5c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99 1.49-1.49-4.99-5zm-6 0c-2.49 0-4.5-2.01-4.5-4.5s2.01-4.5 4.5-4.5 4.5 2.01 4.5 4.5-2.01 4.5-4.5 4.5z"></path>
# </svg>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="FullscreenSearch__results-container container" id="fullscreen-search-results-container">
# <div class="row">
# <div class="col-xs-24">
# <div class="FullscreenSearch__results">
# <!-- Results added dynamically here -->
# </div>
# <a class="FullscreenSearch__results-view-all" href="something" id="fullscreen-search-results-view-all">
#                                 View All Results
#                                 <svg preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 24px; height: 24px;" viewbox="0 0 24 24">
# <path d="M10 6l-1.41 1.41 4.58 4.59-4.58 4.59 1.41 1.41 6-6z"></path>
# </svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </li></ul></div>
# <div class="modal fade" id="newTrailerModal" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
# <div id="videoPlayer" style="width:100%;height:100%"></div>
# </div>
# <div class="fullWidth">
# <div class="btn btn-primary-rt closeBtn">
# <span class="glyphicon glyphicon-chevron-left"></span> Go back
#         </div>
# <div class="moreTrailer">
# <a class="btn btn-primary-rt" href="/trailers/">More trailers <span class="glyphicon glyphicon-chevron-right"></span></a>
# </div>
# </div>
# </div>
# <div class="modal fade" id="newIframeTrailerModal" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
# <iframe id="iframeVideoPlayer" src="about:none" style="width:100%;height:100%"></iframe>
# </div>
# </div>
# <!-- Blue Kai -->
# <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <!-- End Blue Kai -->
# <!-- <bootstrap:bodyScript /> -->
# <script type="text/javascript">
# (function (root) {
# /* -- Data -- */
# root.RottenTomatoes || (root.RottenTomatoes = {});
# root.RottenTomatoes.context = {"_routes":{"adminManagePeople":{"path":"https:\u002F\u002Fadmin.flixster.com\u002Fadmin\u002Fmanage-people?id=:id","tokens":[{"literal":"https:\u002F\u002Fadmin.flixster.com\u002Fadmin\u002Fmanage-people?id="},{"key":"id"}]},"adminMerge":{"path":"https:\u002F\u002Fadmin.flixster.com\u002Factor\u002Fmerge?from=:id","tokens":[{"literal":"https:\u002F\u002Fadmin.flixster.com\u002Factor\u002Fmerge?from="},{"key":"id"}]},"baseCanonicalUrl":{"path":"https:\u002F\u002Fwww.rottentomatoes.com","tokens":[{"literal":"https:\u002F\u002Fwww.rottentomatoes.com"}]},"editorialPageCodeOfConduct":{"path":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fotg-article\u002Fcommunity-code-of-conduct","tokens":[{"literal":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fotg-article\u002Fcommunity-code-of-conduct"}]},"editorialPageProductBlog":{"path":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-product-blog","tokens":[{"literal":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-product-blog"}]},"flixsterGeoLocationApi":{"path":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip","tokens":[{"literal":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip"}]},"napiAudience":{"path":"\u002Fnapi\u002FaudienceScore\u002F:id","tokens":[{"literal":"\u002Fnapi\u002FaudienceScore\u002F"},{"key":"id"}]},"napiAccountForgotPassword":{"path":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F"}]},"napiAccountLogin":{"path":"\u002Fnapi\u002Faccount\u002Flogin\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogin\u002F"}]},"napiAccountLoginFacebookOauth":{"path":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F"}]},"napiAccountLogout":{"path":"\u002Fnapi\u002Faccount\u002Flogout\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogout\u002F"}]},"napiAccountRegister":{"path":"\u002Fnapi\u002Faccount\u002Fregister\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Fregister\u002F"}]},"napiAccountThemePreferences":{"path":"\u002Fnapi\u002Fpreferences\u002Fthemes","tokens":[{"literal":"\u002Fnapi\u002Fpreferences\u002Fthemes"}]},"napiAccountVerifyToken":{"path":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F"}]},"napiAdminMovieDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FmovieDetailPage\u002F:id\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FmovieDetailPage\u002F"},{"key":"id"},{"literal":"\u002Fmenu"}]},"napiAdminTvEpisodeDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvEpisodeDetailPage\u002F:episodeId\u002F:seasonId\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvEpisodeDetailPage\u002F"},{"key":"episodeId"},{"literal":"\u002F"},{"key":"seasonId"},{"literal":"\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAdminTvSeasonDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F:seasonId\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F"},{"key":"seasonId"},{"literal":"\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAdminTvSeriesDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAutocomplete":{"path":"\u002Fnapi\u002Flocation\u002Fautocomplete\u002F:text","tokens":[{"literal":"\u002Fnapi\u002Flocation\u002Fautocomplete\u002F"},{"key":"text"}]},"napiReviewFlag":{"path":"\u002Fnapi\u002Freview\u002Fflag\u002F","tokens":[{"literal":"\u002Fnapi\u002Freview\u002Fflag\u002F"}]},"napiCriticSourceReviews":{"path":"\u002Fnapi\u002Fsource\u002F:id\u002Freview\u002F:type(movie|tv)","tokens":[{"literal":"\u002Fnapi\u002Fsource\u002F"} ...
# root.RottenTomatoes.context || (root.RottenTomatoes.context = {});
# root.RottenTomatoes.context.req = {"params":{},"queries":{},"route":{},"url":"\u002F","secure":false};
# root.RottenTomatoes.context.config = {};
# root.BK = {"PageName":"http:\u002F\u002Fwww.rottentomatoes.com\u002F","SiteID":37528,"SiteSection":""};
# root.RottenTomatoes.thirdParty = {"chartBeat":{"auth":"64558","domain":"rottentomatoes.com"},"facebook":{"appId":"326803741017","version":"v2.9","appName":"flixstertomatoes"},"googleReCaptcha":"6Lcobh0TAAAAAN1K9rWeJ8xgl8uYkASWSDLBuKU1","mpx":{"accountPid":"HNK2IC","playerPid":"vPUdRgYktZD4","accountId":"2474312077"}};
# root.RottenTomatoes.serviceWorker = {"isServiceWokerOn":true};
# root.RottenTomatoes.dtmData = {"webVersion":"node","clicktale":true,"rtVersion":3,"pageName":"rt | homepage"};
# root.RottenTomatoes.context.homepageVideoPlaylist = [{"title":"Top Gun: Maverick - Comic-Con Trailer","mpx_id":"1578836035939","reference_id":"34B6FE9C-0C95-44E3-8077-4DC603C9C878"},{"title":"The Ketchup - The Streaming Wars","mpx_id":"6F8C446C-7838-47A6-8E62-B26F96CB0352","reference_id":"6F8C446C-7838-47A6-8E62-B26F96CB0352"},{"title":"The Hunt: Trailer 1","mpx_id":"1578583107972","reference_id":"ED885403-4355-440E-A622-C6148C212801"},{"title":"Pennyworth: Guess the Batman Quote","mpx_id":"1578853443736","reference_id":"712D8A9B-8522-4CE6-B5AD-47D944D23E08"},{"title":"The Man in the High Castle Season 4 - Comic-Con Sneak Peek","mpx_id":"1579328579864","reference_id":"71445484-404A-4C15-897E-FC19160D7B80"}];
# root.RottenTomatoes.context.gptSite = "home";
# root.RottenTomatoes.serviceWorker || (root.RottenTomatoes.serviceWorker = {});
# root.RottenTomatoes.serviceWorker.preCachingPageUrls = ["\u002Fm\u002Fabominable","\u002Fm\u002Fserie_noire_2019","\u002Fm\u002Fanthropocene_the_human_epoch","\u002Fm\u002Fthe_death_of_dick_long","\u002Fm\u002Fsink_or_swim_2019"];
# }(this));
# </script>
# <script src="//tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/vendor.1c98fc24e13.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/client-side-templates.65b4ed7c2b2.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/global.c6d4814ad11.js"></script>
# <script src="//player.theplatform.com/pdk/dCK2IC/tpPdkController.js?pdk=5.7.14"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/home.2efbe737261.js"></script>
# <script>
#             if ('function' === typeof window.mps.writeFooter) window.mps.writeFooter()
#             </script>
# <script type="text/javascript">window._satellite && _satellite.pageBottom();</script>
# </div></nav></div></body>
# </html>
# >

# %% [markdown]
# <a id='#bs4_parse'></a>
#
# #### Beautiful Soup Parsing Methods
#
# The beauty of Beautiful Soup (pun intended) is in the robust, flexible parsing methods. Some of the ones that I have found the most useful are the following (which we will use to parse this webpage):
#
# * **find_all( )** : the 'find_all()' method is one of the most popular and userful methods of Beautiful Soup. We can pass tags to this method and it will search **DOWN** the tree to return all HTML tags of this type that it finds on the page. <br>
# * **find( )** : the 'find()' method is like the 'find_all()' method, except that it returns only the first occurence of the tag that is passed in as a parameter by searching **DOWN** the tree
#
# (Both **find( )** and **find_all( )** search the descendants of the tree, and most other methods of Beautiful Soup are derivations of these two. We'll touch on a couple others)
#
# * **find_parents( )** : the 'find_parents()' method searches **UP** the tree to find all matching HTML tags, as opposed to **find_all( )** which searches down the tree. <br>
# * **find_parent( )** : the 'find_parent( )' method is like the 'find( )' method, except that it returns only the first occurence of the tag that is found looking **UP** the HTML tree
#
# * **find_next_siblings( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find all matching HTML tags that are siblings in the tree <br>
# * **find_next_sibling( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find the next matching HTML tags that are siblings in the tree <br>
#
# To see a full list of the methods available for parsing HTML trees in Beatiful Soup, visit the documentation page at
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find

# %%
#As we examine our HTML doc, we see that all the information we need are nested in 'div' tags that have 'homepage' 
#as an element of the 'id' tag. 

#To capture these tags, we pass a 'div' tag and also an 'id' tag as parameters to our 'find_all()' method. If we 
#have a value that we are looking to capture in our tags, we can pass it in as a 'dict' parameter. 
#In this instance we use Regular Expressions to capture all the 'id' tags that have the word 'homepage' in the string.

categories = soup.find_all('div', {'id': re.compile('homepage')})

# %%
#Let's now examine the 'categories' object to see what has been stored there
print("Let's look at the length of the 'categories object")
print('Length: ', len(categories), '\n')
print("Now let's examine the first object to see what we need to pull")
print(categories[1].prettify)
# Out:
# Let's look at the length of the 'categories object
# Length:  7
#
# Now let's examine the first object to see what we need to pull
# <bound method Tag.prettify of <div class="listings" id="homepage-top-box-office">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Top Box Office</h2>
# <table class="movie_list" id="Top-Box-Office">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/downton_abbey">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/downton_abbey">Downton Abbey</a>
# </td>
# <td class="right_col right">
# <a href="/m/downton_abbey">$31.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/ad_astra">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/ad_astra">Ad Astra</a>
# </td>
# <td class="right_col right">
# <a href="/m/ad_astra">$19.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/rambo_last_blood">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/rambo_last_blood">Rambo: Last Blood</a>
# </td>
# <td class="right_col right">
# <a href="/m/rambo_last_blood">$18.9M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/it_chapter_two">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">63%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/it_chapter_two">It Chapter Two</a>
# </td>
# <td class="right_col right">
# <a href="/m/it_chapter_two">$17.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hustlers_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hustlers_2019">Hustlers</a>
# </td>
# <td class="right_col right">
# <a href="/m/hustlers_2019">$16.9M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_lion_king_2019">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_lion_king_2019">The Lion King</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_lion_king_2019">$2.8M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/good_boys_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">80%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/good_boys_2019">Good Boys</a>
# </td>
# <td class="right_col right">
# <a href="/m/good_boys_2019">$2.6M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/angel_has_fallen">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">39%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/angel_has_fallen">Angel Has Fallen</a>
# </td>
# <td class="right_col right">
# <a href="/m/angel_has_fallen">$2.5M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/overcomer">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">50%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/overcomer">Overcomer</a>
# </td>
# <td class="right_col right">
# <a href="/m/overcomer">$1.6M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">Fast &amp; Furious Presents: Hobbs &amp; Shaw</a>
# </td>
# <td class="right_col right">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">$1.4M</a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/in-theaters/" id="Top-Box-Office-view-all">View All</a></div>
# </div>>

# %% [markdown]
# <a id='#bs4_html'></a>
#
# #### Creating the right HTML objects to parse: Let's grab the headers
#
# We see that the objects we need to pull have an **'h2'** tag which storest the category name on the rottentomatoes website. The first 6 category objects have this **'h2'** tag, while the last 2 do not (we can discard these last two objects).
#
# We can use the **soup_html_object.text** method to extract the text associated with our tags

# %%
#For each object in the 'categories' object, display it and print out the the movie category title.

for category in categories:
    print(category.find('h2'),'\n')
    # print(category)
    # print("-----------------Next Category Starts----------------- \n\n")
# Out:
# <h2>Movies Opening This Week</h2>
#
# <h2>Top Box Office</h2>
#
# <h2>Coming Soon to Theaters</h2>
#
# <h2>Most Popular TV on RT</h2>
#
# <h2>Top DVD &amp; Streaming Movies</h2>
#
# None
#
# None

# %% [markdown]
# #### Examine Categories
#
# As we examine each object in each of the **categories** object, we see that the nested objects do not give us individual movies with the associated data. In order to grab this in a clear hierarchal fashion, we'll need to create the objects usign the **find( )** and **find_all( )** methodology.

# %%
# Level 1 = categories
# Level 2 = category in categories
# Level 3 = movie in category
for category in categories:
    print(category.find('h2').text,'\n')
    for movie in category.find_all('tr'):
        print(movie, '\n')
        print('****Next Movie****\n')
# Out:
# Movies Opening This Week
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/abominable">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">79%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/abominable">Abominable</a>
# </td>
# <td class="right_col right">
# <a href="/m/abominable">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/serie_noire_2019">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/serie_noire_2019">Série Noire</a>
# </td>
# <td class="right_col right">
# <a href="/m/serie_noire_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/anthropocene_the_human_epoch">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/anthropocene_the_human_epoch">ANTHROPOCENE: The Human Epoch</a>
# </td>
# <td class="right_col right">
# <a href="/m/anthropocene_the_human_epoch">
#
#                     Sep 25
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_death_of_dick_long">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_death_of_dick_long">The Death of Dick Long</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_death_of_dick_long">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/sink_or_swim_2019">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">81%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/sink_or_swim_2019">Sink or Swim (Le grand bain)</a>
# </td>
# <td class="right_col right">
# <a href="/m/sink_or_swim_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# Top Box Office
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/downton_abbey">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/downton_abbey">Downton Abbey</a>
# </td>
# <td class="right_col right">
# <a href="/m/downton_abbey">$31.1M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/ad_astra">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/ad_astra">Ad Astra</a>
# </td>
# <td class="right_col right">
# <a href="/m/ad_astra">$19.1M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/rambo_last_blood">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/rambo_last_blood">Rambo: Last Blood</a>
# </td>
# <td class="right_col right">
# <a href="/m/rambo_last_blood">$18.9M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/it_chapter_two">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">63%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/it_chapter_two">It Chapter Two</a>
# </td>
# <td class="right_col right">
# <a href="/m/it_chapter_two">$17.1M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hustlers_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hustlers_2019">Hustlers</a>
# </td>
# <td class="right_col right">
# <a href="/m/hustlers_2019">$16.9M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_lion_king_2019">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_lion_king_2019">The Lion King</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_lion_king_2019">$2.8M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/good_boys_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">80%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/good_boys_2019">Good Boys</a>
# </td>
# <td class="right_col right">
# <a href="/m/good_boys_2019">$2.6M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/angel_has_fallen">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">39%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/angel_has_fallen">Angel Has Fallen</a>
# </td>
# <td class="right_col right">
# <a href="/m/angel_has_fallen">$2.5M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/overcomer">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">50%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/overcomer">Overcomer</a>
# </td>
# <td class="right_col right">
# <a href="/m/overcomer">$1.6M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">Fast &amp; Furious Presents: Hobbs &amp; Shaw</a>
# </td>
# <td class="right_col right">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">$1.4M</a>
# </td>
# </tr>
#
# ****Next Movie****
#
# Coming Soon to Theaters
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/joker_2019">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/joker_2019">Joker</a>
# </td>
# <td class="right_col right">
# <a href="/m/joker_2019">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/lucy_in_the_sky">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">20%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/lucy_in_the_sky">Lucy in the Sky</a>
# </td>
# <td class="right_col right">
# <a href="/m/lucy_in_the_sky">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/gregorys_girl">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">94%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/gregorys_girl">Gregory's Girl</a>
# </td>
# <td class="right_col right">
# <a href="/m/gregorys_girl">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/pain_and_glory">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">95%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/pain_and_glory">Pain and Glory (Dolor y gloria)</a>
# </td>
# <td class="right_col right">
# <a href="/m/pain_and_glory">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/pretenders">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/pretenders">Pretenders</a>
# </td>
# <td class="right_col right">
# <a href="/m/pretenders">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# Most Popular TV on RT
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/american_horror_story/s09">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">94%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s09">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/stumptown/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/stumptown/s01">
#
#                 Stumptown
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/fleabag/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/fleabag/s02">
#
#                 Fleabag
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/unbelievable/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/unbelievable/s01">
#
#                 Unbelievable
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/marianne/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marianne/s01">
#
#                 Marianne
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/david_makes_man/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/david_makes_man/s01">
#
#                 David Makes Man
#
#         </a>
# </td>
# </tr>
#
# ****Next Movie****
#
# Top DVD & Streaming Movies
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/midsommar">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/midsommar">Midsommar</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/quartet_1981">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/quartet_1981">Quartet</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/crawl_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">82%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/crawl_2019">Crawl</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/skin_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">78%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/skin_2019">Skin</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ****Next Movie****
#
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_bread_factory_part_one_for_the_sake_of_gold">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_bread_factory_part_one_for_the_sake_of_gold">A Bread Factory, Part One: For the Sake of Gold</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ****Next Movie****
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-56dca025a736> in <module>()
#       3 # Level 3 = movie in category
#       4 for category in categories:
# ----> 5     print(category.find('h2').text,'\n')
#       6     for movie in category.find_all('tr'):
#       7         print(movie, '\n')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# We see from these nested loops that we have __three__ levels that need to be parsed in this HTML object in order to get the necessary data. The structure looks like this:
#
# - Categories (TOP BOX OFFICE, OPENING THIS WEEK, etc)
#
#     ```<div id="homepage____">```
#     - Category (TOP BOX OFFICE)
#
#           <h2>Top Box Office</h2>
#
#         - Movies (Dowton Abbey)
#
#           ```<tr class="sidebarInTheaterOpening">```
#
# We can take a look at each of these elements and see how we have to parse the nested HTML objects

# %% [markdown]
# First we'll look at a category:

# %%
# Let's look at the category again
categories[0].prettify
# Out:
# <bound method Tag.prettify of <div class="listings" id="homepage-opening-this-week">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Movies Opening This Week</h2>
# <table class="movie_list" id="Opening">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/abominable">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">79%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/abominable">Abominable</a>
# </td>
# <td class="right_col right">
# <a href="/m/abominable">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/serie_noire_2019">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/serie_noire_2019">Série Noire</a>
# </td>
# <td class="right_col right">
# <a href="/m/serie_noire_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/anthropocene_the_human_epoch">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/anthropocene_the_human_epoch">ANTHROPOCENE: The Human Epoch</a>
# </td>
# <td class="right_col right">
# <a href="/m/anthropocene_the_human_epoch">
#
#                     Sep 25
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_death_of_dick_long">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_death_of_dick_long">The Death of Dick Long</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_death_of_dick_long">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/sink_or_swim_2019">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">81%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/sink_or_swim_2019">Sink or Swim (Le grand bain)</a>
# </td>
# <td class="right_col right">
# <a href="/m/sink_or_swim_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/opening/" id="Opening-view-all">View All</a> </div>
# </div>>

# %% [markdown]
# Next we'll look at an actual movie with all the data by finding the 'tr' tags

# %%
categories[0].find_all('tr')[0]
# Out:
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/abominable">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">79%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/abominable">Abominable</a>
# </td>
# <td class="right_col right">
# <a href="/m/abominable">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>

# %% [markdown]
# <a id='#bs4_find_html'></a>
#
# #### Creating nested HTML objects using **find( ) and **find_all( ) methodology
#
# We see that by setting **movies** to **category.find_all('tr')**, each nested object is a movie with all the necessary data for us to evaluate (title, rating, additional data).

# %%
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    print(category.find('h2').text)
    movies = category.find_all('tr')
    for movie in movies:
        print(movie, '\n')
        print("----------NEXT MOVIE----------")
# Out:
# Movies Opening This Week
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/abominable">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">79%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/abominable">Abominable</a>
# </td>
# <td class="right_col right">
# <a href="/m/abominable">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/serie_noire_2019">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/serie_noire_2019">Série Noire</a>
# </td>
# <td class="right_col right">
# <a href="/m/serie_noire_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/anthropocene_the_human_epoch">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/anthropocene_the_human_epoch">ANTHROPOCENE: The Human Epoch</a>
# </td>
# <td class="right_col right">
# <a href="/m/anthropocene_the_human_epoch">
#
#                     Sep 25
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_death_of_dick_long">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_death_of_dick_long">The Death of Dick Long</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_death_of_dick_long">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/sink_or_swim_2019">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">81%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/sink_or_swim_2019">Sink or Swim (Le grand bain)</a>
# </td>
# <td class="right_col right">
# <a href="/m/sink_or_swim_2019">
#
#                     Sep 27
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Top Box Office
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/downton_abbey">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/downton_abbey">Downton Abbey</a>
# </td>
# <td class="right_col right">
# <a href="/m/downton_abbey">$31.1M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/ad_astra">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/ad_astra">Ad Astra</a>
# </td>
# <td class="right_col right">
# <a href="/m/ad_astra">$19.1M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/rambo_last_blood">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/rambo_last_blood">Rambo: Last Blood</a>
# </td>
# <td class="right_col right">
# <a href="/m/rambo_last_blood">$18.9M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/it_chapter_two">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">63%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/it_chapter_two">It Chapter Two</a>
# </td>
# <td class="right_col right">
# <a href="/m/it_chapter_two">$17.1M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hustlers_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hustlers_2019">Hustlers</a>
# </td>
# <td class="right_col right">
# <a href="/m/hustlers_2019">$16.9M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_lion_king_2019">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_lion_king_2019">The Lion King</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_lion_king_2019">$2.8M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/good_boys_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">80%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/good_boys_2019">Good Boys</a>
# </td>
# <td class="right_col right">
# <a href="/m/good_boys_2019">$2.6M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/angel_has_fallen">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">39%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/angel_has_fallen">Angel Has Fallen</a>
# </td>
# <td class="right_col right">
# <a href="/m/angel_has_fallen">$2.5M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/overcomer">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">50%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/overcomer">Overcomer</a>
# </td>
# <td class="right_col right">
# <a href="/m/overcomer">$1.6M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">Fast &amp; Furious Presents: Hobbs &amp; Shaw</a>
# </td>
# <td class="right_col right">
# <a href="/m/fast_and_furious_presents_hobbs_and_shaw">$1.4M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Coming Soon to Theaters
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/joker_2019">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/joker_2019">Joker</a>
# </td>
# <td class="right_col right">
# <a href="/m/joker_2019">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/lucy_in_the_sky">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">20%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/lucy_in_the_sky">Lucy in the Sky</a>
# </td>
# <td class="right_col right">
# <a href="/m/lucy_in_the_sky">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/gregorys_girl">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">94%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/gregorys_girl">Gregory's Girl</a>
# </td>
# <td class="right_col right">
# <a href="/m/gregorys_girl">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/pain_and_glory">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">95%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/pain_and_glory">Pain and Glory (Dolor y gloria)</a>
# </td>
# <td class="right_col right">
# <a href="/m/pain_and_glory">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/pretenders">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/pretenders">Pretenders</a>
# </td>
# <td class="right_col right">
# <a href="/m/pretenders">
#
#                     Oct 4
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Most Popular TV on RT
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/american_horror_story/s09">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">94%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s09">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/stumptown/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/stumptown/s01">
#
#                 Stumptown
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/fleabag/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/fleabag/s02">
#
#                 Fleabag
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/unbelievable/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/unbelievable/s01">
#
#                 Unbelievable
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/marianne/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marianne/s01">
#
#                 Marianne
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/david_makes_man/s01">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/david_makes_man/s01">
#
#                 David Makes Man
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Top DVD & Streaming Movies
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/midsommar">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">83%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/midsommar">Midsommar</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/quartet_1981">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/quartet_1981">Quartet</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/crawl_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">82%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/crawl_2019">Crawl</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/skin_2019">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">78%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/skin_2019">Skin</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_bread_factory_part_one_for_the_sake_of_gold">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_bread_factory_part_one_for_the_sake_of_gold">A Bread Factory, Part One: For the Sake of Gold</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------

# %% [markdown]
# <a id='#pulling_tags'></a>
#
# #### Pulling the Relevant Tags
#
# Now that we have created the right HTML objects, we can go in and use the **find( )** method to extract the relevant data. We'll leverage the **try/except** functionality in Python so that we can collect the necessary data while not throwing an exception that will break our script should the object not exist.
#
# We can find the data by parsing the appropriate **td** tags tags:
#
# **Movie Title:**
#
# `<td class="middle_col">` <br>
# `<a href="https://www.rottentomatoes.com/tv/the_americans/s06">The Americans</a>` <br>
# `</td>` <br>
#
# **Movie Score:**
#
# `<td class="left_col">` <br>
# `<a href="https://www.rottentomatoes.com/tv/the_americans/s06">` <br>
# `<span class="icon tiny certified_fresh"></span>` <br>
# `<span class="tMeterScore">98%</span>` <br>
# `</a>` <br>
# `</td>` <br>
#
# **Additional Data:**
#
# `<td class="right_col right">` <br>
# `<a href="/m/tyler_perrys_acrimony">` <br>
# `                    $17.2M</a>` <br>
# `</td>` <br>
#
# #### All of these are pieces of this **movie** HTML object:
#
# **Entire Movie Object**
#
# Top Box Office <br>
# `<tr class="sidebarInTheaterOpening">` <br>
# `<td class="left_col">` <br>
# `<a href="/m/ready_player_one">` <br>
# `<span class="icon tiny certified_fresh"></span>` <br>
# `<span class="tMeterScore">74%</span>` <br>
# `</a>` <br>
# `</td>` <br>
# `<td class="middle_col">` <br>
# `<a href="/m/ready_player_one">Ready Player One</a>` <br>
# `</td>` <br>
# `<td class="right_col right">` <br>
# `<a href="/m/ready_player_one">` <br>
# `                    $41.9M</a>` <br>
# `</td>` <br>
# `</tr>` <br>

# %%
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    print(category.find('h2').text)
    movies = category.find_all('tr')
    for movie in movies:
        #We can specify the 'td' tag with 'class' value = 'middle_col' and pull the '.text' attribute
        print(movie.find('td', {'class': 'middle_col'}).text)
        try:
            #To pull the movie score, we need to treat the returned object as an atrribute and then call the 
            #'find_all()' method on that onject once again, while extracting the text of the second element.
            print(movie.find('td', {'class': 'left_col'}).find_all('span')[1].text)
        except:
            print("No Score Yet")
        try:
            #Here we specify the 'td' tag with 'class' value = 'right_col right' and pull the '.text' attribute
            print(movie.find('td', {'class': 'right_col right'}).text)
        except:
            pass
# Out:
# Movies Opening This Week
#
# Abominable
#
# 79%
#
#
#
#                     Sep 27
#
#
#
#
# Série Noire
#
# No Score Yet
#
#
#
#                     Sep 27
#
#
#
#
# ANTHROPOCENE: The Human Epoch
#
# 92%
#
#
#
#                     Sep 25
#
#
#
#
# The Death of Dick Long
#
# 76%
#
#
#
#                     Sep 27
#
#
#
#
# Sink or Swim (Le grand bain)
#
# 81%
#
#
#
#                     Sep 27
#
#
#
# Top Box Office
#
# Downton Abbey
#
# 84%
#
# $31.1M
#
#
# Ad Astra
#
# 83%
#
# $19.1M
#
#
# Rambo: Last Blood
#
# 27%
#
# $18.9M
#
#
# It Chapter Two
#
# 63%
#
# $17.1M
#
#
# Hustlers
#
# 88%
#
# $16.9M
#
#
# The Lion King
#
# 53%
#
# $2.8M
#
#
# Good Boys
#
# 80%
#
# $2.6M
#
#
# Angel Has Fallen
#
# 39%
#
# $2.5M
#
#
# Overcomer
#
# 50%
#
# $1.6M
#
#
# Fast & Furious Presents: Hobbs & Shaw
#
# 67%
#
# $1.4M
#
# Coming Soon to Theaters
#
# Joker
#
# 76%
#
#
#
#                     Oct 4
#
#
#
#
# Lucy in the Sky
#
# 20%
#
#
#
#                     Oct 4
#
#
#
#
# Gregory's Girl
#
# 94%
#
#
#
#                     Oct 4
#
#
#
#
# Pain and Glory (Dolor y gloria)
#
# 95%
#
#
#
#                     Oct 4
#
#
#
#
# Pretenders
#
# No Score Yet
#
#
#
#                     Oct 4
#
#
#
# Most Popular TV on RT
#
#
#
#                 American Horror Story
#
#
#
# 94%
#
#
#
#                 Stumptown
#
#
#
# 96%
#
#
#
#                 Fleabag
#
#
#
# 100%
#
#
#
#                 Unbelievable
#
#
#
# 96%
#
#
#
#                 Marianne
#
#
#
# 100%
#
#
#
#                 David Makes Man
#
#
#
# 100%
# Top DVD & Streaming Movies
#
# Midsommar
#
# 83%
#
#
#
# Quartet
#
# 46%
#
#
#
# Crawl
#
# 82%
#
#
#
# Skin
#
# 78%
#
#
#
# A Bread Factory, Part One: For the Sake of Gold
#
# 100%

# %% [markdown]
# <a id='#storing_data'></a>
#
# #### Storing Data and Exporting to CSV
#
# Now that we know we have the relevant data, we can store our data in a **dict** object and export that data to a **CSV** file via our **Pandas** dataframe.

# %%
movie_data = {}
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    cat = category.find('h2').text
    movies = category.find_all('tr')
    for movie in movies:
        title = movie.find('td', {'class': 'middle_col'}).text
        try:
            score = movie.find('td', {'class': 'left_col'}).find_all('span')[1].text
        except:
            score = "No Score Yet"
        try:
            addtl_data = movie.find('td', {'class': 'right_col right'}).text
        except:
            pass
        movie_data[title.strip()] = {'Category': cat, 'Score': score, 'Addititional_Data': addtl_data.strip()}
movie_data
# Out:
# {'A Bread Factory, Part One: For the Sake of Gold': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '100%'},
#  'ANTHROPOCENE: The Human Epoch': {'Addititional_Data': 'Sep 25',
#   'Category': 'Movies Opening This Week',
#   'Score': '92%'},
#  'Abominable': {'Addititional_Data': 'Sep 27',
#   'Category': 'Movies Opening This Week',
#   'Score': '79%'},
#  'Ad Astra': {'Addititional_Data': '$19.1M',
#   'Category': 'Top Box Office',
#   'Score': '83%'},
#  'American Horror Story': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '94%'},
#  'Angel Has Fallen': {'Addititional_Data': '$2.5M',
#   'Category': 'Top Box Office',
#   'Score': '39%'},
#  'Crawl': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '82%'},
#  'David Makes Man': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '100%'},
#  'Downton Abbey': {'Addititional_Data': '$31.1M',
#   'Category': 'Top Box Office',
#   'Score': '84%'},
#  'Fast & Furious Presents: Hobbs & Shaw': {'Addititional_Data': '$1.4M',
#   'Category': 'Top Box Office',
#   'Score': '67%'},
#  'Fleabag': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '100%'},
#  'Good Boys': {'Addititional_Data': '$2.6M',
#   'Category': 'Top Box Office',
#   'Score': '80%'},
#  "Gregory's Girl": {'Addititional_Data': 'Oct 4',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '94%'},
#  'Hustlers': {'Addititional_Data': '$16.9M',
#   'Category': 'Top Box Office',
#   'Score': '88%'},
#  'It Chapter Two': {'Addititional_Data': '$17.1M',
#   'Category': 'Top Box Office',
#   'Score': '63%'},
#  'Joker': {'Addititional_Data': 'Oct 4',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '76%'},
#  'Lucy in the Sky': {'Addititional_Data': 'Oct 4',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '20%'},
#  'Marianne': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '100%'},
#  'Midsommar': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '83%'},
#  'Overcomer': {'Addititional_Data': '$1.6M',
#   'Category': 'Top Box Office',
#   'Score': '50%'},
#  'Pain and Glory (Dolor y gloria)': {'Addititional_Data': 'Oct 4',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '95%'},
#  'Pretenders': {'Addititional_Data': 'Oct 4',
#   'Category': 'Coming Soon to Theaters',
#   'Score': 'No Score Yet'},
#  'Quartet': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '46%'},
#  'Rambo: Last Blood': {'Addititional_Data': '$18.9M',
#   'Category': 'Top Box Office',
#   'Score': '27%'},
#  'Sink or Swim (Le grand bain)': {'Addititional_Data': 'Sep 27',
#   'Category': 'Movies Opening This Week',
#   'Score': '81%'},
#  'Skin': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '78%'},
#  'Stumptown': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '96%'},
#  'Série Noire': {'Addititional_Data': 'Sep 27',
#   'Category': 'Movies Opening This Week',
#   'Score': 'No Score Yet'},
#  'The Death of Dick Long': {'Addititional_Data': 'Sep 27',
#   'Category': 'Movies Opening This Week',
#   'Score': '76%'},
#  'The Lion King': {'Addititional_Data': '$2.8M',
#   'Category': 'Top Box Office',
#   'Score': '53%'},
#  'Unbelievable': {'Addititional_Data': 'Oct 4',
#   'Category': 'Most Popular TV on RT',
#   'Score': '96%'}}

# %%
#Store dict object in pandas dataframe
df = pd.DataFrame.from_dict(movie_data, orient = 'index')
#Export pandas dataframe to CSV
df.to_csv('rottentomatoes.csv')

# %% [markdown]
# #### Homework Question:
#
# We were unable to handle the "New TV Tonight" section. How can we re-write our code to find this data, and simplify our HTML parsing process? We need to re-examine the HTML on the website. Do we see any other hierarchal tags we can grab to collect all the movie data? How about the movie data **AND** the name of the section above it?
#
# __Hint: what if we look ABOVE a series of tags?__

# %%
categories = soup.find_all('table', {'class': 'movie_list'})

# %% [markdown]
# For each __category__ in __categories__ , can we find the section header name?

# %%
[category.parent.find('h2').text for category in categories]
# Out:
# ['New TV Tonight',
#  'Most Popular TV on RT',
#  'Movies Opening This Week',
#  'Top Box Office',
#  'Coming Soon to Theaters',
#  'New TV Tonight',
#  'Most Popular TV on RT',
#  'Top DVD & Streaming Movies']

# %% [markdown]
# Now, finish extracting the HTML data from this list of objects and export to a CSV file.

# %% [markdown]
# #### Thank You!
#
# Thank you for working through this tutorial. Please feel free to respond with questions/comments, and let me know how this tutorial can be improved.
