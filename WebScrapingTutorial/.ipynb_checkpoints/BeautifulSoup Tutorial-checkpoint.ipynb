# %% [markdown]
# # BeautifulSoup Webscraping Tutorial
#
# #### Table of Contents
#
# 1. <a href='##Introduction'>The Basics of Webscraping With BeautifulSoup</a> <br>
# > 1.a <a href='##urllib'>The urllib package</a> <br>
# > 1.b <a href='##beautiful_soup'>The Beautiful Soup package</a> <br>
# 2. <a href='##example'>Webscrapig Example</a> <br>
# > 2.a <a href='##packages'>Necessary Packages</a> <br>
# > 2.b <a href='##urllib_example'>urllib to grab the website</a> <br>
# > 2.c <a href='##bs4_object'>Create a bs4 object</a> <br>
# 3. <a href='##bs4_parse'>Parsing a Beautiful Soup Object</a> <br>
# > 3.a <a href='##bs4_html'>Creating the right HTML objects to parse</a> <br>
# > 3.b <a href='##bs4_find_html'>Creating nested HTML objects using **find( ) and **find_all( ) methodology</a> <br>
# > 3.c <a href='##pulling_tags'>Parsing the individual movies and pulling the data</a> <br>
# > 3.d <a href='##storing_data'>Storing the data and exporting to CSV</a> <br>

# %% [markdown]
# <a id='#Introduction'></a>
#
# ### The Basics of Webscraping with BeautifulSoup
#
# Beautiful Soup is a lightweight, flexible Python library designed for parsing HTML documents. It provides many great features, such as HTML tree traversal and automatic encoding (incoming documents to Unicode and outgoing documents to UTF-8) (1) which enable the user to focus solely on parsing documents and extracting information. Beautiful Soup itself does not collect webpages - this is left to the urllib package in Python which we'll discuss next. Instead Beauful Soup parses the HTML code, meaning that Beautiful Soup and urllib work hand-in hand.
#
# We'll be working in Python 3 for this tutorial, although Beautiful Soup runs for Python 2 with some simple adjustments to your code. Let's take a look at an example and see if we can get you up and running with parsing your own web pages!
#
# (1) https://www.crummy.com/software/BeautifulSoup/

# %% [markdown]
# <a id='#urllib'></a>
#
# #### The urllib package
#
# The urllib package enables you to access websites via your Python console. With just a few lines of code you can write a program for grabbing objects and saving data from webpages. What's also great about urllib is that it is part of the standard Python libary - so it rarely ever needs to be installed (you already have it upon installing any version of Python). Below are some links to urllib documentation and simple example code:
#
# **Tutorial**:    https://pythonprogramming.net/urllib-tutorial-python-3/ <br>
# **Documentation**: https://docs.python.org/3/library/urllib.html

# %% [markdown]
# <a id='#beautiful_soup'></a>
#
# #### The Beautiful Soup Package
#
# Once we've used urllib to grab an HTML document, then we can deploy Beautiful Soup. Beautiful Soup has built in methods to parse the HTML tree, grab tags and encode incoming/outgoing documents. There have been several iterations of the Beautiful Soup package, the latest of which is **bs4** for Python 3. Below are some relevant links for installing and reading about Beautiful Soup:
#
# **Documentation**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ <br>
# **Installation**: http://www.pythonforbeginners.com/beautifulsoup/beautifulsoup-4-python

# %% [markdown]
# <a id='#example'></a>
#
# #### Let's start a webscraping example
#
# The first thing we need to do is import the relevant packages for our project. These packages are the following: <br>
# * **re** - the regular expressions package for evaluating strings <br>
# * **pandas** - this is a fundamental package for formatting and evaluating data <br>
# * **urllib.request** - HTML reqeusts are handled by the '.request' method in the urllib package <br>
# * **bs4** - we will create an object for parsing using the Beautiful Soup method of the bs4 package <br>

# %% [markdown]
# <a id='#packages'></a>

# %%
import re
import json
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# <a id='#urllib_example'></a>
#
# #### Use urllib to grab the website object

# %%
#Declare the website as a string. For this example, I've decided to grab the data from rottentomatoes website, parse
#the html and save it in a pandas dataframe which we can export to a csv file.
webpage = 'https://www.rottentomatoes.com/'

#Use the 'with-as' method to open the webpage and create an object of the html source code
with urllib.request.urlopen(webpage) as response:
   html = response.read()

# %% [markdown]
# <a id='#bs4_object'></a>
#
# #### Create a Beautiful Soup object
#
# We do this by passing the **html** object to the Beautiful Soup method

# %%
soup = BeautifulSoup(html)
# Out:
# /Users/zacharyescalante/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/zacharyescalante/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# **soup.prettify** displays all the HTML syntax just as it appears on the webpage we took it from. This helps us to determine how to properly search for tags as we parse our tree.

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/" xmlns="http://www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews - Rotten Tomatoes</title>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="description"/>
# <link href="https://www.rottentomatoes.com/" rel="canonical"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/images/favicon.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
# <meta content="326803741017" property="fb:app_id"/>
# <meta content="Rotten Tomatoes" property="og:site_name"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" property="og:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.rottentomatoes.com/" property="og:url"/>
# <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" property="og:image"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" name="twitter:image"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:title"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:text:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="twitter:description"/>
# <meta content="@rottentomatoes" name="twitter:site"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/manifest/manifest.json" rel="manifest"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-60.jpg" rel="apple-touch-icon"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-152.jpg" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-167.jpg" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-180.jpg" rel="apple-touch-icon" sizes="180x180"/>
# <!-- JSON+LD -->
# <meta content="VPPXtECgUUeuATBacnqnCm4ydGO99reF-xgNklSbNbc" name="google-site-verification"/>
# <meta content="034F16304017CA7DCF45D43850915323" name="msvalidate.01"/>
# <meta content="#FA320A" name="theme-color"/>
# <!-- DNS prefetch -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//www.rottentomatoes.com" rel="dns-prefetch"/>
# <link href="//www.rottentomatoes.com" rel="preconnect"/>
# <link as="style" href="/assets/pizza-pie/stylesheets/bundles/roma/layouts/default.68dffaaf6de.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <link as="style" href="/assets/pizza-pie/stylesheets/bundles/roma/pages/home.414a7850bff.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <script>
#         !function(t){"use strict";t.loadCSS||(t.loadCSS=function(){});var e=loadCSS.relpreload={};if(e.support=function(){var e;try{e=t.document.createElement("link").relList.supports("preload")}catch(t){e=!1}return function(){return e}}(),e.bindMediaToggle=function(t){var e=t.media||"all";function a(){t.media=e}t.addEventListener?t.addEventListener("load",a):t.attachEvent&&t.attachEvent("onload",a),setTimeout(function(){t.rel="stylesheet",t.media="only x"}),setTimeout(a,3e3)},e.poly=function(){if(!e.support())for(var a=t.document.getElementsByTagName("link"),n=0;n<a.length;n++){var o=a[n];"preload"!==o.rel||"style"!==o.getAttribute("as")||o.getAttribute("data-loadcss")||(o.setAttribute("data-loadcss",!0),e.bindMediaToggle(o))}},!e.support()){e.poly();var a=t.setInterval(e.poly,500);t.addEventListener?t.addEventListener("load",function(){e.poly(),t.clearInterval(a)}):t.attachEvent&&t.attachEvent("onload",function(){e.poly(),t.clearInterval(a)})}"undefined"!=typeof exports?exports.loadCSS=loadCSS:t.loadCSS=loadCSS}("undefined"!=typeof global?global:this);
#         </script>
# <script>
#             window.RottenTomatoes = {};
#             window.RTLocals = {};
#         </script>
# <script>var dataLayer = dataLayer || [];</script>
# <script id="mps-page-integration">
#       window.mpscall = {"adunits":"Multi Logo|Box Ad|Marquee Banner|Top Banner","cag[score]":null,"cag[certified_fresh]":null,"cag[fresh_rotten]":null,"cag[rating]":null,"cag[release]":null,"cag[movieshow]":null,"cag[genre]":null,"cag[urlid]":null,"cat":"home","field[env]":"production","field[rtid]":null,"path":"/","site":"rottentomatoes-web","title":"Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews","type":"index"};
#       var mpsopts={'host':'mps.nbcuni.com', 'updatecorrelator':1};
#       var mps=mps||{};mps._ext=mps._ext||{};mps._adsheld=[];mps._queue=mps._queue||{};mps._queue.mpsloaded=mps._queue.mpsloaded||[];mps._queue.mpsinit=mps._queue.mpsinit||[];mps._queue.gptloaded=mps._queue.gptloaded||[];mps._queue.adload=mps._queue.adload||[];mps._queue.adclone=mps._queue.adclone||[];mps._queue.adview=mps._queue.adview||[];mps._queue.refreshads=mps._queue.refreshads||[];mps.__timer=Date.now||function(){return+new Date};mps.__intcode="v2";if(typeof mps.getAd!="function")mps.getAd=function(adunit){if(typeof adunit!="string")return false;var slotid="mps-getad-"+adunit.replace(/\W/g,"");if(!mps._ext||!mps._ext.loaded){mps._queue.gptloaded.push(function(){typeof mps._gptfirst=="function"&&mps._gptfirst(adunit,slotid);mps.insertAd("#"+slotid,adunit)});mps._adsheld.push(adunit)}return'<div id="'+slotid+'" class="mps-wrapper" data-mps-fill-slot="'+adunit+'"></div>'};(function(){head=document.head||document.getElementsByTagName("head")[0],mpsload=document.createElement("script");mpsload.src="//"+mpsopts.host+"/fetch/ext/load-"+mpscall.site+".js?nowrite=2";mpsload.id="mps-load";head.insertBefore(mpsload,head.firstChild)})();
#     </script>
# <script>
#         function endsWith(str, suffix) {
#             return str.indexOf(suffix, str.length - suffix.length) !== -1;
#         }
#
#         //--Ad Unit Loaded (called for each ad loaded)
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.adload = mps._queue.adload||[];
#         mps._queue.adload.push(function (eo) {
#             if (!eo.isEmpty) {
#                 var slotName = eo._mps._slot;
#
#                 if ('topbanner' === slotName) {
#                     var leaderboardHeight = eo.size[1];
#                     if (leaderboardHeight > 50){
#
#                         if (leaderboardHeight < 90){
#                             $('.leaderboard_wrapper').css('min-height', leaderboardHeight);
#                         }
#                         $('#top_leaderboard_wrapper').animate({ height: (leaderboardHeight + 10) },1000);
#                     }
#                 }
#
#                 if ('trendinggraphic' === slotName) {
#                     //Hide Trending bar social section
#                     $('#trending_bar_social').hide();
#                     // Roma version
#                     $('.trending-bar__social').hide();
#                     //Removing padding for trending bar ad
#                     $('.trendingBar > .trendingEl').css('padding','0px');
#                     $('#trending_bar_ad').show();
#
#                     $('a.trendingLink').addClass('trending-link-truncate');
#                     // Roma version
#                     $('.trending-bar__link').addClass('trending-link--truncate');
#                 }
#
#                 if ('tomatometer' === slotName) {
#                     if (eo.size[0] == 524 && eo.size[1] == 40) {
#                         //Increase score panel margin
#                         $('#scorePanel').css('margin-bottom', '20px');
#                     }
#                     // Only show Tomatometer Sponsorship div if rendered
#                     $('#tomatometer_sponsorship_ad').show();
#                 }
#             }
#         });
#     </script>
# <script>
#                 dataLayer.push({"webVersion":"node","clicktale":true,"rtVersion":3.1,"loggedInStatus":"","customerId":"","pageName":"rt | homepage"});
#             </script>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-M5LKWCR');
#             </script>
# <script type="text/javascript">!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://honorableland.com/v2xglf05UGcVvzEUFlB6672D6fDwhuTsalYNh9J8Q6zzvZToUzEeznRfzQK-ELINP",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");</script>
# <script>
#             var ALGOLIA_INSIGHTS_SRC = "https://cdn.jsdelivr.net/npm/search-insights@1.5.0";
#
#             !function(e,a,t,n,s,i,c){e.AlgoliaAnalyticsObject=s,e[s]=e[s]||function(){
#             (e[s].queue=e[s].queue||[]).push(arguments)},i=a.createElement(t),c=a.getElementsByTagName(t)[0],
#             i.async=1,i.src=n,c.parentNode.insertBefore(i,c)
#             }(window,document,"script",ALGOLIA_INSIGHTS_SRC,"aa");
#         </script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# </head>
# <body class="body no-touch js-mptd-layout">
# <div id="emptyPlaceholder"></div>
# <script>
#                     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function()
#                     {n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}
#                     ;if(!f._fbq)f._fbq=n;
#                         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#                         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#                     fbq('init', '1147905821962466');
#                     fbq('track', 'PageView');
#                 </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1147905821962466&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script async="" src="//assets.adobedtm.com/launch-EN549327edc13e414a9beb5d61bfd9aac6.min.js"></script>
# <!--BEGIN QUALTRICS WEBSITE FEEDBACK SNIPPET-->
# <script type="text/javascript">
#   (function(){var g=function(e,h,f,g){
#   this.get=function(a){for(var a=a+"=",c=document.cookie.split(";"),b=0,e=c.length;b<e;b++){for(var d=c[b];" "==d.charAt(0);)d=d.substring(1,d.length);if(0==d.indexOf(a))return d.substring(a.length,d.length)}return null};
#   this.set=function(a,c){var b="",b=new Date;b.setTime(b.getTime()+6048E5);b="; expires="+b.toGMTString();document.cookie=a+"="+c+b+"; path=/; "};
#   this.check=function(){var a=this.get(f);if(a)a=a.split(":");else if(100!=e)"v"==h&&(e=Math.random()>=e/100?0:100),a=[h,e,0],this.set(f,a.join(":"));else return!0;var c=a[1];if(100==c)return!0;switch(a[0]){case "v":return!1;case "r":return c=a[2]%Math.floor(100/c),a[2]++,this.set(f,a.join(":")),!c}return!0};
#   this.go=function(){if(this.check()){var a=document.createElement("script");a.type="text/javascript";a.src=g;document.body&&document.body.appendChild(a)}};
#   this.start=function(){var t=this;"complete"!==document.readyState?window.addEventListener?window.addEventListener("load",function(){t.go()},!1):window.attachEvent&&window.attachEvent("onload",function(){t.go()}):t.go()};};
#   try{(new g(100,"r","QSI_S_ZN_6SDb0uWojRgLmmN","https://zn6sdb0uwojrglmmn-fandango.siteintercept.qualtrics.com/SIE/?Q_ZID=ZN_6SDb0uWojRgLmmN")).start()}catch(i){}})();
#   </script><div id="ZN_6SDb0uWojRgLmmN"><!--DO NOT REMOVE-CONTENTS PLACED HERE--></div>
# <!--END WEBSITE FEEDBACK SNIPPET-->
# <div class="container roma-layout__body">
# <div id="header_and_leaderboard">
# <div class="leaderboard_wrapper homepage_leaderboard" id="top_leaderboard_wrapper">
# <div class="leaderboard_helper" id="top_leaderboard_helper">
# <div id="leaderboard_top_ad"></div>
# <script>
#                 //--RESPONSIVE AD SWITCHING (DIFFERENT CONTAINERS)
#                 var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function () {
#                     if (mps.getResponsiveSet() == '0') { //MOBILE
#                         mps.insertAd('#leaderboard_top_ad','mbanner');
#                     } else { //DESKTOP or TABLET
#                         mps.insertAd('#leaderboard_top_ad','topbanner');
#                     }
#                 });
#             </script>
# </div>
# </div>
# </div>
# <!-- salt=mastheader-not-grendel -->
# <header class="masthead">
# <nav aria-label="navigation bar" class="masthead__navbar" id="navbar">
# <a class="skip-link" href="#main-page-content">Skip to Main Content</a>
# <a class="skip-link" href="#masthead-dropdown-menus">Skip to Dropdowns</a>
# <h2 class="unset">
# <a href="/">
# <img alt="Rotten Tomatoes" class="masthead__logo" id="masthead-logo" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/>
# <span class="masthead--hide">Rotten Tomatoes</span>
# </a>
# </h2>
# <div id="new_logo_ad" style="display:none;"></div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             mps.rt.insertlogo('#new_logo_ad', 'ploc=rtlogo;');
#         });
#     </script>
# <ul class="list-inline masthead__inline-links">
# <li><a class="masthead__header-link" data-qa="header:link-whats-tmeter" href="/about#whatisthetomatometer">What's the Tomatometer®?</a></li>
# <li><a class="masthead__header-link" data-qa="header:link-critics-home" href="/critics">Critics</a></li>
# <li class="js-masthead-account-links-login masthead__auth-group">
# <ul class="list-inline">
# <li><button class="masthead__link-btn button--link" data-qa="header:sign-up-btn" id="masthead-show-registration-btn">Sign up</button></li>
# <li class="masthead__log-in-wrap"><button class="masthead__link-btn button--link" data-qa="header:login-btn" id="masthead-show-login-btn">Log in</button></li>
# </ul>
# </li>
# <li class="js-masthead-account-links-user"></li>
# </ul>
# <search-algolia class="search-algolia-desktop" hidden="">
# <search-algolia-controls slot="search-controls">
# <input class="search-text" data-qa="search-input" placeholder="Search movies, TV, actors, more..." slot="search-input" type="text"/>
# <button class="search-clear" data-qa="search-clear" slot="search-clear">
# <rt-icon icon="cancel-circled" image=""></rt-icon>
# </button>
# <a class="search-submit" data-qa="search-submit" href="/search" slot="search-submit">
# <rt-icon icon="search" image=""></rt-icon>
# </a>
# </search-algolia-controls>
# <search-algolia-results data-qa="search-results-overlay" slot="search-results">
# <search-algolia-results-category data-qa="search-results-category" slot="content">
# <h2 data-qa="search-category-header" slot="title">Movies / TV</h2>
# <ul slot="results"></ul>
# </search-algolia-results-category>
# <search-algolia-results-category data-qa="search-results-category" slot="celebrity">
# <h2 data-qa="search-category-header" slot="title">Celebrity</h2>
# <ul slot="results"></ul>
# </search-algolia-results-category>
# <search-algolia-results-category slot="none">
# <h2 data-qa="search-no-results" slot="title">No Results Found</h2>
# </search-algolia-results-category>
# <a data-qa="search-view-all" href="/" slot="view-all">View All</a>
# </search-algolia-results>
# </search-algolia>
# <button class="button--link search-bar-mobile__search-reveal-btn mobile-visible" id="mobile-search-algolia-btn">
# <span class="rt-icon rt-icon__search"></span>
# </button>
# <div class="masthead__dropdown-menus" id="masthead-dropdown-menus">
# <a class="skip-link" href="#trending-bar-start">Skip to Trending Bar</a>
# <ul class="masthead__dropdown-menus list-inline">
# <li class="masthead__menu-header js-masthead-menu-header" data-content="_moviesAndDvds" data-qa="masthead:movies-dvds">
# <a class="masthead__menu-header-title" href="/browse/opening/">Movies</a>
# </li>
# <li class="masthead__menu-header js-masthead-menu-header" data-content="_tv" data-qa="masthead:tv">
# <a class="masthead__menu-header-title" href="https://www.rottentomatoes.com/top-tv">TV Shows</a>
# </li>
# <li class="masthead__menu-header masthead__menu-header--podcast masthead__no-content js-masthead-menu-header" data-qa="masthead:podcast">
# <temporary-display element="#podcast-link" event="click" key="podcast">
# <rt-badge hidden="">New</rt-badge>
# </temporary-display>
# <a class="masthead__menu-header-title" href="https://editorial.rottentomatoes.com/rt-podcast/" id="podcast-link">RT Podcast</a>
# </li>
# <li class="masthead__menu-header js-masthead-menu-header" data-content="_news" data-qa="masthead:news">
# <a class="masthead__menu-header-title" href="https://editorial.rottentomatoes.com/">News</a>
# </li>
# <li class="masthead__menu-header masthead__no-content js-masthead-menu-header" data-qa="masthead:tickets-showtimes">
# <a class="masthead__menu-header-title" href="/showtimes">Showtimes</a>
# </li>
# </ul>
# </div>
# </nav>
# <section class="trending-bar">
# <div id="trending_bar_ad" style="display: none;"></div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                 mps.insertAd('#trending_bar_ad','trendinggraphic');
#             }
#         });
#     </script>
# <div class="trending-list-wrap" id="trending-bar-start">
# <ul class="list-inline trending-bar__list">
# <li class="trending-bar__header">Trending on RT</li>
# <li><a class="trending-bar__link" href="https://editorial.rottentomatoes.com/article/rotten-tomatoes-is-wrong-about-spider-man-3/"> Rotten Tomatoes Podcast </a></li>
# <li><a class="trending-bar__link" href="https://editorial.rottentomatoes.com/rt-hub/2020-fall-tv-survey/"> Fall TV Survey Results </a></li>
# <li><a class="trending-bar__link" href="https://editorial.rottentomatoes.com/article/rotten-tomatoes-watch-list-on-quibi/"> RT Watch List </a></li>
# <li><a class="trending-bar__link" href="https://editorial.rottentomatoes.com/guide/essential-spanish-language-movies-the-best-spanish-movies/"> Essential Spanish-Language Films </a></li>
# </ul>
# <div class="list-inline trending-bar__social">
# <a aria-label="Facebook" class="trending-bar__social-link rt-icon rt-icon__facebook-squared" href="//www.facebook.com/rottentomatoes" id="header-facebook-social-link" rel="noopener" target="_blank"></a>
# <a aria-label="Twitter" class="trending-bar__social-link rt-icon rt-icon__twitter" href="//twitter.com/rottentomatoes" id="header-twitter-social-link" rel="noopener" target="_blank"></a>
# <a aria-label="Instagram" class="trending-bar__social-link rt-icon rt-icon__instagram" href="//www.instagram.com/rottentomatoes/" id="header-instagram-social-link" rel="noopener" target="_blank"></a>
# <a aria-label="Snapchat" class="trending-bar__social-link rt-icon rt-icon__snapchat" href=" https://www.snapchat.com/add/rottentomatoes" id="header-snapchat-social-link" rel="noopener" target="_blank"></a>
# <a aria-label="Youtube" class="trending-bar__social-link rt-icon rt-icon__youtube-play" href="//www.youtube.com/user/rottentomatoes" id="header-youtube-social-link" rel="noopener" target="_blank"></a>
# </div>
# </div>
# </section>
# </header>
# <main class="container roma-layout__content" id="main_container">
# <div id="main-page-content">
# <section class="homepage-video js-homepage-video hide">
# <div class="homepage-video-header-wrap">
# <p class="h1 homepage-video__header">Must-see videos</p>
# <p class="homepage-video__body">The freshest trailers, news, reviews, and interviews</p>
# </div>
# <div class="js-selected-video selected-video" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/491/803/GeniusAretha_S03_Teaser.jpg)">
# <div class="js-selected-video-inner selected-video__inner">
# <span class="js-video-info selected-video__duration">0:30</span>
# <span class="js-video-info selected-video__title selected-video__title--full-width-experience">First Look: See Cynthia Erivo as Aretha Franklin in 'Genius'</span>
# <a class="js-video-info js-selected-video-play-button selected-video__play-button" data-reference-id="23CF7016-504B-53D5-E961-3057D5BEEE4E" href="#">
# <span class="selected-video__play-button-text">Play</span>
# </a>
# <span class="js-video-info selected-video__title">First Look: See Cynthia Erivo as Aretha Franklin in 'Genius'</span>
# </div>
# </div>
# <div class="homepage-video-header-wrap homepage-video-header-wrap--full-width">
# <h1 class="homepage-video__header">Must-see videos</h1>
# <p class="homepage-video__body">The freshest trailers, news, reviews, and interviews</p>
# </div>
# <div class="video-playlist">
# <nav class="video-playlist__scroll-wrap">
# <button class="js-video-playlist-scroll-button video-playlist-scroll-button video-playlist-scroll-button--previous video-playlist-scroll-button--hide" data-direction="previous"></button>
# <button class="js-video-playlist-scroll-button video-playlist-scroll-button video-playlist-scroll-button--next" data-direction="next"></button>
# </nav>
# <div class="js-video-playlist-inner-wrap video-playlist__inner-wrap">
# <a class="js-video-playlist-video video-playlist__video" data-playlist-position="0" data-reference-id="23CF7016-504B-53D5-E961-3057D5BEEE4E" data-thumbnail="https://statcdn.fandango.com/MPX/image/NBCU_Fandango/491/803/GeniusAretha_S03_Teaser.jpg" href="#">
# <div class="video-playlist__thumbnail" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/491/803/GeniusAretha_S03_Teaser.jpg)">
# <div class="video-playlist__background-overlay"></div>
# <div class="video-playlist__video-duration">
# <div class="video-playlist__video-duration-not-playing">
# <span class="video-playlist__video-play-icon"></span>
# <span class="video-playlist__video-duration-time">0:30</span>
# </div>
# <div class="video-playlist__video-duration-is-playing">Now Playing</div>
# </div>
# </div>
# <span class="video-playlist__video-title">First Look: See Cynthia Erivo as Aretha Franklin in 'Genius'</span>
# </a>
# <a class="js-video-playlist-video video-playlist__video" data-playlist-position="1" data-reference-id="88D05905-BF18-4A1E-931A-B86E0E7E3A20" data-thumbnail="https://statcdn.fandango.com/MPX/image/NBCU_Fandango/549/63/thumb_2E5D2F4A-521B-4BBD-A937-23703CF909D0.jpg" href="#">
# <div class="video-playlist__thumbnail" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/549/63/thumb_2E5D2F4A-521B-4BBD-A937-23703CF909D0.jpg)">
# <div class="video-playlist__background-overlay"></div>
# <div class="video-playlist__video-duration">
# <div class="video-playlist__video-duration-not-playing">
# <span class="video-playlist__video-play-icon"></span>
# <span class="video-playlist__video-duration-time">1:40</span>
# </div>
# <div class="video-playlist__video-duration-is-playing">Now Playing</div>
# </div>
# </div>
# <span class="video-playlist__video-title">Watch the Trailer for 'Saw' Spinoff 'Spiral'</span>
# </a>
# <a class="js-video-playlist-video video-playlist__video" data-playlist-position="2" data-reference-id="C295AE60-C35D-4312-AF66-65493112B42A" data-thumbnail="https://statcdn.fandango.com/MPX/image/NBCU_Fandango/302/915/thumb_222BDCFC-CD9A-4230-83C9-DAED79AFF884.jpg" href="#">
# <div class="video-playlist__thumbnail" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/302/915/thumb_222BDCFC-CD9A-4230-83C9-DAED79AFF884.jpg)">
# <div class="video-playlist__background-overlay"></div>
# <div class="video-playlist__video-duration">
# <div class="video-playlist__video-duration-not-playing">
# <span class="video-playlist__video-play-icon"></span>
# <span class="video-playlist__video-duration-time">1:53</span>
# </div>
# <div class="video-playlist__video-duration-is-playing">Now Playing</div>
# </div>
# </div>
# <span class="video-playlist__video-title">Just in: Trailer for 'Lebowski' Spin-off ‘The Jesus Rolls'</span>
# </a>
# <a class="js-video-playlist-video video-playlist__video" data-playlist-position="3" data-reference-id="F1637D60-BDFA-47D4-8439-5625E17F5AA9" data-thumbnail="https://statcdn.fandango.com/MPX/image/NBCU_Fandango/335/623/thumb_9FC0FD42-6D8C-4DD0-804E-F6820901034C.jpg" href="#">
# <div class="video-playlist__thumbnail" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/335/623/thumb_9FC0FD42-6D8C-4DD0-804E-F6820901034C.jpg)">
# <div class="video-playlist__background-overlay"></div>
# <div class="video-playlist__video-duration">
# <div class="video-playlist__video-duration-not-playing">
# <span class="video-playlist__video-play-icon"></span>
# <span class="video-playlist__video-duration-time">3:27</span>
# </div>
# <div class="video-playlist__video-duration-is-playing">Now Playing</div>
# </div>
# </div>
# <span class="video-playlist__video-title">What Do We Know About 'The Mandalorian' Season 2?</span>
# </a>
# <a class="js-video-playlist-video video-playlist__video" data-playlist-position="4" data-reference-id="4BB50798-AB70-44C5-8FEA-F79C3C2D153B" data-thumbnail="https://statcdn.fandango.com/MPX/image/NBCU_Fandango/584/223/thumb_A8FF6E00-559B-4B1A-8E5E-400892C2488E.jpg" href="#">
# <div class="video-playlist__thumbnail" style="background-image: url(https://statcdn.fandango.com/MPX/image/NBCU_Fandango/584/223/thumb_A8FF6E00-559B-4B1A-8E5E-400892C2488E.jpg)">
# <div class="video-playlist__background-overlay"></div>
# <div class="video-playlist__video-duration">
# <div class="video-playlist__video-duration-not-playing">
# <span class="video-playlist__video-play-icon"></span>
# <span class="video-playlist__video-duration-time">2:50</span>
# </div>
# <div class="video-playlist__video-duration-is-playing">Now Playing</div>
# </div>
# </div>
# <span class="video-playlist__video-title">Just in: Trailer for 'Minions: The Rise of Gru'</span>
# </a>
# </div>
# </div>
# </section>
# <!-- salt=home-sticky-wicket-88 -->
# <section class="home-body ">
# <section class="js-rtv2-home-spotlight legacy-home-spotlight">
# <div class="homepage-banner" id="banner">
# <section class="headline col-sm-12">
# <div class="headliners carousel slide js-carousel" data-ride="carousel" id="headliners">
# <ul class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#headliners"></li>
# <li data-slide-to="1" data-target="#headliners"></li>
# <li data-slide-to="2" data-target="#headliners"></li>
# <li data-slide-to="3" data-target="#headliners"></li>
# <li data-slide-to="4" data-target="#headliners"></li>
# <li data-slide-to="5" data-target="#headliners"></li>
# <li data-slide-to="6" data-target="#headliners"></li>
# <li data-slide-to="7" data-target="#headliners"></li>
# </ul>
# <div class="carousel-inner spotlight-item-wrap">
# <section class="js-headline headlineItem item active" id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="0" href="https://editorial.rottentomatoes.com/article/everything-we-know-about-wandavision-disney-plus/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/3HnlIaYQcKexHwsxQWkfWULUuJA=/411x160/v1.czsxMDI4MjkyOTtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/hxUvry4PmtFYjWA_FAPU6ne_qF0=/550x310/v1.czsxMDI4MjkyOTtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>Everything You Need to Know About Disney+'s <em>WandaVision</em></h2>
# <p>See the new trailer, learn how it ties into the MCU, and who else is showing up</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="1" href="https://editorial.rottentomatoes.com/article/biggest-emmy-2020-moments/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/srbG-0Ap-Y-Eg9aI1DLBBbYmAyg=/411x160/v1.czsxMDI4MjkyNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/AgJeGq9BSSzuQimQPSGLeO7zHus=/550x310/v1.czsxMDI4MjkyNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>The Biggest Emmy Awards Moments</h2>
# <p>A historic night for Black TV talent, a <em>Schitt's</em> sweep, and more!</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="2" href="https://editorial.rottentomatoes.com/article/2020-emmy-winners/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/XUPg9AAvVuajfNZegjAaflQx044=/411x160/v1.czsxMDI4MjkyNTtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/DSvRQ6_v0TXRFfM7GxoyGCv7gn8=/550x310/v1.czsxMDI4MjkyNTtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>The 2020 Emmys Winners: Your Full List</h2>
# <p>It was a big night for <em>Schitt's Creek</em>, <em>Watchmen</em>, <em>Succession</em>, and Zendaya</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="3" href="https://editorial.rottentomatoes.com/guide/worst-remakes-of-all-time/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/xCfc89RCtK0GqD7deZyZ3BOYcVo=/411x160/v1.czsxMDI4MjkxNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/1rjElsFRAHvVq6EWwnjb-1Q6bHY=/550x310/v1.czsxMDI4MjkxNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>Worst Remakes of All Time</h2>
# <p>Second time's the harm for these movies scoring less than 10%</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="4" href="https://editorial.rottentomatoes.com/article/jonathan-majors-cast-as-major-ant-man-3-villain-and-more-movie-news/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/xKdtKp5QFdtmbqxGwAwfPFFJSDs=/411x160/v1.czsxMDI4MjkyMDtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/OLSz6jsUWqxpJ51rAAmDMgio1og=/550x310/v1.czsxMDI4MjkyMDtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>Jonathan Majors Cast As <em>Ant-Man 3</em> Villain</h2>
# <p>The <em>Lovecraft Country</em> star moves to the MCU, plus more movie news of the week</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="5" href="https://editorial.rottentomatoes.com/article/tatiana-maslany-is-she-hulk-star-mandalorian-season-2-trailer-more-tv-news/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/W8rSf5-BlLCxqOy_UoWrpjjGgP0=/411x160/v1.czsxMDI4MjkyMjtqOzE4NjE0OzEyMDA7NjAwOzMxNA,https://resizing.flixster.com/K7m4DGrLCnU5bM0k1XE2i0O9Qfg=/550x310/v1.czsxMDI4MjkyMjtqOzE4NjE0OzEyMDA7NjAwOzMxNA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2><em>She-Hulk</em> Star: Tatiana Maslany Lined Up Play the Green Goddess</h2>
# <p>Get that, and all the TV news of the week</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="6" href="https://editorial.rottentomatoes.com/rt-hub/2020-fall-tv-survey/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/d6s5aYrY21h427vErfv-1JCPCNc=/411x160/v1.czsxMDI4MjkxMjtqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/o27oK5Ld9KOFjcFlP5G0aw9-w4U=/550x310/v1.czsxMDI4MjkxMjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>We Asked, you answered: 2020 Fall TV Survey Results</h2>
# <p>Most bingeable shows, best Netflix series, fave talk-show host and more inquiries</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem item " id="">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a data-slide-index="7" href="https://editorial.rottentomatoes.com/article/rotten-tomatoes-is-wrong-about-spider-man-3/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="https://resizing.flixster.com/HbS1ralnH8yAjgDMH-YPFKj3JFg=/411x160/v1.czsxMDI4MjkxMztqOzE4NjE0OzEyMDA7NTUwOzMxMA,https://resizing.flixster.com/uS6l6MJI8XEsmcB-Vefg9SKsXAc=/550x310/v1.czsxMDI4MjkxMztqOzE4NjE0OzEyMDA7NTUwOzMxMA" data-src="">
# </div>
# <div class="bannerCaption subPanel">
# <h2>Raimi's <em>Spidey 3</em>: Under-appreciated gem or bloated mess? </h2>
# <p>The first episode of our brand-new podcast has arrived: Listen now! </p>
# </div>
# </a>
# </section>
# </div>
# <div class="carousel-navigation">
# <button class="carousel-navigation__control" data-slide="prev" data-target="#headliners">
# <rt-icon class="carousel-navigation__control__icon carousel-navigation__control__icon--left" icon="left-chevron" image=""></rt-icon>
# </button>
# <button class="carousel-navigation__control" data-slide="next" data-target="#headliners">
# <rt-icon class="carousel-navigation__control__icon carousel-navigation__control__icon--right" icon="right-chevron" image=""></rt-icon>
# </button>
# </div>
# </div>
# </section>
# <section class="js-headline headlineItem headline col-sm-6 mobile-hidden homepage-spotlight active" id="homepage-spotlight1">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a href="https://editorial.rottentomatoes.com/guide/the-2020-toronto-film-festival-movie-scorecard/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="" data-src="https://resizing.flixster.com/pAE4xrI9DeewFJ-FcEBO7Z6hUFA=/540x610/v1.czsxMDI4MjkyODtqOzE4NjE0OzEyMDA7Mjc0OzMxMA">
# </div>
# <div class="bannerCaption subPanel">
# <h2>2020 Toronto Film Fest Scorecard</h2>
# <p>Every movie that played with a Tomatometer</p>
# </div>
# </a>
# </section>
# <section class="js-headline headlineItem headline col-sm-6 mobile-hidden homepage-spotlight active" id="homepage-spotlight2">
# <aside class="sponsored-tag">
# <p class="sponsored-text">FEATURED</p>
# <div class="sponsored-bg"></div>
# </aside>
# <a href="https://editorial.rottentomatoes.com/rt-hub/binge-central/">
# <div class="bannerPic js-lazyLoad home-slide" data-bg-image="true" data-bg-srcset="" data-src="https://resizing.flixster.com/4-FFWUEHdrjgnIgow00xHbYvc_0=/540x610/v1.czsxMDI4MjkyMTtqOzE4NjE0OzEyMDA7Mjc0OzMxMA">
# </div>
# <div class="bannerCaption subPanel">
# <h2>The Best Of Streaming </h2>
# <p>What to watch and where, sponsored by Mastercard</p>
# </div>
# </a>
# </section>
# <div id="spotlight_ad" style="height:0px"></div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                 mps.insertAd('#spotlight_ad','spotlight');
#             }
#         });
#     </script>
# </div>
# </section>
# <section class="js-new-spotlight hide">
# <section class="spotlight">
# <h2>News &amp; features</h2>
# <div class="spotlight__body">
# <div class="module-1x4">
# <ul class="module-1x4__left spotlight__left">
# <li class="spotlight-item homepage-spotlight__item module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/everything-we-know-about-wandavision-disney-plus/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/7ZCDe64s6RSW17SKu_839xr-fiA=/1100x610/v1.czsxMDI4MjkyOTtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">Everything You Need to Know About Disney+'s <em>WandaVision</em></h3>
# <p class="spotlight-item__header">See the new trailer, learn how it ties into the MCU, and who else is showing up
#       </p></div>
# </a>
# </li>
# </ul>
# <ul class="module-1x4__right spotlight__right">
# <li class="spotlight-item homepage-spotlight__item module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/biggest-emmy-2020-moments/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/3lsGt8T1teub-ctvE3r6v6d3myU=/1100x610/v1.czsxMDI4MjkyNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">The Biggest Emmy Awards Moments</h3>
# <p class="spotlight-item__header">A historic night for Black TV talent, a <em>Schitt's</em> sweep, and more!
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/2020-emmy-winners/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/b8w88fzD8vOTa-vzbAkrP3AcCe0=/1100x610/v1.czsxMDI4MjkyNTtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">The 2020 Emmys Winners: Your Full List</h3>
# <p class="spotlight-item__header">It was a big night for <em>Schitt's Creek</em>, <em>Watchmen</em>, <em>Succession</em>, and Zendaya
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/guide/worst-remakes-of-all-time/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/I6R_Fc_qQkmnIL7MPtLyLMG6Jdw=/1100x610/v1.czsxMDI4MjkxNjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">Worst Remakes of All Time</h3>
# <p class="spotlight-item__header">Second time's the harm for these movies scoring less than 10%
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/jonathan-majors-cast-as-major-ant-man-3-villain-and-more-movie-news/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/oLRqrfbjOXgcSYS13gVGxPnK2cg=/1100x610/v1.czsxMDI4MjkyMDtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">Jonathan Majors Cast As <em>Ant-Man 3</em> Villain</h3>
# <p class="spotlight-item__header">The <em>Lovecraft Country</em> star moves to the MCU, plus more movie news of the week
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item spotlight-item--mobile module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/tatiana-maslany-is-she-hulk-star-mandalorian-season-2-trailer-more-tv-news/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/ZuocSKb8Ge5lauVsL8OE85GYsrU=/1100x610/v1.czsxMDI4MjkyMjtqOzE4NjE0OzEyMDA7NjAwOzMxNA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header"><em>She-Hulk</em> Star: Tatiana Maslany Lined Up Play the Green Goddess</h3>
# <p class="spotlight-item__header">Get that, and all the TV news of the week
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item spotlight-item--mobile module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/rt-hub/2020-fall-tv-survey/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/wMR1UMtTp9epoACbGY1kuTClhyQ=/1100x610/v1.czsxMDI4MjkxMjtqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">We Asked, you answered: 2020 Fall TV Survey Results</h3>
# <p class="spotlight-item__header">Most bingeable shows, best Netflix series, fave talk-show host and more inquiries
#       </p></div>
# </a>
# </li>
# <li class="spotlight-item homepage-spotlight__item spotlight-item--mobile module-1x4__item">
# <a class="spotlight-item__link" href="https://editorial.rottentomatoes.com/article/rotten-tomatoes-is-wrong-about-spider-man-3/">
# <div class="spotlight-item__image js-lazyLoad" data-bg-image="true" data-src="https://resizing.flixster.com/pMDgT7BLrphQDTvaSq4AgN-USJI=/1100x610/v1.czsxMDI4MjkxMztqOzE4NjE0OzEyMDA7NTUwOzMxMA" role="img"></div>
# <div class="spotlight-item__header-sub-header-container">
# <h3 class="spotlight-item__sub-header">Raimi's <em>Spidey 3</em>: Under-appreciated gem or bloated mess? </h3>
# <p class="spotlight-item__header">The first episode of our brand-new podcast has arrived: Listen now!
#       </p></div>
# </a>
# </li>
# </ul>
# </div>
# <div class="home__view-all-group">
# <a href="https://editorial.rottentomatoes.com/">View All</a>
# </div>
# </div>
# </section>
# </section>
# <section id="media-lists">
# <div class="ordered-layout__list ordered-layout__list--carousel">
# <section class="dynamic-poster-list" id="dynamic-poster-list">
# <div class="dynamic-poster-list__header-container--hide-h3">
# <div>
# <h2>New &amp; Upcoming Movies</h2>
# <a class="a--short" href="https://www.rottentomatoes.com/browse/dvd-streaming-upcoming">View all</a>
# </div>
# </div>
# <tiles-carousel hidden="">
# <div class="posters-container" slot="posters-container">
# <tile-poster-video videoid="D414D8FC-57F4-4BEE-BE06-07E0BAEEC597">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the
\u002F","critics":"\u002Fcritics","moviesInTheaters":{"openingThisWeek":"\u002Fbrowse\u002Fopening\u002F","topBoxOffice":"\u002Fbrowse\u002Fin-theaters\u002F","comingSoon":"\u002Fbrowse\u002Fupcoming\u002F","weekendEarnings":"\u002Fbrowse\u002Fbox-office\u002F","certifiedFresh":"\u002Fbrowse\u002Fcf-in-theaters\u002F"},"dvd":"\u002Fdvd","onDvdAndStreaming":{"all":"\u002Fbrowse\u002Fdvd-streaming-all\u002F","top":"\u002Fbrowse\u002Ftop-dvd-streaming\u002F","new":"\u002Fbrowse\u002Fdvd-streaming-new\u002F","upcoming":"\u002Fbrowse\u002Fdvd-streaming-upcoming\u002F","certifiedFresh":"\u002Fbrowse\u002Fcf-dvd-streaming-all\u002F"},"moreMovies":{"topMovies":"\u002Ftop","trailers":"\u002Ftrailers"},"tvTonight":"\u002Fbrowse\u002Ftv-list-1","tvPopular":"\u002Fbrowse\u002Ftv-list-2","moreTv":{"topTv":"https:\u002F\u002Fwww.rottentomatoes.com\u002Ftop-tv","certifiedFresh":"\u002Fbrowse\u002Ftv-list-3"},"editorial":{"allTimeLists":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fall-time-lists\u002F","bingeGuide":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fbinge-guide\u002F","comicsOnTv":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fcomics-on-tv\u002F","countdown":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fcountdown\u002F","criticsConsensus":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fcritics-consensus\u002F","fiveFavoriteFilms":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Ffive-favorite-films\u002F","guidesHome":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-hubs\u002F","home":"https:\u002F\u002Feditorial.rottentomatoes.com\u002F","news":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fnews\u002F","nowStreaming":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fnow-streaming\u002F","parentalGuidance":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fparental-guidance\u002F","podcast":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-podcast\u002F","redCarpetRoundup":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fred-carpet-roundup\u002F","scorecards":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fmovie-tv-scorecards\u002F","subCult":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fsub-cult\u002F","theZeros":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fthe-zeros\u002F","totalRecall":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Ftotal-recall\u002F","twentyFourFrames":"https:\u002F\u002Feditorial.rottentomatoes.com\u002F24-frames\u002F","videoInterviews":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fvideo-interviews\u002F","weekendBoxOffice":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fweekend-box-office\u002F","weeklyKetchup":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fweekly-ketchup\u002F","whatToWatch":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fw ...
# root.BK = {"PageName":"http:\u002F\u002Fwww.rottentomatoes.com\u002F","SiteID":37528,"SiteSection":""};
# root.RottenTomatoes.thirdParty = {"chartBeat":{"auth":"64558","domain":"rottentomatoes.com"},"facebook":{"appId":"326803741017","version":"v6.0","appName":"flixstertomatoes"},"googleReCaptcha":"6Lcobh0TAAAAAN1K9rWeJ8xgl8uYkASWSDLBuKU1","mpx":{"accountPid":"NGweTC","playerPid":"y__7B0iQTi4P","accountId":"2474312077"},"algoliaSearch":{"aId":"79FRDP12PN","sId":"175588f6e5f8319b27702e4cc4013561"},"cognito":{"upId":"us-west-2_EzOtWn0cs","clientId":"omco3pjcakqgrjn2o257hu9r5"}};
# root.RottenTomatoes.serviceWorker = {"isServiceWokerOn":true};
# root.RottenTomatoes.dtmData = {"webVersion":"node","clicktale":true,"rtVersion":3.1,"loggedInStatus":"","customerId":"","pageName":"rt | homepage"};
# root.RottenTomatoes.context.useCognito = false;
# root.RottenTomatoes.context.disableFeatureDetection = false;
# root.RottenTomatoes.context.layout = {"name":"mptd"};
# root.RottenTomatoes.context.shell = {"header":{"legacyItems":{"trending":{"promoItems":[{"noFollow":false,"link":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Farticle\u
js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/micromodal.a54f392f0f5.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/templates.b028a51874d.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/default.94aba9dee2d.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/algoliasearch@4/dist/algoliasearch-lite.umd.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/search-algolia.cfd2415e2cc.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/blueKai.93fda013f61.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/roma/chartbeat.692f1df566a.js"></script>
# <script src="//player.theplatform.com/pdk/dCK2IC/tpPdkController.js?pdk=5.9.6"></script>
# <script src="/assets/pizza-pie/javascripts/roma/bundles/vendor.22447d94895.js"></script>
# <script src="/assets/pizza-pie/javascripts/roma/bundles/home.12537eac0cd.js"></script>
# <script>
#                 if (window.mps && typeof window.mps.writeFooter === 'function') {
#                     window.mps.writeFooter();
#                 }
#             </script>
# <script>
#             window._satellite && _satellite.pageBottom();
#         </script>
# </body>
# </html>
# >

# %% [markdown]
# <a id='#bs4_parse'></a>
#
# #### Beautiful Soup Parsing Methods
#
# The beauty of Beautiful Soup (pun intended) is in the robust, flexible parsing methods. Some of the ones that I have found the most useful are the following (which we will use to parse this webpage):
#
# * **find_all( )** : the 'find_all()' method is one of the most popular and userful methods of Beautiful Soup. We can pass tags to this method and it will search **DOWN** the tree to return all HTML tags of this type that it finds on the page. <br>
# * **find( )** : the 'find()' method is like the 'find_all()' method, except that it returns only the first occurence of the tag that is passed in as a parameter by searching **DOWN** the tree
#
# (Both **find( )** and **find_all( )** search the descendants of the tree, and most other methods of Beautiful Soup are derivations of these two. We'll touch on a couple others)
#
# * **find_parents( )** : the 'find_parents()' method searches **UP** the tree to find all matching HTML tags, as opposed to **find_all( )** which searches down the tree. <br>
# * **find_parent( )** : the 'find_parent( )' method is like the 'find( )' method, except that it returns only the first occurence of the tag that is found looking **UP** the HTML tree
#
# * **find_next_siblings( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find all matching HTML tags that are siblings in the tree <br>
# * **find_next_sibling( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find the next matching HTML tags that are siblings in the tree <br>
#
# To see a full list of the methods available for parsing HTML trees in Beatiful Soup, visit the documentation page at
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find

# %%
#As we examine our HTML doc, we see that all the information we need are nested in 'div' tags that have 'ordered-layout__list ordered-layout__list--carousel' 
#as an element of the 'class' tag. 

#To capture these tags, we pass a 'div' tag and also a 'class' tag as parameters to our 'find_all()' method. If we 
#have a value that we are looking to capture in our tags, we can pass it in as a 'dict' parameter. 
#In this instance we use Regular Expressions to capture all the 'id' tags that have the word 'homepage' in the string.

categories = soup.find_all('div', {'class': re.compile('ordered-layout__list ordered-layout__list--carousel')})

# %%
#Let's now examine the 'categories' object to see what has been stored there
print("Let's look at the length of the 'categories object")
print('Length: ', len(categories), '\n')
print("Now let's examine the first object to see what we need to pull")
print(categories[1].prettify)
# Out:
# Let's look at the length of the 'categories object
data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/EB9ARdcVlemfv9FD3wGP9YPTJP8=/180x257/v2/https://resizing.flixster.com/bellMrIotmrBqm0vybwEtWqlSPA=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzM4YWUzNjIwLTQ1NTYtNGQyMS04MTI1LTdmYWFjYTI3NTY2Yi5wbmc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/alone_2020_2" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="94" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">Alone</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="FE899A19-B5D8-43A3-9BE1-452E453896D1">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/bill_and_ted_face_the_music" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Bill &amp; Ted Face the Music" data-video-id="FE899A19-B5D8-43A3-9BE1-452E453896D1" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/bOqFU9uTqw-tEC2IWgyP-cj43_M=/180x257/v2/https://flxt.tmsimg.com/assets/p16721950_p_v12_ac.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/bill_and_ted_face_the_music" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="81" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="74" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Bill &amp; Ted Face the Music</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="F840B13B-EE49-4F09-BB9C-73C8630A0E49">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_personal_history_of_david_copperfield" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The Personal History of David Copperfield" data-video-id="F840B13B-EE49-4F09-BB9C-73C8630A0E49" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/xO2ucXjelWeQ28v7vifMFpcuIbc=/180x257/v2/https://flxt.tmsimg.com/assets/p17580578_p_v8_ab.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/the_personal_history_of_david_copperfield" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="93" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="55" size="tiny" slot="audience-score" state="spilled"></score-icon-audience>
# <span class="p--small" slot="title">The Personal History of David Copperfield</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="D10BA9F2-C25B-47FE-B60E-B50842C9DA45">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_secrets_we_keep" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The Secrets We Keep" data-video-id="D10BA9F2-C25B-47FE-B60E-B50842C9DA45" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/5J3aDwFxgMqmrmtd7ulg7j5UN-I=/180x257/v2/https://resizing.flixster.com/Jj96BE017Qj2XZlhBL_GD3-FSKI=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzMxMWQ0ZTNhLTZiOWMtNGYwMy1iN2VkLThkZTM5MGM0ZWEzZC5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/the_secrets_we_keep" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="66" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">The Secrets We Keep</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="91B4FBB7-974F-4420-A6DF-427BFD32A9ED">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_nest_2020" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The Nest" data-video-id="91B4FBB7-974F-4420-A6DF-427BFD32A9ED" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/tvrcGWxGq88kgcvWLCoPH1f8ryk=/180x257/v2/https://resizing.flixster.com/-Gxa3oCfImmvPPtse0Wzx51gxMg=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzI2ZDExYzFmLTY4OTctNDU3MS1hNjRmLTdiZWEyNzg3ZmI3Yi5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/the_nest_2020" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="89" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">The Nest</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# </div>
# <rt-icon hidden="" icon="left-chevron" image="" slot="icon-arrow-left"></rt-icon>
# <rt-icon hidden="" icon="right-chevron" image="" slot="icon-arrow-right"></rt-icon>
# </tiles-carousel>
# </section>
# </div>>

# %% [markdown]
# <a id='#bs4_html'></a>
#
# #### Creating the right HTML objects to parse: Let's grab the headers
#
# We see that the objects we need to pull have an **'h2'** tag which storest the category name on the rottentomatoes website. The first 6 category objects have this **'h2'** tag, while the last 2 do not (we can discard these last two objects).
#
# We can use the **soup_html_object.get_text()** method to extract the text associated with our tags

# %%
#For each object in the 'categories' object, display it and print out the the movie category title.

for category in categories:
    print(category.find('h2').get_text(),'\n')
    # print(category)
    # print("-----------------Next Category Starts----------------- \n\n")
# Out:
# New & Upcoming Movies
#
# Popular in Theaters
#
# New TV This Week
#
# Hidden Gem Movies on Hulu
#
# Best Series on Netflix
#
# Essential Comedies
#
# Hidden Gem Movies on Prime
#
# Certified Fresh Picks

# %% [markdown]
# We see from these nested loops that we have __three__ levels that need to be parsed in this HTML object in order to get the necessary data. The structure looks like this:
#
# - Categories (TOP BOX OFFICE, OPENING THIS WEEK, etc)
#
#     ```<div class="ordered-layout__list ordered-layout__list--carousel">```
#     - Category (NEW & UPCOMING MOVIES)
#
#           <h2>New & Upcoming Movies</h2>
#
#         - Movies (The Devil All the Time)
#
#           ```<score-icon-critic alignment="left" percentage="64" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>```
#
#           ```<span slot="title" class="p--small">The Devil All the Time</span>```
#
# We can take a look at each of these elements and see how we have to parse the nested HTML objects

# %% [markdown]
# First we'll look at a category:

# %%
# Let's look at the category again
categories[1].prettify
# Out:
# <bound method Tag.prettify of <div class="ordered-layout__list ordered-layout__list--carousel">
# <section class="dynamic-poster-list" id="dynamic-poster-list">
# <div class="dynamic-poster-list__header-container">
# <div>
# <h2>Popular in Theaters</h2>
# <a class="a--short" href="/browse/in-theaters/">View all</a>
# </div>
# <h3 class="p">Availability may vary, check your <a href="https://www.rottentomatoes.com/showtimes">local showtimes</a> for details.</h3>
# </div>
# <tiles-carousel hidden="">
# <div class="posters-container" slot="posters-container">
# <tile-poster-video videoid="F68956D2-51DB-456F-8CCD-B0EC9C3D4FFB">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/tenet" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Tenet" data-video-id="F68956D2-51DB-456F-8CCD-B0EC9C3D4FFB" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/MPaNLSH_0mOon0f2oA7SBDw4S_k=/180x257/v2/https://resizing.flixster.com/cjkVrRNy9SYE3PwJ1AYbqSg0sq4=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzliMTVjNTkwLTA1ZTUtNDEyMS04NmNmLTBiMzA2OThhMGY0MC5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/tenet" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="73" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="76" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Tenet</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="E4036FAA-9495-4BA9-85A1-FAFA8F78987E">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_new_mutants" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The New Mutants" data-video-id="E4036FAA-9495-4BA9-85A1-FAFA8F78987E" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/FyE89pK7hUk-8vR0QjkjNNfo9uw=/180x257/v2/https://resizing.flixster.com/vW3ug5-igOxENDGIVc5CFrAzLHA=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzL2RjZTcxN2UzLThmOTYtNDBiYS1hOTNjLTlmYmZlZDM2ODU5Yi5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/the_new_mutants" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="34" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="55" size="tiny" slot="audience-score" state="spilled"></score-icon-audience>
# <span class="p--small" slot="title">The New Mutants</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="0912134E-DCDF-448C-872C-99E7A56B4D04">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/infidel_2020" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Infidel" data-video-id="0912134E-DCDF-448C-872C-99E7A56B4D04" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/BKFAp2GzKg83kUisf2_XolcOTPE=/180x257/v2/https://flxt.tmsimg.com/assets/p18682563_p_v8_aa.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/infidel_2020" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="56" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="89" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Infidel</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="BD924CDB-74DF-460B-B6BF-690B5B57D28C">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/unhinged_2020" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Unhinged" data-video-id="BD924CDB-74DF-460B-B6BF-690B5B57D28C" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/uxJtmTjQFsJMcZ33z7Q7uVHQoq0=/180x257/v2/https://resizing.flixster.com/S_sHWpEHIAu5-ogMx2sY4ZLBU68=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzQ0ZDA5N2QyLTIzNjItNDZhNy05ZTM0LWU3MmFkMzFjZjhjYi5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/unhinged_2020" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="47" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="76" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Unhinged</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid
span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# </div>
# <rt-icon hidden="" icon="left-chevron" image="" slot="icon-arrow-left"></rt-icon>
# <rt-icon hidden="" icon="right-chevron" image="" slot="icon-arrow-right"></rt-icon>
# </tiles-carousel>
# </section>
# </div>>

# %% [markdown]
# Now let's see what one movie looks like when we grab the relevant tags

# %%
print('The name of the movie is: ', categories[0].find_all('span', {'class': 'p--small'})[0].get_text())
print('The critics score is: ', categories[0].find_all('score-icon-critic')[0].get('percentage'))
print('The average audience score is: ', categories[0].find_all('score-icon-audience')[0].get('percentage'))
# Out:
# The name of the movie is:  The Devil All the Time
# The critics score is:  64
# The average audience score is:  83

# %% [markdown]
# #### Examine Categories
#
# As we examine each object in each of the **categories** object, we see that the nested objects do not give us individual movies with the associated data. In order to grab this in a clear hierarchal fashion, we'll need to create the objects using the **find( )** and **find_all( )** methodology.

# %%
for category in categories:
    print('THIS IS CATEGORY: ', category.find('h2').get_text(), '\n\n')
    for movie in category.find_all('tile-poster-video'):
        print(movie)
# Out:
# THIS IS CATEGORY:  New & Upcoming Movies
#
#
# <tile-poster-video videoid="D414D8FC-57F4-4BEE-BE06-07E0BAEEC597">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_devil_all_the_time" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The Devil All the Time" data-video-id="D414D8FC-57F4-4BEE-BE06-07E0BAEEC597" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/cjybVUh-ZFidwdU5FxS6xe4FwpY=/180x257/v2/https://resizing.flixster.com/aAnDGC9xqq_cNk-LDPJf1VwZdEk=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzEzN2ZhN2M3LWEwM2UtNDdmZi1hZjNkLWE2ODIxNjlkODk1OC5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/the_devil_all_the_time" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="64" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="83" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">The Devil All the Time</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="E983A755-7CD2-4F7B-840E-791DD14906C5">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/antebellum" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Antebellum" data-video-id="E983A755-7CD2-4F7B-840E-791DD14906C5" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/Ajcy-i40jcIXrL7yWNywDUN5cO0=/180x257/v2/https://flxt.tmsimg.com/assets/p17661976_p_v8_ab.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/antebellum" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="27" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="64" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Antebellum</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="44C59816-1952-4E8E-B85A-A565D2669B26">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/enola_holmes" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Enola Holmes" data-video-id="44C59816-1952-4E8E-B85A-A565D2669B26" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/C4VmJfv_eJaUWjIOlrnTyrtFCIY=/180x257/v2/https://resizing.flixster.com/UmXy3z2xOr4Ps2IaTS9iN3rWZGo=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzI5YjVmYmM2LWMxZWQtNDBkMC1hMmNiLTkwZGMxYTkwYmVhMS5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/enola_holmes" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="88" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">Enola Holmes</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="A3A413C8-1EBB-472C-B82C-13C45C336FC1">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/misbehaviour" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Misbehaviour" data-video-id="A3A413C8-1EBB-472C-B82C-13C45C336FC1" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/V69NMkDKBUGaAgoGfjPmCpZVyCM=/180x257/v2/https://flxt.tmsimg.com/assets/p17814124_p_v8_aa.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/misbehaviour" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="89" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">Misbehaviour</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="F975882B-C17E-46A1-8C3C-19788268F387">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/kajillionaire" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Kajillionaire" data-video-id="F975882B-C17E-46A1-8C3C-19788268F387" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/hTYf7mWpwigx7JNKbd9wx4vB2bo=/180x257/v2/https://resizing.flixster.com/qc9wAfsEXnAbJZNAI1lbR84nyJM=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzLzRiZjViYTViLWFjYzAtNDNiMy05MDcwLTMyODhjYWM3ODU4ZS5qcGc=" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/kajillionaire" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="93" size="tiny" slot="critic-score" state="fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="" size="tiny" slot="audience-score" state="audience-empty"></score-icon-audience>
# <span class="p--small" slot="title">Kajillionaire</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="DE9D7CCE-435A-482A-841D-EEC23C39B012">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_trial_of_the_chicago_7" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The Trial of the Chicago 7" data-video-id="DE9D7CCE-435A-482A-841D-EEC23C39B012" data-video-list="rt-hp-list-posters-coming-soon" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com
data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Bone Tomahawk" data-video-id="45A06774-E2DB-9CB5-282B-394C63A9C01C" data-video-list="rt-hp-list-posters-streaming-service-4" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/yzarn5bDNxOvWokQ9yI0E2XFc3k=/180x257/v2/https://flxt.tmsimg.com/assets/p11992120_p_v8_aa.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/bone_tomahawk" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="90" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="73" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Bone Tomahawk</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="C8A9FF01-403A-4659-94E2-21232E8F0246">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/destination_wedding" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Destination Wedding" data-video-id="C8A9FF01-403A-4659-94E2-21232E8F0246" data-video-list="rt-hp-list-posters-streaming-service-4" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/iAmP7ZHk0UXwEyZ_afKzlxj32uo=/180x257/v2/https://flxt.tmsimg.com/assets/p15530320_p_v8_aa.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/destination_wedding" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="51" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="58" size="tiny" slot="audience-score" state="spilled"></score-icon-audience>
# <span class="p--small" slot="title">Destination Wedding</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# <tile-poster-video videoid="0C0ADDB8-26E1-450B-8BF3-6D5178A8D395">
# <button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/anna_and_the_apocalypse" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="Anna and the Apocalypse" data-video-id="0C0ADDB8-26E1-450B-8BF3-6D5178A8D395" data-video-list="rt-hp-list-posters-streaming-service-4" slot="play">
# <tile-poster-image isvideovisible="true" slot="image">
# <img class="js-lazyLoad" data-src="https://resizing.flixster.com/LikoK_PsE0wCeeATVHQT7YlJHEI=/180x257/v2/https://flxt.tmsimg.com/assets/p14550906_p_v8_aa.jpg" onerror="this.onerror=null; this.src='/images/poster_default.gif';" slot="poster" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
# <rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>
# </tile-poster-image>
# </button>
# <a class="unset" href="/m/anna_and_the_apocalypse" slot="link">
# <tile-poster-meta>
# <score-icon-critic alignment="left" percentage="77" size="tiny" slot="critic-score" state="certified_fresh"></score-icon-critic>
# <score-icon-audience alignment="left" percentage="62" size="tiny" slot="audience-score" state="upright"></score-icon-audience>
# <span class="p--small" slot="title">Anna and the Apocalypse</span>
# </tile-poster-meta>
# </a>
# </tile-poster-video>
# THIS IS CATEGORY:  Certified Fresh Picks

# %% [markdown]
# <a id='#bs4_find_html'></a>
#
# #### Now we need to extract the data in these categories
#
# We see that by setting **movies** to **category.find_all('title-poster-video')**, each nested object is a movie with all the necessary data for us to evaluate (title, rating, additional data).

# %%
_dict={}
for category in categories:
    #print(category.find_all('a', {'class': 'unset'}),'\n')
    for movie in category.find_all('tile-poster-video'):
        print('Category: ', category.find('h2').get_text())
        print('Movie: ', movie.find('span', {'class': 'p--small'}).get_text())
        print('Critics Rating: ', movie.find('score-icon-critic').get('percentage'))
        print('****Next Movie****\n')
# Out:
# Category:  New & Upcoming Movies
# Movie:  The Devil All the Time
# Critics Rating:  64
# ****Next Movie****
#
# Category:  New & Upcoming Movies
# Movie:  Antebellum
# Critics Rating:  27
# ****Next Movie****
#
# Category:  New & Upcoming Movies
# Movie:  Enola Holmes
# Critics Rating:  88
# ****Next Movie****
#
# Category:  New & Upcoming Movies
# Movie:  Misbehaviour
# Critics Rating:  89
# ****Next Movie****
#
# Category:  New & Upcoming Movies
# Movie:  Kajillionaire
# Critics Rating:  93
# ****Next Movie****
#
# Category:  New & Upcoming Movies
# Movie:  The Trial of the Chicago 7
# ****Next Movie****
#
# Category:  Hidden Gem Movies on Prime
# Movie:  Bone Tomahawk
# Critics Rating:  90
# ****Next Movie****
#
# Category:  Hidden Gem Movies on Prime
# Movie:  Destination Wedding
# Critics Rating:  51
# ****Next Movie****
#
# Category:  Hidden Gem Movies on Prime
# Movie:  Anna and the Apocalypse
# Critics Rating:  77
# ****Next Movie****

# %% [markdown]
# <a id='#pulling_tags'></a>
#
# #### Pulling the Relevant Tags
#
# Now that we see how to create the right HTML objects, we can go in and use the **find( )** method to extract the relevant data.
#
# We can find the data by parsing the appropriate tags:
#
# **Movie Title:**
#
# `<span slot="title" class="p--small">The New Mutants</span>` <br>
#
# **Audience Score:**
#
# `<score-icon-audience alignment="left" percentage="55" size="tiny" slot="audience-score" state="spilled" style="display: none;"></score-icon-audience>` <br>
#
# **Critics Score:**
#
# `<score-icon-critic alignment="left" percentage="34" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>`
#
# #### All of these are pieces of this **movie** HTML object:
#
# **Entire Movie Object**
#
# `<tile-poster-video videoid="E4036FAA-9495-4BA9-85A1-FAFA8F78987E">`
# `<button class="js-show-modal-trailer" data-content-type="movie" data-media-url="/m/the_new_mutants" data-mpx-fwsite="rotten_tomatoes_video_vod" data-no-ads="false" data-title="The New Mutants" data-video-id="E4036FAA-9495-4BA9-85A1-FAFA8F78987E" data-video-list="rt-hp-list-posters-popular-in-theaters" slot="play">`
# `<tile-poster-image isvideovisible="true" slot="image">`
#
# `<img slot="poster" data-src="https://resizing.flixster.com/FyE89pK7hUk-8vR0QjkjNNfo9uw=/180x257/v2/https://resizing.flixster.com/vW3ug5-igOxENDGIVc5CFrAzLHA=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzL2RjZTcxN2UzLThmOTYtNDBiYS1hOTNjLTlmYmZlZDM2ODU5Yi5qcGc=" src="https://resizing.flixster.com/FyE89pK7hUk-8vR0QjkjNNfo9uw=/180x257/v2/https://resizing.flixster.com/vW3ug5-igOxENDGIVc5CFrAzLHA=/ems.ZW1zLXByZC1hc3NldHMvbW92aWVzL2RjZTcxN2UzLThmOTYtNDBiYS1hOTNjLTlmYmZlZDM2ODU5Yi5qcGc=" class="js-lazyLoad" onerror="this.onerror=null; this.src='/images/poster_default.gif';" data-revealed="true" style=" -webkit-animation: overlay-fade 1s 1; -o-animation: overlay-fade 1s 1; animation: overlay-fade 1s 1;">`
#
#
# `<rt-icon-cta-video slot="icon-play"></rt-icon-cta-video>`
# `</tile-poster-image>`
# `</button>`
# `<a href="/m/the_new_mutants" class="unset" slot="link">`
# `<tile-poster-meta>`
# `<score-icon-critic alignment="left" percentage="34" size="tiny" slot="critic-score" state="rotten"></score-icon-critic>`
# `<score-icon-audience alignment="left" percentage="55" size="tiny" slot="audience-score" state="spilled"` `style="display: none;"></score-icon-audience>`
# `<span slot="title" class="p--small">The New Mutants</span>`
# `</tile-poster-meta>`
# `</a>`
# `</tile-poster-video>`

# %% [markdown]
# #### Pull the relevant data into a dictionary object and export to CSV

# %%
movie_data={}
for category in categories:
    #print(category.find_all('a', {'class': 'unset'}),'\n')
    for movie in category.find_all('tile-poster-video'):
        movie_data[movie.find('span', {'class': 'p--small'}).get_text()]={'category': category.find('h2').get_text(),
                                                                    'critics_rating': movie.find('score-icon-critic').get('percentage'),
                                                                    'audience_rating': movie.find('score-icon-audience').get('percentage')}
print(json.dumps(movie_data, sort_keys=True, indent=4))
# Out:
# {
#     "21 Jump Street": {
#         "audience_rating": "82",
#         "category": "Essential Comedies",
#         "critics_rating": "84"
#     },
#     "Airplane!": {
#         "audience_rating": "89",
#         "category": "Essential Comedies",
#         "critics_rating": "97"
#     },
#     "Alone": {
#         "audience_rating": "",
#         "category": "Popular in Theaters",
#         "critics_rating": "94"
#     },
#     "Anna and the Apocalypse": {
#         "audience_rating": "62",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "77"
#     },
#     "Antebellum": {
#         "audience_rating": "64",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "27"
#     },
#     "BPM (Beats Per Minute)": {
#         "audience_rating": "83",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "98"
#     },
#     "Bill & Ted Face the Music": {
#         "audience_rating": "74",
#         "category": "Popular in Theaters",
#         "critics_rating": "81"
#     },
#     "Bone Tomahawk": {
#         "audience_rating": "73",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "90"
#     },
#     "Booksmart": {
#         "audience_rating": "77",
#         "category": "Essential Comedies",
#         "critics_rating": "96"
#     },
#     "Buried": {
#         "audience_rating": "65",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "87"
#     },
#     "Charm City Kings": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "88"
#     },
#     "Coming to America": {
#         "audience_rating": "85",
#         "category": "Essential Comedies",
#         "critics_rating": "65"
#     },
#     "Crazy Rich Asians": {
#         "audience_rating": "76",
#         "category": "Essential Comedies",
#         "critics_rating": "91"
#     },
#     "Destination Wedding": {
#         "audience_rating": "58",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "51"
#     },
#     "Enola Holmes": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "88"
#     },
#     "Fast Color": {
#         "audience_rating": "63",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "81"
#     },
#     "Infidel": {
#         "audience_rating": "89",
#         "category": "Popular in Theaters",
#         "critics_rating": "56"
#     },
#     "Kajillionaire": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "93"
#     },
#     "Love & Mercy": {
#         "audience_rating": "85",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "89"
#     },
#     "Misbehaviour": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "89"
#     },
#     "Monsters and Men": {
#         "audience_rating": "74",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "84"
#     },
#     "Roman Holiday": {
#         "audience_rating": "93",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "97"
#     },
#     "Seven Psychopaths": {
#         "audience_rating": "71",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "83"
#     },
#     "Shoplifters": {
#         "audience_rating": "91",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "99"
#     },
#     "Spy": {
#         "audience_rating": "78",
#         "category": "Essential Comedies",
#         "critics_rating": "95"
#     },
#     "Step Brothers": {
#         "audience_rating": "69",
#         "category": "Essential Comedies",
#         "critics_rating": "55"
#     },
#     "Tenet": {
#         "audience_rating": "76",
#         "category": "Popular in Theaters",
#         "critics_rating": "73"
#     },
#     "The Big Lebowski": {
#         "audience_rating": "93",
#         "category": "Essential Comedies",
#         "critics_rating": "83"
#     },
#     "The Boys in the Band": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": ""
#     },
#     "The Broken Hearts Gallery": {
#         "audience_rating": "89",
#         "category": "Popular in Theaters",
#         "critics_rating": "76"
#     },
#     "The Devil All the Time": {
#         "audience_rating": "83",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "64"
#     },
#     "The Glorias": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "73"
#     },
#     "The Handmaiden": {
#         "audience_rating": "91",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "95"
#     },
#     "The Nest": {
#         "audience_rating": "",
#         "category": "Popular in Theaters",
#         "critics_rating": "89"
#     },
#     "The New Mutants": {
#         "audience_rating": "55",
#         "category": "Popular in Theaters",
#         "critics_rating": "34"
#     },
#     "The Overnight": {
#         "audience_rating": "54",
#         "category": "Hidden Gem Movies on Prime",
#         "critics_rating": "83"
#     },
#     "The Personal History of David Copperfield": {
#         "audience_rating": "55",
#         "category": "Popular in Theaters",
#         "critics_rating": "93"
#     },
#     "The School of Rock": {
#         "audience_rating": "64",
#         "category": "Essential Comedies",
#         "critics_rating": "91"
#     },
#     "The Secrets We Keep": {
#         "audience_rating": "",
#         "category": "Popular in Theaters",
#         "critics_rating": "66"
#     },
#     "The Swerve": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": "100"
#     },
#     "The Trial of the Chicago 7": {
#         "audience_rating": "",
#         "category": "New & Upcoming Movies",
#         "critics_rating": ""
#     },
#     "Unhinged": {
#         "audience_rating": "76",
#         "category": "Popular in Theaters",
#         "critics_rating": "47"
#     },
#     "Wild Rose": {
#         "audience_rating": "87",
#         "category": "Hidden Gem Movies on Hulu",
#         "critics_rating": "92"
#     }
# }

# %% [markdown]
# <a id='#storing_data'></a>
#
# #### Storing Data and Exporting to CSV
#
# Now that we know we have the relevant data, we can store our data in a **dict** object and export that data to a **CSV** file via our **Pandas** dataframe.

# %%
#Store dict object in pandas dataframe
df = pd.DataFrame.from_dict(movie_data, orient = 'index')
#Export pandas dataframe to CSV
df.to_csv('rottentomatoes.csv')

# %% [markdown]
# #### Homework Question:
#
# There are two sections on the webpage, **POPULAR STREAMING MOVIES** and **MOST POPULAR TV ON RT**. How would we go about parsing this data and exporting to CSV?

# %% [markdown]
# #### Thank You!
#
# Thank you for working through this tutorial. Please feel free to respond with questions/comments, and let me know how this tutorial can be improved.
