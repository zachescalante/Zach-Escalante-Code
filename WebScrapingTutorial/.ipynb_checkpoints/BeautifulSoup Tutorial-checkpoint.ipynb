# %% [markdown]
# # BeautifulSoup Webscraping Tutorial
#
# #### Table of Contents
#
# 1. <a href='##Introduction'>The Basics of Webscraping With BeautifulSoup</a> <br>
# > 1.a <a href='##urllib'>The urllib package</a> <br>
# > 1.b <a href='##beautiful_soup'>The Beautiful Soup package</a> <br>
# 2. <a href='##example'>Webscrapig Example</a> <br>
# > 2.a <a href='##packages'>Necessary Packages</a> <br>
# > 2.b <a href='##urllib_example'>urllib to grab the website</a> <br>
# > 2.c <a href='##bs4_object'>Create a bs4 object</a> <br>
# 3. <a href='##bs4_parse'>Parsing a Beautiful Soup Object</a> <br>
# > 3.a <a href='##bs4_html'>Creating the right HTML objects to parse</a> <br>
# > 3.b <a href='##bs4_find_html'>Creating nested HTML objects using **find( ) and **find_all( ) methodology</a> <br>
# > 3.c <a href='##pulling_tags'>Parsing the individual movies and pulling the data</a> <br>
# > 3.d <a href='##storing_data'>Storing the data and exporting to CSV</a> <br>

# %% [markdown]
# <a id='#Introduction'></a>
#
# ### The Basics of Webscraping with BeautifulSoup
#
# Beautiful Soup is a lightweight, flexible Python library designed for parsing HTML documents. It provides many great features, such as HTML tree traversal and automatic encoding (incoming documents to Unicode and outgoing documents to UTF-8) (1) which enable the user to focus solely on parsing documents and extracting information. Beautiful Soup itself does not collect webpages - this is left to the urllib package in Python which we'll discuss next. Instead Beauful Soup parses the HTML code, meaning that Beautiful Soup and urllib work hand-in hand.
#
# We'll be working in Python 3 for this tutorial, although Beautiful Soup runs for Python 2 with some simple adjustments to your code. Let's take a look at an example and see if we can get you up and running with parsing your own web pages!
#
# (1) https://www.crummy.com/software/BeautifulSoup/

# %% [markdown]
# <a id='#urllib'></a>
#
# #### The urllib package
#
# The urllib package enables you to access websites via your Python console. With just a few lines of code you can write a program for grabbing objects and saving data from webpages. What's also great about urllib is that it is part of the standard Python libary - so it rarely ever needs to be installed (you already have it upon installing any version of Python). Below are some links to urllib documentation and simple example code:
#
# **Tutorial**:    https://pythonprogramming.net/urllib-tutorial-python-3/ <br>
# **Documentation**: https://docs.python.org/3/library/urllib.html

# %% [markdown]
# <a id='#beautiful_soup'></a>
#
# #### The Beautiful Soup Package
#
# Once we've used urllib to grab an HTML document, then we can deploy Beautiful Soup. Beautiful Soup has built in methods to parse the HTML tree, grab tags and encode incoming/outgoing documents. There have been several iterations of the Beautiful Soup package, the latest of which is **bs4** for Python 3. Below are some relevant links for installing and reading about Beautiful Soup:
#
# **Documentation**: https://www.crummy.com/software/BeautifulSoup/bs4/doc/ <br>
# **Installation**: http://www.pythonforbeginners.com/beautifulsoup/beautifulsoup-4-python

# %% [markdown]
# <a id='#example'></a>
#
# #### Let's start a webscraping example
#
# The first thing we need to do is import the relevant packages for our project. These packages are the following: <br>
# * **re** - the regular expressions package for evaluating strings <br>
# * **pandas** - this is a fundamental package for formatting and evaluating data <br>
# * **urllib.request** - HTML reqeusts are handled by the '.request' method in the urllib package <br>
# * **bs4** - we will create an object for parsing using the Beautiful Soup method of the bs4 package <br>

# %% [markdown]
# <a id='#packages'></a>

# %%
import re
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# <a id='#urllib_example'></a>
#
# #### Use urllib to grab the website object

# %%
#Declare the website as a string. For this example, I've decided to grab the data from rottentomatoes website, parse
#the html and save it in a pandas dataframe which we can export to a csv file.
webpage = 'https://www.rottentomatoes.com/'

#Use the 'with-as' method to open the webpage and create an object of the html source code
with urllib.request.urlopen(webpage) as response:
   html = response.read()

# %% [markdown]
# <a id='#bs4_object'></a>
#
# #### Create a Beautiful Soup object
#
# We do this by passing the **html** object to the Beautiful Soup method

# %%
soup = BeautifulSoup(html)
# Out:
# /Users/zacharyescalante/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/zacharyescalante/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# **soup.prettify** displays all the HTML syntax just as it appears on the webpage we took it from. This helps us to determine how to properly search for tags as we parse our tree.

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dit="ltr" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
# <!-- salt=lay-def-02-juRm -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews - Rotten Tomatoes</title>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="description"/>
# <link href="https://www.rottentomatoes.com/" rel="canonical"/>
# <link href="/assets/pizza-pie/images/favicon.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
# <meta content="326803741017" property="fb:app_id"/>
# <meta content="Rotten Tomatoes" property="og:site_name"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" property="og:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.rottentomatoes.com/" property="og:url"/>
# <meta content="/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" property="og:image"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="//twitter.com/rottentomatoes" name="twitter:url"/>
# <meta content="/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" name="twitter:image"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:title"/>
# <meta content="Rotten Tomatoes: Movies | TV Shows | Movie Trailers | Reviews" name="twitter:text:title"/>
# <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="twitter:description"/>
# <meta content="@rottentomatoes" name="twitter:site"/>
# <link href="/assets/pizza-pie/manifest/manifest.json" rel="manifest"/>
# <link href="/assets/pizza-pie/head-assets/images/apple-touch-icon-60.jpg" rel="apple-touch-icon"/>
# <link href="/assets/pizza-pie/head-assets/images/apple-touch-icon-152.jpg" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/assets/pizza-pie/head-assets/images/apple-touch-icon-167.jpg" rel="apple-touch-icon" sizes="167x167"/>
# <link href="/assets/pizza-pie/head-assets/images/apple-touch-icon-180.jpg" rel="apple-touch-icon" sizes="180x180"/>
# <!-- JSON+LD -->
# <!-- Google webmaster tools -->
# <meta content="VPPXtECgUUeuATBacnqnCm4ydGO99reF-xgNklSbNbc" name="google-site-verification"/>
# <!-- Bing webmaster tools -->
# <meta content="034F16304017CA7DCF45D43850915323" name="msvalidate.01"/>
# <meta content="#FA320A" name="theme-color"/>
# <!-- DNS prefetch -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//www.rottentomatoes.com" rel="dns-prefetch"/>
# <link href="//www.rottentomatoes.com" rel="preconnect"/>
# <link as="style" href="/assets/pizza-pie/stylesheets/bundles/global.af1f12e68aa.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <style id="critical-path">html {
#   font-family: sans-serif;
#   /* 1 */
#   -ms-text-size-adjust: 100%;
#   /* 2 */
#   -webkit-text-size-adjust: 100%;
#   /* 2 */
# }
#
# body {
#   margin: 0;
# }
#
# aside,
# footer,
# nav,
# section {
#   display: block;
# }
#
# a {
#   background-color: transparent;
# }
#
# h1 {
#   font-size: 2em;
#   margin: 0.67em 0;
# }
#
# small {
#   font-size: 80%;
# }
#
# img {
#   border: 0;
# }
#
# svg:not(:root) {
#   overflow: hidden;
# }
#
# button,
# input {
#   color: inherit;
#   /* 1 */
#   font: inherit;
#   /* 2 */
#   margin: 0;
#   /* 3 */
# }
#
# button {
#   overflow: visible;
# }
#
# button {
#   text-transform: none;
# }
#
# button {
#   -webkit-appearance: button;
#   /* 2 */
#   /* 3 */
# }
#
# button::-moz-focus-inner,
# input::-moz-focus-inner {
#   border: 0;
#   padding: 0;
# }
#
# input {
#   line-height: normal;
# }
#
# table {
#   border-collapse: collapse;
#   border-spacing: 0;
# }
#
# td {
#   padding: 0;
# }
#
# .glyphicon {
#   position: relative;
#   top: 1px;
#   display: inline-block;
#   font-family: 'Glyphicons Halflings';
#   font-style: normal;
#   font-weight: normal;
#   line-height: 1;
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
#
# .glyphicon-search:before {
#   content: "\e003";
# }
#
# .glyphicon-remove:before {
#   content: "\e014";
# }
#
# .glyphicon-chevron-left:before {
#   content: "\e079";
# }
#
# .glyphicon-chevron-right:before {
#   content: "\e080";
# }
#
# .glyphicon-remove-circle:before {
#   content: "\e088";
# }
#
# .container {
#   margin-right: auto;
#   margin-left: auto;
# }
#
# .container:before,
# .container:after {
#   content: " ";
#   display: table;
# }
#
# .container:after {
#   clear: both;
# }
#
# .row {
#   margin-left: -10px;
#   margin-right: -10px;
# }
#
# .row:before,
# .row:after {
#   content: " ";
#   display: table;
# }
#
# .row:after {
#   clear: both;
# }
#
# .col-xs-3,
# .col-xs-4,
# .col-xs-5,
# .col-xs-6,
# .col-sm-6,
# .col-xs-7,
# .col-sm-7,
# .col-xs-11,
# .col-sm-11,
# .col-xs-12,
# .col-sm-12,
# .col-sm-13,
# .col-sm-17,
# .col-sm-18,
# .col-xs-24 {
#   position: relative;
#   min-height: 1px;
#   padding-left: 10px;
#   padding-right: 10px;
# }
#
# .col-xs-3,
# .col-xs-4,
# .col-xs-5,
# .col-xs-6,
# .col-xs-7,
# .col-xs-11,
# .col-xs-12,
# .col-xs-24 {
#   float: left;
# }
#
# .col-xs-3 {
#   width: 12.5%;
# }
#
# .col-xs-4 {
#   width: 16.66667%;
# }
#
# .col-xs-5 {
#   width: 20.83333%;
# }
#
# .col-xs-6 {
#   width: 25%;
# }
#
# .col-xs-7 {
#   width: 29.16667%;
# }
#
# .col-xs-11 {
#   width: 45.83333%;
# }
#
# .col-xs-12 {
#   width: 50%;
# }
#
# .col-xs-24 {
#   width: 100%;
# }
#
# @media (min-width: 768px) {
#   .col-sm-6,
#   .col-sm-7,
#   .col-sm-11,
#   .col-sm-12,
#   .col-sm-13,
#   .col-sm-17,
#   .col-sm-18 {
#     float: left;
#   }
#
#   .col-sm-6 {
#     width: 25%;
#   }
#
#   .col-sm-7 {
#     width: 29.16667%;
#   }
#
#   .col-sm-11 {
#     width: 45.83333%;
#   }
#
#   .col-sm-12 {
#     width: 50%;
#   }
#
#   .col-sm-13 {
#     width: 54.16667%;
#   }
#
#   .col-sm-17 {
#     width: 70.83333%;
#   }
#
#   .col-sm-18 {
#     width: 75%;
#   }
# }
#
# * {
#   -webkit-box-sizing: border-box;
#   -moz-box-sizing: border-box;
#   box-sizing: border-box;
# }
#
# *:before,
# *:after {
#   -webkit-box-sizing: border-box;
#   -moz-box-sizing: border-box;
#   box-sizing: border-box;
# }
#
# html {
#   font-size: 10px;
# }
#
# body {
#   font-size: 16px;
#   line-height: 1.25;
#   color: #343434;
#   background-color: #fff;
# }
#
# input,
# button {
#   font-family: inherit;
#   font-size: inherit;
#   line-height: inherit;
# }
#
# a {
#   color: #337ab7;
#   text-decoration: none;
# }
#
# img {
#   vertical-align: middle;
# }
#
# .sr-only {
#   position: absolute;
#   width: 1px;
#   height: 1px;
#   margin: -1px;
#   padding: 0;
#   overflow: hidden;
#   clip: rect(0, 0, 0, 0);
#   border: 0;
# }
#
# h1,
# h2,
# h3,
# .h2 {
#   font-family: inherit;
#   font-weight: bold;
#   line-height: 1.1;
#   color: #343434;
# }
#
# h1,
# h2,
# .h2,
# h3 {
#   margin-top: 20px;
#   margin-bottom: 10px;
# }
#
# h1 {
#   font-size: 24px;
# }
#
# h2,
# .h2 {
#   font-size: 18px;
# }
#
# h3 {
#   font-size: 14px;
# }
#
# p {
#   margin: 0 0 10px;
# }
#
# small {
#   font-size: 75%;
# }
#
# .text-center {
#   text-align: center;
# }
#
# ul,
# ol {
#   margin-top: 0;
#   margin-bottom: 10px;
# }
#
# ul ul {
#   margin-bottom: 0;
# }
#
# .list-unstyled {
#   padding-left: 0;
#   list-style: none;
# }
#
# .list-inline {
#   padding-left: 0;
#   list-style: none;
#   margin-left: -5px;
# }
#
# .list-inline>li {
#   display: inline-block;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# table {
#   background-color: transparent;
#   border-collapse: collapse;
# }
#
# label {
#   display: inline-block;
#   max-width: 100%;
#   margin-bottom: 5px;
#   font-weight: bold;
# }
#
# .form-control {
#   display: block;
#   width: 100%;
#   height: 34px;
#   padding: 6px 12px;
#   font-size: 16px;
#   line-height: 1.25;
#   color: #555;
#   background-color: #fff;
#   background-image: none;
#   border: 1px solid #ccc;
#   border-radius: 4px;
#   -webkit-box-shadow: inset 0 1px 1px rgba(0,0,0,0.075);
#   box-shadow: inset 0 1px 1px rgba(0,0,0,0.075);
# }
#
# .form-control::-moz-placeholder {
#   color: #999;
#   opacity: 1;
# }
#
# .form-control:-ms-input-placeholder {
#   color: #999;
# }
#
# .form-control::-webkit-input-placeholder {
#   color: #999;
# }
#
# .form-control::-ms-expand {
#   border: 0;
#   background-color: transparent;
# }
#
# .form-group {
#   margin-bottom: 15px;
# }
#
# .help-block {
#   display: block;
#   margin-top: 5px;
#   margin-bottom: 10px;
#   color: #747474;
# }
#
# .btn {
#   display: inline-block;
#   margin-bottom: 0;
#   font-weight: normal;
#   text-align: center;
#   vertical-align: middle;
#   touch-action: manipulation;
#   background-image: none;
#   border: 1px solid transparent;
#   white-space: nowrap;
#   padding: 6px 12px;
#   font-size: 16px;
#   line-height: 1.25;
#   border-radius: 4px;
# }
#
# .btn.disabled {
#   opacity: .65;
#   filter: alpha(opacity=65);
#   -webkit-box-shadow: none;
#   box-shadow: none;
# }
#
# .btn-default {
#   color: #333;
#   background-color: #fff;
#   border-color: #ccc;
# }
#
# .btn-primary {
#   color: #343434 !important;
#   background-color: #FFE400;
# }
#
# .btn-lg {
#   padding: 10px 16px;
#   font-size: 18px;
#   line-height: 1.33333;
#   border-radius: 6px;
# }
#
# .fade {
#   opacity: 0;
# }
#
# .dropdown {
#   position: relative;
# }
#
# .dropdown-menu {
#   position: absolute;
#   top: 100%;
#   left: 0;
#   z-index: 1000;
#   display: none;
#   float: left;
#   min-width: 160px;
#   padding: 5px 0;
#   margin: 2px 0 0;
#   list-style: none;
#   font-size: 16px;
#   text-align: left;
#   background-color: #fff;
#   border: 1px solid #ccc;
#   border: 1px solid rgba(0,0,0,0.15);
#   border-radius: 5px;
#   -webkit-box-shadow: 0 6px 12px rgba(0,0,0,0.175);
#   box-shadow: 0 6px 12px rgba(0,0,0,0.175);
#   background-clip: padding-box;
# }
#
# .input-group {
#   position: relative;
#   display: table;
#   border-collapse: separate;
# }
#
# .input-group .form-control {
#   position: relative;
#   z-index: 2;
#   float: left;
#   width: 100%;
#   margin-bottom: 0;
# }
#
# .input-group-btn,
# .input-group .form-control {
#   display: table-cell;
# }
#
# .input-group-btn:not(:first-child):not(:last-child) {
#   border-radius: 0;
# }
#
# .input-group-btn {
#   width: 1%;
#   white-space: nowrap;
#   vertical-align: middle;
# }
#
# .input-group .form-control:first-child {
#   border-bottom-right-radius: 0;
#   border-top-right-radius: 0;
# }
#
# .input-group-btn {
#   position: relative;
#   font-size: 0;
#   white-space: nowrap;
# }
#
# .input-group-btn>.btn {
#   position: relative;
# }
#
# .navbar {
#   position: relative;
#   min-height: 50px;
#   margin-bottom: 20px;
#   border: 1px solid transparent;
# }
#
# .navbar:before,
# .navbar:after {
#   content: " ";
#   display: table;
# }
#
# .navbar:after {
#   clear: both;
# }
#
# @media (min-width: 768px) {
#   .navbar {
#     border-radius: 4px;
#   }
# }
#
# .navbar-header:before,
# .navbar-header:after {
#   content: " ";
#   display: table;
# }
#
# .navbar-header:after {
#   clear: both;
# }
#
# @media (min-width: 768px) {
#   .navbar-header {
#     float: left;
#   }
# }
#
# .navbar-brand {
#   float: left;
#   padding: 15px 15px;
#   font-size: 18px;
#   line-height: 20px;
#   height: 50px;
# }
#
# .navbar-nav {
#   margin: 7.5px -15px;
# }
#
# @media (min-width: 768px) {
#   .navbar-nav {
#     float: left;
#     margin: 0;
#   }
# }
#
# .panel-body {
#   padding: 15px;
# }
#
# .panel-body:before,
# .panel-body:after {
#   content: " ";
#   display: table;
# }
#
# .panel-body:after {
#   clear: both;
# }
#
# .panel-heading {
#   border-bottom: 1px solid transparent;
#   border-top-right-radius: 3px;
#   border-top-left-radius: 3px;
# }
#
# .close {
#   float: right;
#   font-size: 24px;
#   font-weight: bold;
#   line-height: 1;
#   color: #000;
#   text-shadow: 0 1px 0 #fff;
#   opacity: .2;
#   filter: alpha(opacity=20);
# }
#
# button.close {
#   padding: 0;
#   background: transparent;
#   border: 0;
#   -webkit-appearance: none;
# }
#
# .modal {
#   display: none;
#   overflow: hidden;
#   position: fixed;
#   top: 0;
#   right: 0;
#   bottom: 0;
#   left: 0;
#   z-index: 1050;
#   -webkit-overflow-scrolling: touch;
#   outline: 0;
# }
#
# .modal.fade .modal-dialog {
#   -webkit-transform: translate(0, -25%);
#   -ms-transform: translate(0, -25%);
#   -o-transform: translate(0, -25%);
#   transform: translate(0, -25%);
# }
#
# .modal.in .modal-dialog {
#   -webkit-transform: translate(0, 0);
#   -ms-transform: translate(0, 0);
#   -o-transform: translate(0, 0);
#   transform: translate(0, 0);
# }
#
# .modal-dialog {
#   position: relative;
#   width: auto;
#   margin: 10px;
# }
#
# .modal-content {
#   position: relative;
#   background-color: #fff;
#   border: 1px solid #999;
#   border: 1px solid rgba(0,0,0,0.2);
#   border-radius: 6px;
#   -webkit-box-shadow: 0 3px 9px rgba(0,0,0,0.5);
#   box-shadow: 0 3px 9px rgba(0,0,0,0.5);
#   background-clip: padding-box;
#   outline: 0;
# }
#
# .modal-header {
#   padding: 15px;
#   border-bottom: 1px solid #e5e5e5;
# }
#
# .modal-header:before,
# .modal-header:after {
#   content: " ";
#   display: table;
# }
#
# .modal-header:after {
#   clear: both;
# }
#
# .modal-header .close {
#   margin-top: -2px;
# }
#
# .modal-title {
#   margin: 0;
#   line-height: 1.42857;
# }
#
# .modal-body {
#   position: relative;
#   padding: 15px;
# }
#
# .modal-footer {
#   padding: 15px;
#   text-align: right;
#   border-top: 1px solid #e5e5e5;
# }
#
# .modal-footer:before,
# .modal-footer:after {
#   content: " ";
#   display: table;
# }
#
# .modal-footer:after {
#   clear: both;
# }
#
# @media (min-width: 768px) {
#   .modal-dialog {
#     width: 600px;
#     margin: 30px auto;
#   }
#
#   .modal-content {
#     -webkit-box-shadow: 0 5px 15px rgba(0,0,0,0.5);
#     box-shadow: 0 5px 15px rgba(0,0,0,0.5);
#   }
#
#   .modal-sm {
#     width: 300px;
#   }
# }
#
# @media (min-width: 992px) {
#   .modal-lg {
#     width: 900px;
#   }
# }
#
# .carousel {
#   position: relative;
# }
#
# .carousel-inner {
#   position: relative;
#   overflow: hidden;
#   width: 100%;
# }
#
# .carousel-control {
#   position: absolute;
#   top: 0;
#   left: 0;
#   bottom: 0;
#   width: 15%;
#   opacity: .5;
#   filter: alpha(opacity=50);
#   font-size: 20px;
#   color: #fff;
#   text-align: center;
#   text-shadow: 0 1px 2px rgba(0,0,0,0.6);
#   background-color: transparent;
# }
#
# .carousel-control.left {
#   background-image: -webkit-linear-gradient(left, rgba(0,0,0,0.5) 0%, rgba(0,0,0,0.0001) 100%);
#   background-image: -o-linear-gradient(left, rgba(0,0,0,0.5) 0%, rgba(0,0,0,0.0001) 100%);
#   background-image: linear-gradient(to right, rgba(0,0,0,0.5) 0%, rgba(0,0,0,0.0001) 100%);
#   background-repeat: repeat-x;
#   filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#80000000', endColorstr='#00000000', GradientType=1);
# }
#
# .carousel-control.right {
#   left: auto;
#   right: 0;
#   background-image: -webkit-linear-gradient(left, rgba(0,0,0,0.0001) 0%, rgba(0,0,0,0.5) 100%);
#   background-image: -o-linear-gradient(left, rgba(0,0,0,0.0001) 0%, rgba(0,0,0,0.5) 100%);
#   background-image: linear-gradient(to right, rgba(0,0,0,0.0001) 0%, rgba(0,0,0,0.5) 100%);
#   background-repeat: repeat-x;
#   filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#00000000', endColorstr='#80000000', GradientType=1);
# }
#
# .carousel-control .glyphicon-chevron-left,
# .carousel-control .glyphicon-chevron-right {
#   position: absolute;
#   top: 50%;
#   margin-top: -10px;
#   z-index: 5;
#   display: inline-block;
# }
#
# .carousel-control .glyphicon-chevron-left {
#   left: 50%;
#   margin-left: -10px;
# }
#
# .carousel-control .glyphicon-chevron-right {
#   right: 50%;
#   margin-right: -10px;
# }
#
# .carousel-indicators {
#   position: absolute;
#   bottom: 10px;
#   left: 50%;
#   z-index: 15;
#   width: 60%;
#   margin-left: -30%;
#   padding-left: 0;
#   list-style: none;
#   text-align: center;
# }
#
# .carousel-indicators li {
#   display: inline-block;
#   width: 10px;
#   height: 10px;
#   margin: 1px;
#   text-indent: -999px;
#   border: 1px solid #fff;
#   border-radius: 10px;
#   background-color: #000 \9;
#   background-color: transparent;
# }
#
# .carousel-indicators .active {
#   margin: 0;
#   width: 12px;
#   height: 12px;
#   background-color: #fff;
# }
#
# @media screen and (min-width: 768px) {
#   .carousel-control .glyphicon-chevron-left,
#   .carousel-control .glyphicon-chevron-right {
#     width: 30px;
#     height: 30px;
#     margin-top: -10px;
#     font-size: 30px;
#   }
#
#   .carousel-control .glyphicon-chevron-left {
#     margin-left: -10px;
#   }
#
#   .carousel-control .glyphicon-chevron-right {
#     margin-right: -10px;
#   }
#
#   .carousel-indicators {
#     bottom: 20px;
#   }
# }
#
# .clearfix:before,
# .clearfix:after {
#   content: " ";
#   display: table;
# }
#
# .clearfix:after {
#   clear: both;
# }
#
# .pull-right {
#   float: right !important;
# }
#
# .pull-left {
#   float: left !important;
# }
#
# .hide {
#   display: none !important;
# }
#
# @-ms-viewport {
#   width: device-width;
# }
#
# .visible-xs-block {
#   display: none !important;
# }
#
# @media (max-width: 767px) {
#   .visible-xs-block {
#     display: block !important;
#   }
# }
#
# @media (max-width: 767px) {
#   .hidden-xs {
#     display: none !important;
#   }
# }
#
# .hide {
#   display: none;
# }
#
# @media (min-width: 768px) and (max-width: 1119px) {
#   @viewport {
#     width: 1120px;
#     user-zoom: fixed;
#   }
#
#   @-ms-viewport {
#     width: 1120px;
#     user-zoom: fixed;
#   }
# }
#
# @media (max-width: 767px) {
#   @viewport {
#     width: device-width;
#     initial-scale: 1;
#   }
#
#   @-ms-viewport {
#     width: device-width;
#     initial-scale: 1;
#   }
# }
#
# ul {
#   list-style-type: none;
#   padding: 0;
#   margin: 0;
# }
#
# .noSpacing {
#   margin: 0;
#   padding: 0;
# }
#
# .container {
#   background-color: white;
#   padding: 0;
#   margin: 0 auto;
# }
#
# .container.body_main {
#   background: none;
# }
#
# @media (min-width: 768px) {
#   .container {
#     width: 1100px;
#   }
# }
#
# @media (max-width: 767px) {
#   .container {
#     width: 100%;
#     overflow: hidden;
#   }
# }
#
# @media (min-width: 768px) {
#   h1 {
#     line-height: 30px;
#     margin-bottom: 6px;
#   }
# }
#
# @media (max-width: 767px) {
#   h1 {
#     font-size: 18px;
#     margin: 0;
#     padding: 4px 6px;
#   }
# }
#
# @media (min-width: 768px) {
#   h2 {
#     line-height: 19px;
#     margin-bottom: 6px;
#     margin-top: 4px;
#   }
# }
#
# @media (max-width: 767px) {
#   h2:not(.panel-heading) {
#     color: #343434;
#     font-size: 17px;
#     font-weight: bold;
#     margin: 0;
#     padding: 4px 6px;
#     text-transform: uppercase;
#   }
# }
#
# h3 {
#   line-height: 17px;
#   color: #545454;
#   margin: 0 0 12px 0;
# }
#
# h1,
# h2,
# h3 {
#   text-transform: uppercase;
# }
#
# body {
#   color: #333;
#   background-color: #EEEEEE;
#   position: relative;
#   -webkit-font-smoothing: antialiased;
# }
#
# @media (max-width: 767px) {
#   body {
#     background: #EEEEEE;
#     border: 0;
#     width: 100%;
#     margin: 0;
#     padding: 0;
#   }
# }
#
# em {
#   display: inline;
# }
#
# @media (max-width: 767px) {
#   .col-full-xs {
#     padding: 0;
#     width: 100%;
#   }
# }
#
# a {
#   color: #2466d4;
#   text-decoration: none;
# }
#
# a.unstyled {
#   color: #343434;
# }
#
# a.articleLink {
#   color: black;
# }
#
# .lightGray {
#   color: #eee;
# }
#
# .white {
#   color: white;
# }
#
# @media (min-width: 768px) {
#   .default-margin {
#     margin: 20px;
#   }
# }
#
# @media (max-width: 767px) {
#   .default-margin {
#     margin: 10px;
#   }
# }
#
# .fullWidth {
#   width: 100% !important;
# }
#
# .fr {
#   float: right;
# }
#
# .clearfix {
#   clear: both;
# }
#
# .inlineBlock {
#   display: inline-block;
# }
#
# .btn-primary-rt:not(.disabled) {
#   color: black;
#   background-color: #FFE400;
#   border-color: #FFE400;
# }
#
# .btn-primary-fb {
#   color: #fff;
#   background-color: #337ab7;
#   border-color: #2e6da4;
#   background-color: #3B5999;
#   border-width: 0;
# }
#
# .center {
#   text-align: center;
# }
#
# .tableCenterDiv {
#   display: table;
#   margin: 0 auto;
# }
#
# .clickForMore {
#   text-align: right;
# }
#
# @media (min-width: 768px) {
#   .clickForMore {
#     margin: 0;
#   }
# }
#
# @media (max-width: 767px) {
#   .clickForMore {
#     margin: 5px 0 30px 0;
#   }
# }
#
# .row-sameColumnHeight {
#   margin-left: -10px;
#   margin-right: -10px;
#   display: table;
# }
#
# .row-sameColumnHeight.noSpacing {
#   margin: 0;
# }
#
# .row-sameColumnHeight>[class*="col-"] {
#   float: none;
#   display: table-cell;
#   vertical-align: top;
# }
#
# .sponsored-tag {
#   display: none;
# }
#
# .sponsored-bg {
#   border-width: 0 80px 80px 0;
#   border-color: transparent #2971b2 transparent transparent;
#   border-style: solid;
#   position: absolute;
#   right: 0;
#   top: 0;
#   z-index: 1;
# }
#
# .sponsored-text {
#   -webkit-transform: rotate(45deg);
#   -ms-transform: rotate(45deg);
#   -o-transform: rotate(45deg);
#   transform: rotate(45deg);
#   color: #FFFFFF;
#   font-size: 0.9em;
#   position: absolute;
#   right: 0;
#   top: 28px;
#   z-index: 2;
# }
#
# #trending_bar_ad {
#   margin-top: -4px;
#   position: relative;
#   left: 10px;
# }
#
# @media (max-width: 767px) {
#   #main_container {
#     padding-top: 0 !important;
#   }
# }
#
# @media (max-width: 767px) {
#   .searchButton {
#     margin-right: 5px;
#     margin-top: 2px;
#     padding: 9px;
#   }
# }
#
# .navbar.navbar-rt {
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   background-color: #FA320A;
#   font-family: "Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif;
#   margin: 0;
# }
#
# @media (min-width: 768px) {
#   .navbar.navbar-rt {
#     background-repeat: no-repeat;
#     background-size: 9%;
#   }
# }
#
# @media (max-width: 767px) {
#   .navbar.navbar-rt {
#     border-top: solid #555555 1px;
#   }
# }
#
# .navbar.navbar-rt h2 {
#   font-family: "Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif;
# }
#
# .navbar.navbar-rt .navbar-header {
#   padding: 4px 2px;
# }
#
# .navbar.navbar-rt .navbar-header .header_links {
#   float: right;
#   vertical-align: middle;
# }
#
# .navbar.navbar-rt .navbar-header .header_links>* {
#   color: #b1eda3;
#   font-size: 14px;
#   padding: 2px 6px;
#   text-decoration: none;
# }
#
# .navbar.navbar-rt .navbar-header .header_links>* a {
#   padding-left: 6px;
# }
#
# .navbar.navbar-rt .navbar-header .header_links #headerUserSection {
#   display: inline-block;
#   font-weight: bold;
# }
#
# .navbar.navbar-rt a:not(.FullscreenSearch__results-view-all):not(.FullscreenSearch__result-one-line-format):not(.active):not(.articleLink) {
#   background-color: transparent;
#   color: white;
#   text-decoration: none;
# }
#
# .navbar.navbar-rt #menu {
#   position: static;
# }
#
# .navbar.navbar-rt #menu>ul {
#   list-style-type: none;
#   margin: 0 0 0 -5px;
#   padding: 0;
# }
#
# .navbar.navbar-rt #menu .menuHeader {
#   border-top-left-radius: 5px;
#   border-top-right-radius: 5px;
#   color: white;
#   padding: 0;
#   position: static;
# }
#
# .navbar.navbar-rt #menu .menuHeader #ticketingMenu {
#   -webkit-border-radius: 5px;
#   -moz-border-radius: 5px;
#   -ms-border-radius: 5px;
#   border-radius: 5px;
# }
#
# .navbar.navbar-rt #menu .menuHeader .row-sameColumnHeight {
#   width: 100%;
# }
#
# .navbar.navbar-rt #menu .menuHeader>a {
#   display: block;
#   margin: 0;
#   padding: 14px 10px 17px;
#   text-transform: uppercase;
# }
#
# .navbar.navbar-rt #menu .menuHeader>a>.fontelloIcon.icon-down-dir:before {
#   margin-right: 0;
#   width: 10px;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu {
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   border-top: none;
#   display: none;
#   margin: -4px 0 10px 0;
#   left: -1px;
#   top: 78px;
#   position: absolute;
#   width: 1102px;
#   z-index: 2147483647;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu a {
#   color: #343434;
#   font-size: 16px;
#   line-height: 21px;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu .subnav {
#   padding: 10px;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu .subnav h2.title {
#   font-size: 18px;
#   margin-top: 0;
#   font-weight: bold;
#   width: max-content;
#   width: -moz-max-content;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu .subnav li {
#   padding: 2px 0;
#   width: max-content;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu .subnav .innerSubnav {
#   margin: 0 10px;
# }
#
# .navbar.navbar-rt #menu .menuHeader .dropdown-menu #header-news-columns ul li {
#   padding: 0;
# }
#
# .navbar.navbar-rt .navbar-button {
#   -webkit-border-radius: 4px;
#   -moz-border-radius: 4px;
#   -ms-border-radius: 4px;
#   border-radius: 4px;
#   background-color: transparent;
#   border: 1px solid white;
#   position: relative;
#   margin: 4px;
#   width: 40px;
#   height: 40px;
#   text-align: center;
# }
#
# @media (min-width: 768px) {
#   .navbar.navbar-rt .navbar-brand {
#     height: auto;
#     padding: 22px 26px 10px 15px;
#     width: 36%;
#   }
# }
#
# @media (max-width: 767px) {
#   .navbar.navbar-rt .navbar-brand {
#     float: left;
#     margin-left: 0;
#     max-height: 44px;
#     max-width: 36%;
#     padding: 5px;
#     position: static;
#   }
# }
#
# @media (min-width: 768px) {
#   .navbar.navbar-rt .navbar-brand img {
#     width: 100%;
#     position: relative;
#     right: 10px;
#     bottom: 5px;
#   }
# }
#
# @media (max-width: 767px) {
#   .navbar.navbar-rt .navbar-brand img {
#     max-height: 34px;
#     max-width: 100%;
#   }
# }
#
# .navbar.navbar-rt .navbar-searchbox {
#   display: inline-block;
# }
#
# @media (min-width: 768px) {
#   .navbar.navbar-rt .navbar-searchbox {
#     margin-bottom: 10px;
#     margin-top: 31px;
#     width: 64%;
#   }
# }
#
# @media (max-width: 767px) {
#   .navbar.navbar-rt .navbar-searchbox {
#     float: right;
#     margin: 2px 0;
#     width: 100%;
#   }
# }
#
# .navbar.navbar-rt .navbar-searchbox.main {
#   width: 64%;
# }
#
# .navbar.navbar-rt .navbar-searchbox .input-group {
#   -webkit-border-radius: 5px;
#   -moz-border-radius: 5px;
#   -ms-border-radius: 5px;
#   border-radius: 5px;
#   position: static;
# }
#
# .navbar.navbar-rt .navbar-searchbox .input-group #search-term {
#   border: none;
#   box-shadow: none;
#   width: 100%;
# }
#
# .navbar.navbar-rt .navbar-searchbox .searchBtn {
#   -webkit-border-radius: 0 5px 5px 0;
#   -moz-border-radius: 0 5px 5px 0;
#   -ms-border-radius: 0 5px 5px 0;
#   border-radius: 0 5px 5px 0;
#   border: none;
#   height: 34px;
# }
#
# @media (max-width: 480px) {
#   .navbar.navbar-rt .navbar-searchbox .searchBtn {
#     padding-left: 3px;
#   }
# }
#
# .navbar.navbar-rt .navbar-searchbox .navbar-close {
#   display: none;
# }
#
# .mob-nav-bottom {
#   background: #343434;
#   border-top: 1px solid #858585;
#   bottom: 0;
#   display: block;
#   font-size: 12px;
#   left: 0;
#   position: fixed;
#   width: 100%;
#   z-index: 10;
# }
#
# .mob-nav-bottom .nav-list .nav-item {
#   text-align: center;
# }
#
# .mob-nav-bottom .nav-list .nav-item a {
#   color: white;
#   display: block;
#   font-size: 10px;
#   padding: 5px 0;
#   text-align: center;
#   text-decoration: none;
#   text-transform: uppercase;
#   width: 100%;
# }
#
# .mob-nav-bottom .nav-list .nav-item a i {
#   font-size: 25px;
#   display: block;
#   top: 2px;
# }
#
# .nav-list,
# .mobile-menu-panel {
#   display: flex;
#   display: -ms-flexbox;
#   display: -moz-box;
#   display: -webkit-box;
#   display: -webkit-flex;
#   -moz-box-flex: 0;
#   -webkit-box-flex: 0;
#   -webkit-flex: 0 1 auto;
#   -ms-flex: 0 1 auto;
#   flex: 0 1 auto;
#   -webkit-box-direction: normal;
#   -moz-box-direction: normal;
#   -webkit-flex-direction: row;
#   -ms-flex-direction: row;
#   flex-direction: row;
#   -ms-flex-wrap: wrap;
#   -webkit-flex-wrap: wrap;
#   flex-wrap: wrap;
#   -webkit-box-orient: horizontal;
# }
#
# .nav-item {
#   -moz-box-flex: 1;
#   -webkit-box-flex: 1;
#   -webkit-flex: 0 0 auto;
#   -ms-flex: 0 0 auto;
#   flex: 0 0 auto;
#   -ms-flex-positive: 1;
#   -webkit-flex-grow: 1;
#   flex-grow: 1;
#   -ms-flex-preferred-size: 0;
#   -webkit-flex-basis: 0;
#   flex-basis: 0;
#   max-width: 100%;
# }
#
# .mobile-nav-overlay {
#   background: rgba(0,0,0,0.5);
#   bottom: 0;
#   display: none;
#   height: 100%;
#   left: 0;
#   position: fixed;
#   width: 100%;
#   z-index: 5;
# }
#
# .mobile-menu-panel {
#   background: #FA320A;
#   bottom: 54px;
#   display: none;
#   overflow: hidden;
#   position: absolute;
#   width: 100%;
#   z-index: 2;
# }
#
# .mobile-menu-panel .nav-item {
#   border-bottom: 1px solid rgba(255,255,255,0.35);
#   color: #fff;
#   padding: 7px 10px;
#   text-transform: uppercase;
# }
#
# .login-signup-box a {
#   -webkit-box-shadow: 0 0 0 1px rgba(255,255,255,0.35) inset;
#   box-shadow: 0 0 0 1px rgba(255,255,255,0.35) inset;
#   border: 0;
#   border-radius: 6px;
#   background-color: transparent;
#   background-image: none;
#   color: #fff;
#   display: inline-block;
#   float: left;
#   font-weight: normal;
#   font-size: 12px;
#   line-height: 25px;
#   margin-bottom: 0;
#   min-width: 66px;
#   outline: 0;
#   text-align: center;
#   touch-action: manipulation;
#   vertical-align: middle;
#   white-space: nowrap;
# }
#
# .login-signup-box a:first-of-type {
#   margin-right: 6px;
# }
#
# .social-media-box {
#   height: 26px;
# }
#
# .social-media-box a {
#   color: #fff;
#   font-size: 26px;
#   height: 26px;
#   position: relative;
#   top: -5px;
#   width: 26px;
# }
#
# .social-media-box a:first-of-type {
#   margin-right: 5px;
# }
#
# .trendingBar {
#   background-color: rgba(0,0,0,0.6);
#   color: white;
#   padding: 4px 10px;
#   font-size: 14px;
#   z-index: 1;
#   opacity: 0.9;
#   width: inherit;
#   position: relative;
#   height: 26px;
# }
#
# .trendingBar .header {
#   color: #FFE400;
#   font-family: "Neusa Next Pro Compact" !important;
#   font-size: 18px;
#   text-transform: uppercase;
#   padding-left: 0px;
# }
#
# .trendingBar li a,
# .trendingBar li a:before {
#   color: white;
# }
#
# .trendingBar .social li {
#   padding: 0 3px;
# }
#
# .trendingBar .trendingEl {
#   display: table;
#   padding: 0 15px;
# }
#
# .trendingBar .trendingEl li {
#   display: table-cell;
#   font-family: "Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif;
# }
#
# #login,
# #signup {
#   z-index: 1000001;
# }
#
# @media (max-width: 767px) {
#   #login .modal-dialog,
#   #signup .modal-dialog {
#     height: 100%;
#     margin: auto;
#     width: 300px;
#   }
#
#   #login .modal-dialog .modal-content,
#   #signup .modal-dialog .modal-content {
#     height: auto;
#     overflow-y: scroll;
#     width: 100%;
#   }
# }
#
# #login .modal-dialog .modal-footer,
# #signup .modal-dialog .modal-footer {
#   background-color: #eee;
#   text-align: center;
# }
#
# @media (min-width: 768px) {
#   #navMenu {
#     display: none;
#   }
# }
#
# .trendingBar .social li a {
#   display: inline-block;
# }
#
# @media (max-width: 767px) {
#   #navMenu {
#     background: transparent;
#     border-right: 1px solid black;
#     padding: 0;
#     width: 100%;
#   }
#
#   #navMenu .modal-dialog {
#     height: 100%;
#     margin: 0;
#   }
#
#   #navMenu .modal-dialog .modal-content {
#     background: #3A9425;
#     height: 100%;
#   }
#
#   #navMenu .modal-dialog .modal-content .modal-body {
#     height: 100%;
#     padding: 0;
#     overflow-y: scroll;
#     width: 100%;
#   }
#
#   #navMenu .social {
#     margin-left: 0;
#   }
#
#   #navMenu .social li {
#     padding: 0;
#   }
#
#   #navMenu .social li a {
#     color: white;
#     display: block;
#     font-size: 32px;
#     padding: 12px;
#   }
#
#   #navMenu .close {
#     padding: 20px;
#   }
#
#   #navMenu .items {
#     border-top: 1px solid #326028;
#     margin-top: 67px;
#   }
#
#   #navMenu .items .item {
#     border-bottom: 1px solid #326028;
#     display: block;
#   }
#
#   #navMenu .items .item>a {
#     color: #fff;
#     display: inline-block;
#     font-weight: bold;
#     text-transform: uppercase;
#   }
#
#   #navMenu .items .item>a {
#     padding: 15px 5px;
#   }
#
#   #navMenu .items .item>a.navLink {
#     padding: 15px;
#     width: 85%;
#   }
#
#   #navMenu .items .item>a.navLink.fullLink {
#     display: block;
#     width: 100%;
#   }
#
#   #navMenu .loginArea {
#     display: block;
#   }
# }
#
# #header-news-columns ul li {
#   padding: 0;
# }
#
# .panel-rt {
#   border-color: #fff;
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   -webkit-box-shadow: none;
#   box-shadow: none;
#   border: none;
#   clear: both;
# }
#
# .panel-rt>.panel-heading {
#   color: #1C1C1C;
#   border-color: transparent;
# }
#
# @media (max-width: 767px) {
#   .panel-rt {
#     border: none;
#     margin: 10px 0;
#     padding-bottom: 0;
#   }
# }
#
# .panel-rt .panel-body {
#   clear: both;
#   overflow: hidden;
# }
#
# @media (max-width: 767px) {
#   .panel-rt .panel-body {
#     padding: 5px;
#   }
# }
#
# .panel-rt .panel-heading {
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   border-color: transparent;
#   clear: left;
#   color: #1C1C1C;
#   float: left;
#   text-transform: uppercase;
# }
#
# @media (min-width: 768px) {
#   .panel-rt .panel-heading {
#     padding: 10px 25px;
#     float: initial;
#   }
# }
#
# .panel-rt.bannerCaption {
#   border: none;
#   margin: 0;
# }
#
# .panel-rt.bannerCaption .panel-heading {
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   margin: 0;
#   padding: 0 10px;
#   z-index: 20;
# }
#
# .panel-rt.bannerCaption .panel-body .title {
#   font-weight: bold;
#   margin: 0;
# }
#
# .social-tools {
#   background-color: #fff;
#   border: none;
#   margin-top: -100px;
#   overflow: hidden;
#   position: fixed;
#   right: 0;
#   top: 75%;
# }
#
# @media (max-width: 1150px) {
#   .social-tools {
#     display: none;
#   }
# }
#
# .social-tools a {
#   background-image: url("/assets/pizza-pie/images/social/sharevert-sprite.3b34457fe6e.png");
#   display: block;
#   height: 32px;
#   width: 57px;
# }
#
# .social-tools a::after {
#   background-image: url("/assets/pizza-pie/images/social/sharevert-sprite.3b34457fe6e.png");
#   content: "";
#   display: block;
#   height: 32px;
#   opacity: 0;
#   width: 57px;
# }
#
# .social-tools-facebook-share {
#   background-position: 0 0;
# }
#
# .social-tools-facebook-share:after {
#   background-position: -57px 0;
# }
#
# @media (max-width: 767px) {
#   .social-tools-facebook-share {
#     width: 23%;
#   }
# }
#
# .social-tools-facebook-like {
#   text-align: center;
#   background-position: 0 -31px;
#   display: block;
#   height: 32px;
#   width: 57px;
#   padding-top: 7px;
# }
#
# @media (max-width: 767px) {
#   .social-tools-facebook-like {
#     width: 23%;
#   }
# }
#
# .social-tools-facebook-like:after {
#   background-position: -57px -32px;
# }
#
# .social-tools-twitter {
#   background-position: 0 -97px;
# }
#
# @media (max-width: 767px) {
#   .social-tools-twitter {
#     width: 23%;
#   }
# }
#
# .social-tools-twitter:after {
#   background-position: -57px -96px;
# }
#
# .social-tools-pinterest {
#   background-position: 0 -128px;
# }
#
# @media (max-width: 767px) {
#   .social-tools-pinterest {
#     width: 23%;
#   }
# }
#
# .social-tools-pinterest:after {
#   background-position: -57px -128px;
# }
#
# .social-tools-googleplus {
#   background-position: 0 -160px;
# }
#
# @media (max-width: 767px) {
#   .social-tools-googleplus {
#     width: 23%;
#   }
# }
#
# .social-tools-googleplus:after {
#   background-position: -57px -160px;
# }
#
# .social-tools-stumbleupon {
#   background-position: 0 -192px;
# }
#
# .social-tools-stumbleupon:after {
#   background-position: -57px -192px;
# }
#
# @media (max-width: 767px) {
#   .social-tools-stumbleupon {
#     width: 23%;
#   }
# }
#
# .noRating {
#   color: #545454;
#   font-size: 10px;
# }
#
# .tMeterIcon.tiny {
#   display: inline-block;
#   min-width: 50px;
#   padding-bottom: 1px;
# }
#
# .tMeterIcon.tiny.noRating {
#   width: 59px;
# }
#
# .fontelloIcon:before {
#   display: inline-block;
#   font-family: "fontello";
#   font-style: normal;
#   font-variant: normal;
#   font-weight: normal;
#   line-height: 1em;
#   margin-left: .2em;
#   margin-right: .2em;
#   speak: none;
#   text-align: center;
#   text-decoration: inherit;
#   text-transform: none;
#   width: 1em;
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
# }
#
# .icon-twitter:before {
#   content: '\e801';
# }
#
# .icon-youtube-play:before {
#   content: '\e803';
# }
#
# .icon-facebook-squared:before {
#   content: '\e804';
# }
#
# .icon-down-dir:before {
#   content: '\e807';
# }
#
# .icon-tv2:before {
#   content: '\e80c';
# }
#
# .icon-boxoffice:before {
#   content: '\e80d';
# }
#
# .icon-home:before {
#   content: '\e80e';
# }
#
# .icon-more:before {
#   content: '\e80f';
# }
#
# .icon-redeem:before {
#   content: '\e813';
# }
#
# .icon-snapchat:before {
#   content: '\e817';
# }
#
# .icon-instagram:before {
#   content: '\e818';
# }
#
# .headline {
#   padding: .5px;
# }
#
# .headline:first-of-type {
#   padding-left: 0;
#   padding-right: 0;
# }
#
# .headline .headlineItem .bannerPic {
#   background-size: cover !important;
#   width: 100%;
#   height: 310px;
# }
#
# @media (max-width: 767px) {
#   .headline .headlineItem .bannerCaption {
#     bottom: 10px;
#   }
#
#   .headline .headlineItem .bannerPic {
#     margin-top: 25px;
#   }
# }
#
# .headline .headlineItem .bannerCaption {
#   background-color: #343434;
#   padding-bottom: 10px;
#   overflow: hidden;
#   border-bottom: 0;
#   margin: 0;
# }
#
# .headline .headlineItem .bannerCaption .panel-heading {
#   -webkit-border-radius: 0;
#   -moz-border-radius: 0;
#   -ms-border-radius: 0;
#   border-radius: 0;
#   margin: 0;
#   padding: 0 10px;
#   z-index: 20;
# }
#
# .headline .headlineItem .bannerCaption .panel-body .title {
#   font-weight: bold;
#   margin: 0;
# }
#
# @media (min-width: 768px) {
#   .headline .headlineItem .bannerCaption {
#     padding-top: 15px !important;
#     height: 90px;
#     opacity: .8;
#     left: 25px;
#     background-color: white;
#     position: absolute;
#     border-left: 5px solid #FA320A;
#     bottom: 10px;
#   }
# }
#
# .headline .headlineItem .bannerCaption .panel-body {
#   padding: 5px 15px;
# }
#
# #headliners .carousel-indicators {
#   background-color: transparent;
#   bottom: -37px;
#   height: 16px;
#   left: auto;
#   padding-right: 188px;
#   right: 30px;
#   text-align: right;
#   width: auto;
#   z-index: 1;
# }
#
# #headliners .carousel-indicators li {
#   background-color: #000000;
#   opacity: .35;
#   margin: 5px;
# }
#
# #headliners .carousel-indicators li.active {
#   background-color: #FA320A !important;
#   height: 10px;
#   width: 10px;
#   opacity: 1 !important;
# }
#
# #headliners .carousel-control {
#   bottom: 75px;
#   top: 0;
#   background-image: none;
# }
#
# #homepage-top-dvd-streaming h2 {
#   margin-bottom: 0;
# }
#
# #dvd-affliate-links {
#   margin-bottom: 10px;
# }
#
# @media (max-width: 767px) {
#   #dvd-affliate-links {
#     margin-left: 6px;
#   }
# }
#
# #dvd-affliate-links a:first-child {
#   margin-left: 0;
# }
#
# #dvd-affliate-links a {
#   font-size: 14px;
#   margin: 0 2px;
#   text-decoration: none;
#   color: black;
# }
#
# .movie_list {
#   line-height: 24px;
#   margin-top: 10px;
#   max-width: 100%;
#   table-layout: fixed;
#   width: 100%;
# }
#
# .movie_list a {
#   color: #343434;
# }
#
# .movie_list tr td {
#   padding: 0;
# }
#
# .movie_list .right_col {
#   padding: 0 7px;
#   text-align: right;
#   text-transform: uppercase;
#   width: 65px;
# }
#
# @media (max-width: 767px) {
#   .movie_list tr td {
#     padding: 8px;
#   }
# }
#
# .movie_list tr .left_col {
#   width: 75px;
# }
#
# .movie_list tr .middle_col {
#   overflow: hidden;
#   text-overflow: ellipsis;
#   white-space: nowrap;
#   width: auto;
#   padding-left: 5px;
#   font-family: 'Franklin Gothic FS Book', sans-serif;
# }
#
# .movie_list tr .middle_col a {
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
#
# .movie_list tr .right_col {
#   color: #545454;
#   padding: 0 5px;
#   text-align: right;
#   text-transform: uppercase;
#   width: 65px;
# }
#
# @media (max-width: 767px) {
#   .movie_list tr {
#     border-top: 1px solid #ddd;
#     margin: 5px 0;
#   }
#
#   .movie_list tr td {
#     vertical-align: middle;
#   }
#
#   .movie_list tr:last-of-type {
#     border-bottom: 1px solid #ddd;
#   }
# }
#
# .freshPicks .cfpItem {
#   float: left;
#   text-align: center;
# }
#
# @media (min-width: 768px) {
#   .freshPicks .cfpItem {
#     padding: 0 10px;
#     width: 20%;
#   }
# }
#
# @media (max-width: 767px) {
#   .freshPicks .cfpItem {
#     padding: 5px;
#     width: 30vw;
#   }
# }
#
# .freshPicks .cfpItem a {
#   color: #555;
# }
#
# @media (min-width: 768px) {
#   .freshPicks .cfpItem a .imgContainer {
#     height: 200px;
#   }
# }
#
# @media (max-width: 767px) {
#   .freshPicks .cfpItem a .imgContainer {
#     height: 40vw;
#   }
#
#   .freshPicks .cfpItem a .imgContainer img {
#     height: 100%;
#     width: 100%;
#   }
# }
#
# .freshPicks .cfpItem a .topText {
#   font-weight: 600;
#   font-size: 16px;
#   margin: 0;
#   text-transform: uppercase;
#   font-family: 'Neusa Next Pro Compact', Impact, Arial, sans-serif;
# }
#
# @media (max-width: 767px) {
#   .freshPicks .cfpItem a .topText {
#     height: 32px;
#   }
# }
#
# @media (min-width: 768px) {
#   .freshPicks .cfpItem a .imgContainer img {
#     height: 100%;
#     width: 118%;
#     position: relative;
#     left: -13px;
#   }
# }
#
# #newTrailerModal.modal,
# #newIframeTrailerModal.modal {
#   bottom: 0;
#   display: none;
#   overflow: auto;
#   position: fixed;
#   left: 0;
#   outline: 0;
#   right: 0;
#   top: 0;
#   z-index: 1000001;
#   -webkit-overflow-scrolling: touch;
# }
#
# @media (max-width: 991px) {
#   #newTrailerModal.modal,
#   #newIframeTrailerModal.modal {
#     background: black;
#     height: 100%;
#     width: 100%;
#   }
# }
#
# #newTrailerModal.modal.fade .modal-dialog,
# #newIframeTrailerModal.modal.fade .modal-dialog {
#   transform: none !important;
#   -webkit-transform: none !important;
#   -moz-transform: none !important;
#   -o-transform: none !important;
# }
#
# #newTrailerModal .modal-dialog,
# #newIframeTrailerModal .modal-dialog {
#   -webkit-border-radius: 6px;
#   -moz-border-radius: 6px;
#   -ms-border-radius: 6px;
#   border-radius: 6px;
#   -webkit-box-shadow: 0 5px 15px rgba(0,0,0,0.5);
#   box-shadow: 0 5px 15px rgba(0,0,0,0.5);
#   background: black;
#   bottom: 0;
#   left: 0;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# @media (min-width: 768px) {
#   #newTrailerModal .modal-dialog,
#   #newIframeTrailerModal .modal-dialog {
#     height: 51vw;
#     margin: 10vh auto auto;
#     max-height: 70vh;
#     max-width: 125vh;
#     width: 90vw;
#   }
# }
#
# @media (max-width: 767px) {
#   #newTrailerModal .modal-dialog,
#   #newIframeTrailerModal .modal-dialog {
#     height: 60vw;
#     margin: auto;
#     max-height: 100vh;
#     max-width: 178vh;
#     width: 100vw;
#   }
# }
#
# #newTrailerModal #videoPlayer {
#   height: 100%;
#   width: 100%;
# }
#
# #newTrailerModal .closebutton,
# #newIframeTrailerModal .closebutton {
#   opacity: 0;
#   filter: alpha(opacity=0);
#   font-size: 25px;
#   position: absolute;
#   right: -11px;
#   top: -11px;
#   z-index: 2147483647;
# }
#
# #videoPlayer {
#   height: 100%;
#   text-align: center;
#   width: 100%;
# }
#
# @media (max-width: 767px) {
#   #videoPlayer {
#     height: calc(100% - 40px);
#   }
# }
#
# @media (max-width: 767px) {
#   #newTrailerModal .closebutton,
#   #newIframeTrailerModal .closebutton {
#     display: none;
#   }
# }
#
# @media (min-width: 768px) {
#   #newTrailerModal .closeBtn,
#   #newTrailerModal .moreTrailer {
#     display: none;
#   }
# }
#
# @media (max-width: 767px) {
#   #newTrailerModal .closeBtn,
#   #newTrailerModal .moreTrailer {
#     bottom: 0;
#     height: 40px;
#     margin: 0 auto;
#     position: absolute;
#     width: 49%;
#   }
# }
#
# @media (max-width: 767px) {
#   #newTrailerModal .closeBtn {
#     left: 0;
#   }
# }
#
# @media (max-width: 767px) {
#   #newTrailerModal .moreTrailer {
#     left: 50%;
#   }
#
#   #newTrailerModal .moreTrailer a {
#     display: block;
#     height: 100%;
#     width: 100%;
#   }
# }
#
# .in {
#   opacity: 1;
# }
#
# .home-slide {
#   background: url('/assets/pizza-pie/images/home/default_homepage_slide.87639326b72.jpg') center center;
#   background-size: cover;
# }
#
# .spotlight-item-wrap {
#   overflow: hidden;
#   max-height: 310px;
# }
#
# @media (min-width: 768px) {
#   .cfpModule h1.panel-heading {
#     margin-left: 5px;
#   }
#
#   #headliners .panel-rt.bannerCaption.subPanel {
#     width: 500px;
#   }
#
#   h1.panel-heading::after {
#     content: '  ';
#   }
# }
#
# @media (max-width: 767px) {
#   .cfpModule h1.panel-heading {
#     margin-left: 20px;
#   }
#
#   #miniMOB .clickForMore a {
#     padding-left: 10px;
#   }
#
#   .cfpModule .panel-body.row {
#     margin-top: -75px;
#   }
#
#   .movie_list {
#     line-height: initial;
#   }
#
#   h1.panel-heading::after {
#     content: none;
#   }
# }
#
# h3,
# .articleLink,
# .btn {
#   font-family: 'Franklin Gothic FS Med', sans-serif;
# }
#
# #header-main .dropdown-menu li a,
# .cfpModule .col-sm-6,
# .input-group,
# .modal-content,
# .clickForMore a {
#   font-family: 'Franklin Gothic FS Book', sans-serif;
# }
#
# #movieMenu,
# #tvMenu,
# #newsMenu,
# #ticketingMenu,
# h1.panel-heading {
#   font-family: 'Neusa Next Pro Compact', Impact, Arial, sans-serif;
# }
#
# #home-cfp-cf-logo {
#   margin-right: 15px;
# }
#
# .home-body {
#   position: relative;
#   overflow: hidden;
#   margin-top: -26.4px;
#   width: 100%;
# }
#
# h1.panel-heading::before {
#   padding-left: 6px;
# }
#
# h1.panel-heading::after {
#   position: absolute;
#   margin-left: 11px;
#   width: 100%;
#   background-color: #FA320A;
#   min-width: 20px;
#   height: 20px;
# }
#
# h1.panel-heading::before {
#   background-color: #FA320A;
#   content: ' ';
#   min-width: 20px;
#   height: 20px;
#   position: absolute;
#   left: 0;
# }
#
# .panel-rt .panel-heading {
#   border: 0;
#   font-size: 28px;
# }
#
# .cfpItem p {
#   color: #343434;
# }
#
# .clickForMore a {
#   color: #2466d4;
# }
#
# #menu .list-inline {
#   width: 520px;
# }
#
# #movieMenu,
# #tvMenu,
# #newsMenu,
# #ticketingMenu {
#   font-size: 20px;
#   font-weight: 700;
# }
#
# #header-whats-the-tomatometer,
# #header-top-bar-critics {
#   font-family: 'Franklin Gothic FS Med', sans-serif;
#   color: #ffffff;
# }
#
# #headerUserSection {
#   color: #ffffff;
# }
#
# #header-top-bar-signup {
#   padding-right: 3px;
# }
#
# #header-main .dropdown-menu h2 {
#   font-family: 'Franklin Gothic FS Med', sans-serif;
#   font-weight: normal;
# }
#
# .glyphicon-chevron-right:before {
#   content: "\e250";
# }
#
# .glyphicon-chevron-left:before {
#   content: "\e251";
# }
#
# #main_container {
#   position: relative;
# }
#
# h1.panel-heading {
#   font-weight: 600;
#   line-height: 25px;
# }
#
# @media (max-width: 767px) {
#   .FullscreenSearch__results-view-all {
#     color: white;
#   }
# }
#
# .FullscreenSearch__top-section {
#   background: #FA320A;
#   padding-top: 54px;
#   padding-bottom: 16px;
# }
#
# .FullscreenSearch__top-rt-logo {
#   height: 30px;
#   position: absolute;
#   top: 10px;
#   margin-left: auto;
#   margin-right: auto;
#   left: 0;
#   right: 0;
# }
#
# .FullscreenSearch__close-btn {
#   background: none;
#   border: none;
#   border-radius: 50%;
#   line-height: 0;
#   outline: none;
#   padding: 0.5rem;
#   vertical-align: middle;
#   position: absolute;
#   top: 2px;
#   right: 2px;
#   color: black;
# }
#
# .FullscreenSearch__top-section-container {
#   background: none;
#   padding-left: 15px;
#   padding-right: 15px;
# }
#
# .FullscreenSearch__search-box {
#   position: relative;
# }
#
# .FullscreenSearch__search-btn {
#   position: absolute;
#   right: 0;
#   top: 0;
#   bottom: 0;
#   color: #555;
#   width: 36px;
#   text-align: center;
# }
#
# .FullscreenSearch__clear-search-query-btn {
#   position: absolute;
#   right: 36px;
#   top: 0;
#   bottom: 0;
#   color: #555;
#   width: 36px;
#   text-align: center;
# }
#
# .FullscreenSearch__input {
#   display: block;
#   width: 100%;
#   height: 36px;
#   font-size: 22px;
#   background: white;
#   border: none;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 16px;
#   padding-right: 72px;
#   line-height: normal;
#   border-radius: 5px;
#   color: #1C1C1C;
#   font-size: 22px;
#   font-family: 'Franklin Gothic FS Book';
# }
#
# .FullscreenSearch__input::-ms-clear {
#   display: none;
# }
#
# .FullscreenSearch__results-container {
#   background: rgba(40, 40, 40, 0.97);
#   padding-left: 15px;
#   padding-right: 15px;
#   padding-bottom: 256px;
# }
#
# .FullscreenSearch__results {
#   min-height: 100px;
#   padding-bottom: 8px;
# }
#
# @media (max-width: 767px) {
#   .FullscreenSearch__results {
#     margin-left: -15px;
#     margin-right: -15px;
#   }
# }
#
# .FullscreenSearch__results-view-all {
#   text-align: right;
#   display: block;
#   text-decoration: none;
#   font-size: 18px;
#   padding-top: 16px;
#   padding-bottom: 16px;
# }
#
# .FullscreenSearch__results-view-all>* {
#   vertical-align: middle;
# }
#
# .FullscreenSearch--mobile {
#   overflow: auto;
#   -webkit-overflow-scrolling: touch;
#   z-index: 1000000000;
#   position: fixed;
#   top: 0;
#   right: 0;
#   bottom: 0;
#   left: 0;
# }
#
# .FullscreenSearch--mobile.FullscreenSearch {
#   background: rgba(40, 40, 40, 0.97);
# }
#
# .navbar-searchbox.main {
#   position: relative;
# }
#
# .FullscreenSearch--desktop .FullscreenSearch__results-container {
#   z-index: 1000000000;
#   background: white;
#   position: absolute;
#   left: 0;
#   right: -190px;
#   width: auto;
#   border-radius: 6px;
#   margin-top: 0;
#   overflow: hidden;
#   padding: 0;
#   box-shadow: 0px 0px 5px rgba(0, 0, 0, 0.3);
# }
#
# .FullscreenSearch__results-view-all {
#   font-family: 'Franklin Gothic FS Book';
# }
#
# @media all and (-ms-high-contrast: none) and (min-width: 767px), (-ms-high-contrast: active) and (min-width: 767px) {
#   h1.panel-heading::before {
#     background-color: #FA320A;
#     content: ' ';
#     min-width: 20px;
#     height: 20px;
#     position: absolute;
#     left: 0;
#   }
# }
#
# @media all and (-ms-high-contrast: none) and (max-width: 768px), (-ms-high-contrast: active) and (max-width: 768px) {
#   h1.panel-heading::before {
#     background-color: #FA320A;
#     content: ' ';
#     min-width: 20px;
#     height: 20px;
#     position: absolute;
#     left: 0;
#   }
# }
#
# .footer-mobile {
#   background-color: #343434;
#   border-top: 1px solid white;
#   clear: both;
#   color: white;
#   font-size: 14px;
#   padding: 15px 15px 69px;
#   text-align: center;
#   font-family: 'Franklin Gothic FS Book';
# }
#
# .footer-mobile .footerLinks {
#   color: #b2b2b2;
# }
#
# .footer-space {
#   padding-right: 10px;
# }
#
# .version {
#   color: #343434;
# }
#
# @media (max-width: 767px) {
#   .mobileNav {
#     display: block;
#   }
# }
#
# @media (min-width: 768px) {
#   .mobileNav {
#     display: none;
#   }
#
#   .cfp-img-container {
#     width: 85%;
#     position: relative;
#     right: -14px;
#   }
# }
#
# @media all and (-ms-high-contrast: none) and (min-width: 767px), (-ms-high-contrast: active) and (min-width: 767px) {
#   .trendingBar .icon-snapchat {
#     background-image: url("/assets/pizza-pie/images/icons/global/Snapchat_White_25x25.1630e6c487a.png");
#     background-size: cover;
#     margin-right: -10px;
#     font-size: 2px;
#     position: relative;
#     top: -8px;
#     left: -15px;
#     top: -9px;
#     padding-bottom: 13px;
#     padding-right: 12px;
#   }
#
# ...
#                                   </a>
# <br/>
# <span class="home-news-source">– Variety</span>
# </li>
# <li>
# <a class="home-news-article-link" href="https://variety.com/2018/film/news/lebron-james-ryan-coogler-space-jam-1202948644/" rel="noopener" target="_blank">
# <i>Space Jam</i> Sequel Unites Ryan Coogler, LeBron James
#                                   </a>
# <br/>
# <span class="home-news-source">– Variety</span>
# </li>
# <li>
# <a class="home-news-article-link" href="https://editorial.rottentomatoes.com/article/five-big-things-we-learned-from-the-captain-marvel-trailer/?headline=1" rel="noopener" target="_blank">
#                                       Five Big Things We Learned from the <i>Captain Marvel</i> Trailer
#                                   </a>
# <br/>
# <span class="home-news-source">– Rotten Tomatoes</span>
# </li>
# <li>
# <a class="home-news-article-link" href="https://editorial.rottentomatoes.com/article/the-toronto-international-film-festival-just-shook-up-awards-season/?headline=1" rel="noopener" target="_blank">
#                                       The Toronto International Film Festival Just Shook Up Awards Season
#                                   </a>
# <br/>
# <span class="home-news-source">– Rotten Tomatoes</span>
# </li>
# </ul>
# </div>
# <br clear="all"/>
# <div class="clickForMore" id="home-top-headlines-view-all">
# <a class="articleLink unstyled" href="https://editorial.rottentomatoes.com/publications/">View All</a>
# </div>
# </div>
# </div>
# <div class="col-sm-17 newsList hidden-xs">
# <div class="col-sm-7 center"><!-- Glam medrec for overseas users. glamTarget is set globally in body.tag -->
# <aside class="medrec_ad " id="medrec_bottom_ad" style="width:300px"></aside>
# <script>
#                 var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function () {
#                     if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                         mps.insertAd('#medrec_bottom_ad','boxadone');
#                     } else if (mps.getResponsiveSet() == '0' && 'home' == 'home') {
#                         mps.insertAd('#medrec_bottom_ad','mboxadtwo');
#                     }
#                 });
#             </script>
# </div>
# </div>
# </div>
# </section>
# </section>
# </div>
# <div class="sleaderboard_wrapper hidden-xs">
# <div id="leaderboard_bottom_ad" style="margin-left:auto;margin-right:auto;display:inline-block"> </div>
# <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             if (mps.getResponsiveSet() != '0') { //DESKTOP or TABLET
#                 mps.insertAd('#leaderboard_bottom_ad','bottombanner');
#             }
#         });
#     </script>
# </div>
# <!--
#     <c:set var="onloadJs">
#     if(!$("#[skin]_ad").is(":visible")){$("body").removeAttr("style");}
#     </c:set>
#      -->
# <style>#[skin]_ad { height:0px !important; }</style>
# <div id="[skin]_ad"></div>
# <footer class="footer hidden-xs" id="foot">
# <div class="row">
# <div class="col-xs-5 subnav">
# <ul class="unstyled">
# <li><a href="/help_desk/" id="footer-help">Help</a></li>
# <li><a href="/about/" id="footer-about">About Rotten Tomatoes</a></li>
# <li><a href="/about#whatisthetomatometer" id="footer-tomatometer" style="cursor: pointer;">What's the Tomatometer?</a></li>
# <li><a href="https://fandango.az1.qualtrics.com/SE/?SID=SV_cGSHgMIu5ivVwAB" id="footer-feedback" rel="noopener" target="_blank">Feedback</a></li>
# </ul>
# </div>
# <div class="col-xs-4 subnav">
# <ul>
# <li><a href="/help_desk/critics/" id="footer-critics">Critic Submission</a></li>
# <li><a href="/help_desk/licensing/" id="footer-licensing">Licensing</a></li>
# <li><a href="//www.fandango.com/Advertising.aspx" id="footer-advertise">Advertise</a></li>
# <li><a href="//www.fandango.com/careers" id="footer-jobs">Careers</a></li>
# </ul>
# </div>
# <div class="col-xs-7 subnav center">
# <h2><span class="glyphicon glyphicon-envelope envelope"></span>JOIN THE NEWSLETTER</h2>
# <div class="default-half-margin-vertical" id="footer-center-text">
#               Get the freshest reviews, news, and more delivered right to your inbox!
#           </div>
# <div class="default-margin">
# <a class="btn btn-primary" href="/newsletter">Join the Newsletter!</a>
# </div>
# </div>
# <div class="col-xs-8 subnav">
# <h2>Follow Us</h2>
# <div>
# <a class="fontelloIcon icon-facebook-squared footerIcon footer-space" href="//www.facebook.com/rottentomatoes" id="footer-follow-us-facebook"></a>
# <a class="fontelloIcon icon-twitter footerIcon footer-space" href="//twitter.com/rottentomatoes" id="footer-follow-us-twitter"></a>
# <a class="fontelloIcon icon-instagram footerIcon footer-space" href="//www.instagram.com/rottentomatoes/" id="footer-follow-us-instagram"></a>
# <a class="fontelloIcon icon-snapchat footerIcon footer-space" href="https://www.snapchat.com/add/rottentomatoes" id="footer-follow-us-snapchat"></a>
# <a class="fontelloIcon icon-youtube-play footerIcon" href="//www.youtube.com/user/rottentomatoes" id="footer-follow-us-youtube"></a>
# </div>
# </div>
# </div>
# <div class="subtle" style="padding:10px">
#         Copyright © Fandango. All rights reserved. <span class="version">V3</span>
# <a href="//www.fandango.com/PrivacyPolicy" id="footer-privacy">Privacy Policy</a> |
#         <a href="//www.fandango.com/terms-and-policies" id="footer-tos">Terms and Policies</a> |
#         <a href="//www.aboutads.info/choices" id="footer-ad-choices"><span class="icon-adchoices"></span> Ad Choices</a>
# </div>
# </footer>
# <footer class="footer-mobile visible-xs-block">
# <div class="white">Copyright © Fandango. All rights reserved. <span class="version">V3</span></div>
# <div class="default-margin">
# <a class="btn btn-primary" href="/newsletter">Join Newsletter</a>
# </div>
# <div>
# <a class="footerLinks footer-space" href="//www.fandango.com/terms-and-policies">Terms and Policies</a>
# <a class="footerLinks footer-space" href="//www.fandango.com/PrivacyPolicy">Privacy Policy</a>
# <a class="footerLinks" href="https://fandango.az1.qualtrics.com/SE/?SID=SV_cGSHgMIu5ivVwAB" rel="noopener" target="_blank">Feedback</a>
# </div>
# </footer>
# <div id="fullscreen-search-root" style="display: none;">
# <form id="search-form" method="get">
# <div class="FullscreenSearch FullscreenSearch--mobile">
# <div>
# <div class="FullscreenSearch__top-section">
# <img alt="Rotten Tomatoes Logo" class="FullscreenSearch__top-rt-logo" role="presentation" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/>
# <button class="FullscreenSearch__close-btn" type="button">
# <svg preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 36px; height: 36px;" viewbox="0 0 24 24">
# <g>
# <path d="M19 6.41l-1.41-1.41-5.59 5.59-5.59-5.59-1.41 1.41 5.59 5.59-5.59 5.59 1.41 1.41 5.59-5.59 5.59 5.59 1.41-1.41-5.59-5.59z"></path>
# </g>
# </svg>
# </button>
# <div class="FullscreenSearch__top-section-container container">
# <div class="row">
# <div class="col-xs-24">
# <div class="FullscreenSearch__search-box">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" class="FullscreenSearch__input" id="mobile-search-term" name="search" placeholder="Search movies, TV…" spellcheck="false" value=""/>
# <a class="FullscreenSearch__clear-search-query-btn">
# <svg class="FullscreenSearch__clear-search-query-icon" preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 27px; height: 36px;" viewbox="0 0 24 24">
# <g>
# <path d="M12 2c-5.53 0-10 4.47-10 10s4.47 10 10 10 10-4.47 10-10-4.47-10-10-10zm5 13.59l-1.41 1.41-3.59-3.59-3.59 3.59-1.41-1.41 3.59-3.59-3.59-3.59 1.41-1.41 3.59 3.59 3.59-3.59 1.41 1.41-3.59 3.59 3.59 3.59z"></path>
# </g>
# </svg>
# </a>
# <a class="FullscreenSearch__search-btn">
# <svg class="FullscreenSearch__search-icon" preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 27px; height: 36px;" viewbox="0 0 24 24">
# <g>
# <path d="M15.5 14h-.79l-.28-.27c.98-1.14 1.57-2.62 1.57-4.23 0-3.59-2.91-6.5-6.5-6.5s-6.5 2.91-6.5 6.5 2.91 6.5 6.5 6.5c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99 1.49-1.49-4.99-5zm-6 0c-2.49 0-4.5-2.01-4.5-4.5s2.01-4.5 4.5-4.5 4.5 2.01 4.5 4.5-2.01 4.5-4.5 4.5z"></path>
# </g>
# </svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="FullscreenSearch__results-container container">
# <div class="row">
# <div class="col-xs-24">
# <div class="FullscreenSearch__results">
# <!-- Results added dynamically here -->
# </div>
# <a class="FullscreenSearch__results-view-all" href="something">
#                                 View All Results
#                                 <svg preserveaspectratio="xMidYMid meet" style="fill: currentcolor; vertical-align: middle; width: 24px; height: 24px;" viewbox="0 0 24 24">
# <g>
# <path d="M10 6l-1.41 1.41 4.58 4.59-4.58 4.59 1.41 1.41 6-6z"></path>
# </g>
# </svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </li></ul></div>
# <div class="modal fade" id="newTrailerModal" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
# <div id="videoPlayer" style="width:100%;height:100%"></div>
# </div>
# <div class="fullWidth">
# <div class="btn btn-primary-rt closeBtn">
# <span class="glyphicon glyphicon-chevron-left"></span> Go back
#         </div>
# <div class="moreTrailer">
# <a class="btn btn-primary-rt" href="/trailers/">More trailers <span class="glyphicon glyphicon-chevron-right"></span></a>
# </div>
# </div>
# </div>
# <div class="modal fade" id="newIframeTrailerModal" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
# <iframe id="iframeVideoPlayer" src="about:none" style="width:100%;height:100%"></iframe>
# </div>
# </div>
# <!-- <bootstrap:bodyScript /> -->
# <script type="text/javascript">
# (function (root) {
# /* -- Data -- */
# root.RottenTomatoes || (root.RottenTomatoes = {});
# root.RottenTomatoes.context = {"_routes":{"apiDiscoveryTheaters":{"path":"http:\u002F\u002Forigin-discovery-api-2103972120.us-east-1.elb.amazonaws.com\u002Ftheaters\u002Fv2","keys":[],"regexp":/^http:\/\/origin-discovery-api-2103972120\.us-east-1\.elb\.amazonaws\.com\/theaters\/v2\/?$/i,"pathTokens":[{"literal":"http:\u002F\u002Forigin-discovery-api-2103972120.us-east-1.elb.amazonaws.com\u002Ftheaters\u002Fv2"}]},"apiTvSeasonEpisodes":{"path":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fapi\u002Fprivate\u002Fv2.0\u002FtvSeason\u002F:id\u002Fepisodes","keys":[{"name":"id","optional":false,"offset":66}],"regexp":/^https:\/\/www\.rottentomatoes\.com\/api\/private\/v2\.0\/tvSeason\/(?:([^\/]+?))\/episodes\/?$/i,"pathTokens":[{"literal":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fapi\u002Fprivate\u002Fv2.0\u002FtvSeason\u002F"},{"key":"id"},{"literal":"\u002Fepisodes"}]},"baseCanonicalUrl":{"path":"https:\u002F\u002Fwww.rottentomatoes.com","keys":[],"regexp":/^https:\/\/www\.rottentomatoes\.com\/?$/i,"pathTokens":[{"literal":"https:\u002F\u002Fwww.rottentomatoes.com"}]},"flixsterGeoLocationApi":{"path":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip","keys":[],"regexp":/^https:\/\/api\.flixster\.com\/ticketing\/api\/v1\/geoip\/?$/i,"pathTokens":[{"literal":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip"}]},"napiAccountForgotPassword":{"path":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F","keys":[],"regexp":/^\/napi\/account\/forgotPassword\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F"}]},"napiAccountLogin":{"path":"\u002Fnapi\u002Faccount\u002Flogin\u002F","keys":[],"regexp":/^\/napi\/account\/login\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogin\u002F"}]},"napiAccountLoginFacebookOauth":{"path":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F","keys":[],"regexp":/^\/napi\/account\/loginFacebookOauth\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F"}]},"napiAccountLogout":{"path":"\u002Fnapi\u002Faccount\u002Flogout\u002F","keys":[],"regexp":/^\/napi\/account\/logout\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogout\u002F"}]},"napiAccountRegister":{"path":"\u002Fnapi\u002Faccount\u002Fregister\u002F","keys":[],"regexp":/^\/napi\/account\/register\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002Fregister\u002F"}]},"napiAccountVerifyToken":{"path":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F","keys":[],"regexp":/^\/napi\/account\/verifyToken\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F"}]},"napiMovieCalendar":{"path":"\u002Fnapi\u002FmovieCalendar\u002F:title-:id(\\d+)","keys":[{"name":"title","optional":false,"offset":22},{"name":"id","optional":false,"offset":38}],"regexp":/^\/napi\/movieCalendar\/(?:([^\/]+?))-(?:(\d+))\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002FmovieCalendar\u002F"},{"key":"title"},{"literal":"-"},{"key":"id"}]},"napiMovieListDvdAll":{"path":"\u002Fnapi\u002FmovieList\u002FdvdAll","keys":[],"regexp":/^\/napi\/movieList\/dvdAll\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002FmovieList\u002FdvdAll"}]},"napiMovieListDvdUpcoming":{"path":"\u002Fnapi\u002FmovieList\u002FdvdUpcoming","keys":[],"regexp":/^\/napi\/movieList\/dvdUpcoming\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002FmovieList\u002FdvdUpcoming"}]},"napiMovieListDvdCertified":{"path":"\u002Fnapi\u002FmovieList\u002FdvdCertified","keys":[],"regexp":/^\/napi\/movieList\/dvdCertified\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002FmovieList\u002FdvdCertified"}]},"napiMovieShowtimeGroupings":{"path":"\u002Fnapi\u002FtheaterShowtimeGroupings\u002F:id(\\d+)\u002F:startDate","keys":[{"name":"id","optional":false,"offset":33},{"name":"startDate","optional":false,"offset":44}],"regexp":/^\/napi\/theaterShowtimeGroupings\/(?:(\d+))\/(?:([^\/]+?))\/?$/i,"pathTokens":[{"literal":"\u002Fnapi\u002FtheaterShowtimeGroupings\u002F"} ...
# root.RottenTomatoes.context || (root.RottenTomatoes.context = {});
# root.RottenTomatoes.context.req = {"params":{},"queries":{},"route":{},"url":"\u002F","secure":false,"buildVersion":"1.0.1"};
# root.RottenTomatoes.thirdParty = {"chartBeat":{"auth":"64558","domain":"rottentomatoes.com"},"facebook":{"appId":"326803741017","version":"v2.9","appName":"flixstertomatoes"},"googleReCaptcha":"6Lcobh0TAAAAAN1K9rWeJ8xgl8uYkASWSDLBuKU1","mpx":{"accountPid":"dCK2IC","playerPid":"X36SYnM49ldh","accountId":"2474312077"}};
# root.RottenTomatoes.serviceWorker = {"isServiceWokerOn":true};
# root.RottenTomatoes.dtmData = {"webVersion":"node","pageName":"rt | homepage"};
# root.RottenTomatoes.context.akamaiEdgescape = {"zip":"10451-10475+10499","zipFallback":["10475","10499"],"city":"BRONX","state":"NY","county":"BRONX","areacode":"718","lat":"40.8208","long":"-73.9235","countryCode":"US"};
# root.RottenTomatoes.context.gptSite = "home";
# root.RottenTomatoes.serviceWorker || (root.RottenTomatoes.serviceWorker = {});
# root.RottenTomatoes.serviceWorker.preCachingPageUrls = ["\u002Fm\u002Fnight_school_2018","\u002Fm\u002Fsmallfoot","\u002Fm\u002Fhell_fest","\u002Fm\u002Fthe_old_man_and_the_gun","\u002Fm\u002Fblack_47"];
# }(this));
# </script>
# <script async="" defer="" src="//maps.googleapis.com/maps/api/js?key=AIzaSyDPjsVhzeFsT0QhCw_gwy2PyXyfLo-ejds&amp;libraries=places"></script>
# <script async="" defer="" src="//www.google.com/recaptcha/api.js?onload=onRecaptchaCallback&amp;render=explicit"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/vendor.41e3207a5bb.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/client-side-templates.215cf1a8cfb.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/global.32450d9af31.js"></script>
# <script src="/assets/pizza-pie/javascripts/bundles/home.3b059ae6272.js"></script>
# <script>
#             if ('function' === typeof window.mps.writeFooter) window.mps.writeFooter()
#             </script>
# <script type="text/javascript">window._satellite && _satellite.pageBottom();</script>
# </div></nav></div></body>
# </html>
# >

# %% [markdown]
# <a id='#bs4_parse'></a>
#
# #### Beautiful Soup Parsing Methods
#
# The beauty of Beautiful Soup (pun intended) is in the robust, flexible parsing methods. Some of the ones that I have found the most useful are the following (which we will use to parse this webpage):
#
# * **find_all( )** : the 'find_all()' method is one of the most popular and userful methods of Beautiful Soup. We can pass tags to this method and it will search **DOWN** the tree to return all HTML tags of this type that it finds on the page. <br>
# * **find( )** : the 'find()' method is like the 'find_all()' method, except that it returns only the first occurence of the tag that is passed in as a parameter by searching **DOWN** the tree
#
# (Both **find( )** and **find_all( )** search the descendants of the tree, and most other methods of Beautiful Soup are derivations of these two. We'll touch on a couple others)
#
# * **find_parents( )** : the 'find_parents()' method searches **UP** the tree to find all matching HTML tags, as opposed to **find_all( )** which searches down the tree. <br>
# * **find_parent( )** : the 'find_parent( )' method is like the 'find( )' method, except that it returns only the first occurence of the tag that is found looking **UP** the HTML tree
#
# * **find_next_siblings( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find all matching HTML tags that are siblings in the tree <br>
# * **find_next_sibling( )** : the 'find_next_sibling( )' method searches **DOWN** the tree to find the next matching HTML tags that are siblings in the tree <br>
#
# To see a full list of the methods available for parsing HTML trees in Beatiful Soup, visit the documentation page at
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find

# %%
#As we examine our HTML doc, we see that all the information we need are nested in 'div' tags that have 'homepage' 
#as an element of the 'id' tag. 

#To capture these tags, we pass a 'div' tag and also an 'id' tag as parameters to our 'find_all()' method. If we 
#have a value that we are looking to capture in our tags, we can pass it in as a 'dict' parameter. 
#In this instance we use Regular Expressions to capture all the 'id' tags that have the word 'homepage' in the string.

categories = soup.find_all('div', {'id': re.compile('homepage')})

# %%
#Let's now examine the 'categories' object to see what has been stored there
print("Let's look at the length of the 'categories object")
print('Length: ', len(categories), '\n')
print("Now let's examine the first object to see what we need to pull")
print(categories[0])
# Out:
# Let's look at the length of the 'categories object
# Length:  7
#
# Now let's examine the first object to see what we need to pull
# <div class="listings" id="homepage-opening-this-week">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Movies Opening This Week</h2>
# <table class="movie_list" id="Opening">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/night_school_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/night_school_2018">Night School</a>
# </td>
# <td class="right_col right">
# <a href="/m/night_school_2018">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/smallfoot">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/smallfoot">Smallfoot</a>
# </td>
# <td class="right_col right">
# <a href="/m/smallfoot">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hell_fest">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hell_fest">Hell Fest</a>
# </td>
# <td class="right_col right">
# <a href="/m/hell_fest">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_old_man_and_the_gun">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_old_man_and_the_gun">The Old Man &amp; the Gun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_old_man_and_the_gun">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/black_47">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">68%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/black_47">Black '47</a>
# </td>
# <td class="right_col right">
# <a href="/m/black_47">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/opening/" id="Opening-view-all">View All</a> </div>
# </div>

# %% [markdown]
# <a id='#bs4_html'></a>
#
# #### Creating the right HTML objects to parse
#
# We see that the objects we need to pull have an **'h2'** tag which storest the category name on the rottentomatoes website. The first 6 category objects have this **'h2'** tag, while the last 2 do not (we can discard these last two objects).
#
# We can use the **soup_html_object.text** method to extract the text associated with our tags

# %%
#For each object in the 'categories' object, display it and print out the the movie category title.

for category in categories:
    print(category.find('h2').text,'\n')
    print(category)
    print("-----------------Next Category Starts----------------- \n\n")
# Out:
# Movies Opening This Week
#
# <div class="listings" id="homepage-opening-this-week">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Movies Opening This Week</h2>
# <table class="movie_list" id="Opening">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/night_school_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/night_school_2018">Night School</a>
# </td>
# <td class="right_col right">
# <a href="/m/night_school_2018">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/smallfoot">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/smallfoot">Smallfoot</a>
# </td>
# <td class="right_col right">
# <a href="/m/smallfoot">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hell_fest">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hell_fest">Hell Fest</a>
# </td>
# <td class="right_col right">
# <a href="/m/hell_fest">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_old_man_and_the_gun">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_old_man_and_the_gun">The Old Man &amp; the Gun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_old_man_and_the_gun">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/black_47">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">68%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/black_47">Black '47</a>
# </td>
# <td class="right_col right">
# <a href="/m/black_47">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/opening/" id="Opening-view-all">View All</a> </div>
# </div>
# -----------------Next Category Starts-----------------
#
#
# Top Box Office
#
# <div class="listings" id="homepage-top-box-office">
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
# <h2>Top Box Office</h2>
# <table class="movie_list" id="Top-Box-Office">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">The House with a Clock in Its Walls</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_house_with_a_clock_in_its_walls">$26.7M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_simple_favor">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_simple_favor">A Simple Favor</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_simple_favor">$10.4M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_nun_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_nun_2018">The Nun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_nun_2018">$10.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_predator">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">34%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_predator">The Predator</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_predator">$9.3M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/crazy_rich_asians">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/crazy_rich_asians">Crazy Rich Asians</a>
# </td>
# <td class="right_col right">
# <a href="/m/crazy_rich_asians">$6.5M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/white_boy_rick">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/white_boy_rick">White Boy Rick</a>
# </td>
# <td class="right_col right">
# <a href="/m/white_boy_rick">$5M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/peppermint_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">11%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/peppermint_2018">Peppermint</a>
# </td>
# <td class="right_col right">
# <a href="/m/peppermint_2018">$3.8M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fahrenheit_119">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">77%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fahrenheit_119">Fahrenheit 11/9</a>
# </td>
# <td class="right_col right">
# <a href="/m/fahrenheit_119">$3.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_meg">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_meg">The Meg</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_meg">$2.4M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/searching_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/searching_2018">Searching</a>
# </td>
# <td class="right_col right">
# <a href="/m/searching_2018">$2.3M</a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/in-theaters/" id="Top-Box-Office-view-all">View All</a></div>
# </div>
# -----------------Next Category Starts-----------------
#
#
# Coming Soon to Theaters
#
# <div class="listings" id="homepage-top-coming-soon">
# <h2>Coming Soon to Theaters</h2>
# <table class="movie_list" id="Top-Coming-Soon">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/venom_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/venom_2018">Venom</a>
# </td>
# <td class="right_col right">
# <a href="/m/venom_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/shine_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/shine_2018">Shine</a>
# </td>
# <td class="right_col right">
# <a href="/m/shine_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_star_is_born_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">95%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_star_is_born_2018">A Star Is Born</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_star_is_born_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/loving_pablo">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">26%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/loving_pablo">Loving Pablo</a>
# </td>
# <td class="right_col right">
# <a href="/m/loving_pablo">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_hate_u_give">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_hate_u_give">The Hate U Give</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_hate_u_give">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/upcoming/" id="Top-Coming-Soon-view-all">View All</a> </div>
# </div>
# -----------------Next Category Starts-----------------
#
#
# Most Popular TV on RT
#
# <div id="homepage-tv-bottom">
# <h2>Most Popular TV on RT</h2>
# <table class="movie_list">
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/marvel_s_iron_fist/s02">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marvel_s_iron_fist/s02">
#
#                 Marvel's Iron Fist
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/bojack_horseman/s05">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/bojack_horseman/s05">
#
#                 BoJack Horseman
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/the_sinner/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_sinner/s02">
#
#                 The Sinner
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/American_Vandal/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">97%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/American_Vandal/s02">
#
#                 American Vandal
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/jack_ryan/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">73%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/jack_ryan/s01">
#
#                 Tom Clancy's Jack Ryan
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/american_horror_story/s08">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s08">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
# </table>
# <div class="clickForMore"><a class="unstyled articleLink tv-list-2-view-all" href="/browse/tv-list-2">View All</a></div>
# </div>
# -----------------Next Category Starts-----------------
#
#
# Top DVD & Streaming Movies
#
# <div id="homepage-top-dvd-streaming">
# <h2>Top DVD &amp; Streaming Movies</h2>
# <div id="dvd-affliate-links">
# <a href="/browse/dvd-streaming-all/?services=fandango_now" id="fandango-affililate-link">FandangoNOW</a> |
#                         <a href="/browse/dvd-streaming-all/?services=netflix_iw" id="netflix-affiliate-link">Netflix</a> |
#                         <a href="/browse/dvd-streaming-all/?services=itunes" id="itunes-affiliate-link">iTunes</a> |
#                         <a href="/browse/dvd-streaming-all/?services=amazon;amazon_prime" id="amazon-affiliate-link">Amazon</a> |
#                         <a href="/browse/dvd-streaming-all/" id="all-affiliates-link">More...</a>
# </div>
# <table class="movie_list" id="Top-DVD">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/gotti_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">0%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/gotti_2018">Gotti</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/skyscraper_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/skyscraper_2018">Skyscraper</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/leave_no_trace">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/leave_no_trace">Leave No Trace</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/eighth_grade">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">98%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/eighth_grade">Eighth Grade</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">Hotel Transylvania 3: Summer Vacation</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# </table>
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/top-dvd-streaming/" id="Top-DVD-view-all">View All</a> </div>
# </div>
# -----------------Next Category Starts-----------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-707278d4fcc7> in <module>()
#       2
#       3 for category in categories:
# ----> 4     print(category.find('h2').text,'\n')
#       5     print(category)
#       6     print("-----------------Next Category Starts----------------- \n\n")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# #### Examine Categories
#
# As we examine each object in each of the **categories** object, we see that the nested objects do not give us individual movies with the associated data. In order to grab this in a clear hierarchal fashion, we'll need to create the objects usign the **find( )** and **find_all( )** methodology.

# %%
for category in categories:
    print(category.find('h2').text,'\n')
    for movie in category:
        print(movie, '\n')
        print('----------NEXT MOVIE----------')
# Out:
# Movies Opening This Week
#
#
#
#
# ----------NEXT MOVIE----------
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <h2>Movies Opening This Week</h2>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <table class="movie_list" id="Opening">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/night_school_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/night_school_2018">Night School</a>
# </td>
# <td class="right_col right">
# <a href="/m/night_school_2018">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/smallfoot">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/smallfoot">Smallfoot</a>
# </td>
# <td class="right_col right">
# <a href="/m/smallfoot">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hell_fest">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hell_fest">Hell Fest</a>
# </td>
# <td class="right_col right">
# <a href="/m/hell_fest">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_old_man_and_the_gun">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_old_man_and_the_gun">The Old Man &amp; the Gun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_old_man_and_the_gun">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/black_47">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">68%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/black_47">Black '47</a>
# </td>
# <td class="right_col right">
# <a href="/m/black_47">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
# </table>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/opening/" id="Opening-view-all">View All</a> </div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# Top Box Office
#
#
#
#
# ----------NEXT MOVIE----------
# <a class="pull-right showtimesLink" href="/showtimes/">Get Tickets</a>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <h2>Top Box Office</h2>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <table class="movie_list" id="Top-Box-Office">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">The House with a Clock in Its Walls</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_house_with_a_clock_in_its_walls">$26.7M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_simple_favor">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_simple_favor">A Simple Favor</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_simple_favor">$10.4M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_nun_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_nun_2018">The Nun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_nun_2018">$10.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_predator">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">34%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_predator">The Predator</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_predator">$9.3M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/crazy_rich_asians">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/crazy_rich_asians">Crazy Rich Asians</a>
# </td>
# <td class="right_col right">
# <a href="/m/crazy_rich_asians">$6.5M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/white_boy_rick">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/white_boy_rick">White Boy Rick</a>
# </td>
# <td class="right_col right">
# <a href="/m/white_boy_rick">$5M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/peppermint_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">11%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/peppermint_2018">Peppermint</a>
# </td>
# <td class="right_col right">
# <a href="/m/peppermint_2018">$3.8M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fahrenheit_119">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">77%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fahrenheit_119">Fahrenheit 11/9</a>
# </td>
# <td class="right_col right">
# <a href="/m/fahrenheit_119">$3.1M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_meg">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_meg">The Meg</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_meg">$2.4M</a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/searching_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/searching_2018">Searching</a>
# </td>
# <td class="right_col right">
# <a href="/m/searching_2018">$2.3M</a>
# </td>
# </tr>
# </table>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/in-theaters/" id="Top-Box-Office-view-all">View All</a></div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# Coming Soon to Theaters
#
#
#
#
# ----------NEXT MOVIE----------
# <h2>Coming Soon to Theaters</h2>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <table class="movie_list" id="Top-Coming-Soon">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/venom_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/venom_2018">Venom</a>
# </td>
# <td class="right_col right">
# <a href="/m/venom_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/shine_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/shine_2018">Shine</a>
# </td>
# <td class="right_col right">
# <a href="/m/shine_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_star_is_born_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">95%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_star_is_born_2018">A Star Is Born</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_star_is_born_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/loving_pablo">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">26%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/loving_pablo">Loving Pablo</a>
# </td>
# <td class="right_col right">
# <a href="/m/loving_pablo">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_hate_u_give">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_hate_u_give">The Hate U Give</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_hate_u_give">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
# </table>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/upcoming/" id="Top-Coming-Soon-view-all">View All</a> </div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# Most Popular TV on RT
#
#
#
#
# ----------NEXT MOVIE----------
# <h2>Most Popular TV on RT</h2>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <table class="movie_list">
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/marvel_s_iron_fist/s02">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marvel_s_iron_fist/s02">
#
#                 Marvel's Iron Fist
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/bojack_horseman/s05">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/bojack_horseman/s05">
#
#                 BoJack Horseman
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/the_sinner/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_sinner/s02">
#
#                 The Sinner
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/American_Vandal/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">97%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/American_Vandal/s02">
#
#                 American Vandal
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/jack_ryan/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">73%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/jack_ryan/s01">
#
#                 Tom Clancy's Jack Ryan
#
#         </a>
# </td>
# </tr>
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/american_horror_story/s08">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s08">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
# </table>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div class="clickForMore"><a class="unstyled articleLink tv-list-2-view-all" href="/browse/tv-list-2">View All</a></div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# Top DVD & Streaming Movies
#
#
#
#
# ----------NEXT MOVIE----------
# <h2>Top DVD &amp; Streaming Movies</h2>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div id="dvd-affliate-links">
# <a href="/browse/dvd-streaming-all/?services=fandango_now" id="fandango-affililate-link">FandangoNOW</a> |
#                         <a href="/browse/dvd-streaming-all/?services=netflix_iw" id="netflix-affiliate-link">Netflix</a> |
#                         <a href="/browse/dvd-streaming-all/?services=itunes" id="itunes-affiliate-link">iTunes</a> |
#                         <a href="/browse/dvd-streaming-all/?services=amazon;amazon_prime" id="amazon-affiliate-link">Amazon</a> |
#                         <a href="/browse/dvd-streaming-all/" id="all-affiliates-link">More...</a>
# </div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <table class="movie_list" id="Top-DVD">
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/gotti_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">0%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/gotti_2018">Gotti</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/skyscraper_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/skyscraper_2018">Skyscraper</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/leave_no_trace">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/leave_no_trace">Leave No Trace</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/eighth_grade">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">98%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/eighth_grade">Eighth Grade</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">Hotel Transylvania 3: Summer Vacation</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
# </table>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# <div class="clickForMore"> <a class="unstyled articleLink" href="/browse/top-dvd-streaming/" id="Top-DVD-view-all">View All</a> </div>
#
# ----------NEXT MOVIE----------
#
#
#
# ----------NEXT MOVIE----------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-af8b3a513846> in <module>()
#       1 for category in categories:
# ----> 2     print(category.find('h2').text,'\n')
#       3     for movie in category:
#       4         print(movie, '\n')
#       5         print('----------NEXT MOVIE----------')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# <a id='#bs4_find_html'></a>
#
# #### Creating nested HTML objects using **find( ) and **find_all( ) methodology
#
# We see that by setting **movies** to **category.find_all('td')**, each nested object is a movie with all the necessary data for us to evaluate (title, rating, additional data).

# %%
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    print(category.find('h2').text)
    movies = category.find_all('tr')
    for movie in movies:
        print(movie, '\n')
        print("----------NEXT MOVIE----------")
# Out:
# Movies Opening This Week
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/night_school_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/night_school_2018">Night School</a>
# </td>
# <td class="right_col right">
# <a href="/m/night_school_2018">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/smallfoot">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">76%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/smallfoot">Smallfoot</a>
# </td>
# <td class="right_col right">
# <a href="/m/smallfoot">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hell_fest">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hell_fest">Hell Fest</a>
# </td>
# <td class="right_col right">
# <a href="/m/hell_fest">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_old_man_and_the_gun">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">92%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_old_man_and_the_gun">The Old Man &amp; the Gun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_old_man_and_the_gun">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/black_47">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">68%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/black_47">Black '47</a>
# </td>
# <td class="right_col right">
# <a href="/m/black_47">
#
#                     Sep 28
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Top Box Office
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">67%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_house_with_a_clock_in_its_walls">The House with a Clock in Its Walls</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_house_with_a_clock_in_its_walls">$26.7M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_simple_favor">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">84%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_simple_favor">A Simple Favor</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_simple_favor">$10.4M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_nun_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">27%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_nun_2018">The Nun</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_nun_2018">$10.1M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_predator">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">34%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_predator">The Predator</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_predator">$9.3M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/crazy_rich_asians">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/crazy_rich_asians">Crazy Rich Asians</a>
# </td>
# <td class="right_col right">
# <a href="/m/crazy_rich_asians">$6.5M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/white_boy_rick">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/white_boy_rick">White Boy Rick</a>
# </td>
# <td class="right_col right">
# <a href="/m/white_boy_rick">$5M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/peppermint_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">11%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/peppermint_2018">Peppermint</a>
# </td>
# <td class="right_col right">
# <a href="/m/peppermint_2018">$3.8M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/fahrenheit_119">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">77%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/fahrenheit_119">Fahrenheit 11/9</a>
# </td>
# <td class="right_col right">
# <a href="/m/fahrenheit_119">$3.1M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_meg">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_meg">The Meg</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_meg">$2.4M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/searching_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">93%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/searching_2018">Searching</a>
# </td>
# <td class="right_col right">
# <a href="/m/searching_2018">$2.3M</a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Coming Soon to Theaters
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/venom_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/venom_2018">Venom</a>
# </td>
# <td class="right_col right">
# <a href="/m/venom_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/shine_2018">
# <span class="tMeterIcon tiny noRating">No Score Yet</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/shine_2018">Shine</a>
# </td>
# <td class="right_col right">
# <a href="/m/shine_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/a_star_is_born_2018">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">95%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/a_star_is_born_2018">A Star Is Born</a>
# </td>
# <td class="right_col right">
# <a href="/m/a_star_is_born_2018">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/loving_pablo">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">26%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/loving_pablo">Loving Pablo</a>
# </td>
# <td class="right_col right">
# <a href="/m/loving_pablo">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/the_hate_u_give">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/the_hate_u_give">The Hate U Give</a>
# </td>
# <td class="right_col right">
# <a href="/m/the_hate_u_give">
#
#                     Oct 5
#
#             </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Most Popular TV on RT
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/marvel_s_iron_fist/s02">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">53%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/marvel_s_iron_fist/s02">
#
#                 Marvel's Iron Fist
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/bojack_horseman/s05">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/bojack_horseman/s05">
#
#                 BoJack Horseman
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/the_sinner/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">96%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/the_sinner/s02">
#
#                 The Sinner
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/American_Vandal/s02">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">97%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/American_Vandal/s02">
#
#                 American Vandal
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/jack_ryan/s01">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">73%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/jack_ryan/s01">
#
#                 Tom Clancy's Jack Ryan
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="tv_show_tr tvLists.mostPopularTvOnRt">
# <td class="left_col">
# <a href="/tv/american_horror_story/s08">
# <span class="icon tiny fresh"></span>
# <span class="tMeterScore">88%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/tv/american_horror_story/s08">
#
#                 American Horror Story
#
#         </a>
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# Top DVD & Streaming Movies
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/gotti_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">0%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/gotti_2018">Gotti</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/skyscraper_2018">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">46%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/skyscraper_2018">Skyscraper</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/leave_no_trace">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">100%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/leave_no_trace">Leave No Trace</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/eighth_grade">
# <span class="icon tiny certified_fresh"></span>
# <span class="tMeterScore">98%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/eighth_grade">Eighth Grade</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------
# <tr class="sidebarInTheaterOpening">
# <td class="left_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">
# <span class="icon tiny rotten"></span>
# <span class="tMeterScore">59%</span>
# </a>
# </td>
# <td class="middle_col">
# <a href="/m/hotel_transylvania_3_summer_vacation">Hotel Transylvania 3: Summer Vacation</a>
# </td>
# <td class="right_col right">
# </td>
# </tr>
#
# ----------NEXT MOVIE----------

# %% [markdown]
# <a id='#pulling_tags'></a>
#
# #### Pulling the Relevant Tags
#
# Now that we have created the right HTML objects, we can go in and use the **find( )** method to extract the relevant data. We'll leverage the **try/except** functionality in Python so that we can collect the necessary data while not throwing an exception that will break our script should the object not exist.
#
# We can find the data by parsing the appropriate **td** tags tags:
#
# **Movie Title:**
#
# `<td class="middle_col">` <br>
# `<a href="https://www.rottentomatoes.com/tv/the_americans/s06">The Americans</a>` <br>
# `</td>` <br>
#
# **Movie Score:**
#
# `<td class="left_col">` <br>
# `<a href="https://www.rottentomatoes.com/tv/the_americans/s06">` <br>
# `<span class="icon tiny certified_fresh"></span>` <br>
# `<span class="tMeterScore">98%</span>` <br>
# `</a>` <br>
# `</td>` <br>
#
# **Additional Data:**
#
# `<td class="right_col right">` <br>
# `<a href="/m/tyler_perrys_acrimony">` <br>
# `                    $17.2M</a>` <br>
# `</td>` <br>
#
# #### All of these are pieces of this **movie** HTML object:
#
# **Entire Movie Object**
#
# Top Box Office <br>
# `<tr class="sidebarInTheaterOpening">` <br>
# `<td class="left_col">` <br>
# `<a href="/m/ready_player_one">` <br>
# `<span class="icon tiny certified_fresh"></span>` <br>
# `<span class="tMeterScore">74%</span>` <br>
# `</a>` <br>
# `</td>` <br>
# `<td class="middle_col">` <br>
# `<a href="/m/ready_player_one">Ready Player One</a>` <br>
# `</td>` <br>
# `<td class="right_col right">` <br>
# `<a href="/m/ready_player_one">` <br>
# `                    $41.9M</a>` <br>
# `</td>` <br>
# `</tr>` <br>

# %%
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    print(category.find('h2').text)
    movies = category.find_all('tr')
    for movie in movies:
        #We can specify the 'td' tag with 'class' value = 'middle_col' and pull the '.text' attribute
        print(movie.find('td', {'class': 'middle_col'}).text)
        try:
            #To pull the movie score, we need to treat the returned object as an atrribute and then call the 
            #'find_all()' method on that onject once again, while extracting the text of the second element.
            print(movie.find('td', {'class': 'left_col'}).find_all('span')[1].text)
        except:
            print("No Score Yet")
        try:
            #Here we specify the 'td' tag with 'class' value = 'right_col right' and pull the '.text' attribute
            print(movie.find('td', {'class': 'right_col right'}).text)
        except:
            pass
# Out:
# Movies Opening This Week
#
# Night School
#
# No Score Yet
#
#
#
#                     Sep 28
#
#
#
#
# Smallfoot
#
# 76%
#
#
#
#                     Sep 28
#
#
#
#
# Hell Fest
#
# No Score Yet
#
#
#
#                     Sep 28
#
#
#
#
# The Old Man & the Gun
#
# 92%
#
#
#
#                     Sep 28
#
#
#
#
# Black '47
#
# 68%
#
#
#
#                     Sep 28
#
#
#
# Top Box Office
#
# The House with a Clock in Its Walls
#
# 67%
#
# $26.7M
#
#
# A Simple Favor
#
# 84%
#
# $10.4M
#
#
# The Nun
#
# 27%
#
# $10.1M
#
#
# The Predator
#
# 34%
#
# $9.3M
#
#
# Crazy Rich Asians
#
# 93%
#
# $6.5M
#
#
# White Boy Rick
#
# 59%
#
# $5M
#
#
# Peppermint
#
# 11%
#
# $3.8M
#
#
# Fahrenheit 11/9
#
# 77%
#
# $3.1M
#
#
# The Meg
#
# 46%
#
# $2.4M
#
#
# Searching
#
# 93%
#
# $2.3M
#
# Coming Soon to Theaters
#
# Venom
#
# No Score Yet
#
#
#
#                     Oct 5
#
#
#
#
# Shine
#
# No Score Yet
#
#
#
#                     Oct 5
#
#
#
#
# A Star Is Born
#
# 95%
#
#
#
#                     Oct 5
#
#
#
#
# Loving Pablo
#
# 26%
#
#
#
#                     Oct 5
#
#
#
#
# The Hate U Give
#
# 100%
#
#
#
#                     Oct 5
#
#
#
# Most Popular TV on RT
#
#
#
#                 Marvel's Iron Fist
#
#
#
# 53%
#
#
#
#                 BoJack Horseman
#
#
#
# 100%
#
#
#
#                 The Sinner
#
#
#
# 96%
#
#
#
#                 American Vandal
#
#
#
# 97%
#
#
#
#                 Tom Clancy's Jack Ryan
#
#
#
# 73%
#
#
#
#                 American Horror Story
#
#
#
# 88%
# Top DVD & Streaming Movies
#
# Gotti
#
# 0%
#
#
#
# Skyscraper
#
# 46%
#
#
#
# Leave No Trace
#
# 100%
#
#
#
# Eighth Grade
#
# 98%
#
#
#
# Hotel Transylvania 3: Summer Vacation
#
# 59%

# %% [markdown]
# <a id='#storing_data'></a>
#
# #### Storing Data and Exporting to CSV
#
# Now that we know we have the relevant data, we can store our data in a **dict** object and export that data to a **CSV** file via our **Pandas** dataframe.

# %%
movie_data = {}
#category represensts what it sounds - each category on the rottentomatoes website
for category in categories[:-2]:
    cat = category.find('h2').text
    movies = category.find_all('tr')
    for movie in movies:
        title = movie.find('td', {'class': 'middle_col'}).text
        try:
            score = movie.find('td', {'class': 'left_col'}).find_all('span')[1].text
        except:
            score = "No Score Yet"
        try:
            addtl_data = movie.find('td', {'class': 'right_col right'}).text
        except:
            pass
        movie_data[title.strip()] = {'Category': cat, 'Score': score, 'Addititional_Data': addtl_data.strip()}
movie_data
# Out:
# {'A Simple Favor': {'Addititional_Data': '$10.4M',
#   'Category': 'Top Box Office',
#   'Score': '84%'},
#  'A Star Is Born': {'Addititional_Data': 'Oct 5',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '95%'},
#  'American Horror Story': {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '88%'},
#  'American Vandal': {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '97%'},
#  "Black '47": {'Addititional_Data': 'Sep 28',
#   'Category': 'Movies Opening This Week',
#   'Score': '68%'},
#  'BoJack Horseman': {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '100%'},
#  'Crazy Rich Asians': {'Addititional_Data': '$6.5M',
#   'Category': 'Top Box Office',
#   'Score': '93%'},
#  'Eighth Grade': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '98%'},
#  'Fahrenheit 11/9': {'Addititional_Data': '$3.1M',
#   'Category': 'Top Box Office',
#   'Score': '77%'},
#  'Gotti': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '0%'},
#  'Hell Fest': {'Addititional_Data': 'Sep 28',
#   'Category': 'Movies Opening This Week',
#   'Score': 'No Score Yet'},
#  'Hotel Transylvania 3: Summer Vacation': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '59%'},
#  'Leave No Trace': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '100%'},
#  'Loving Pablo': {'Addititional_Data': 'Oct 5',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '26%'},
#  "Marvel's Iron Fist": {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '53%'},
#  'Night School': {'Addititional_Data': 'Sep 28',
#   'Category': 'Movies Opening This Week',
#   'Score': 'No Score Yet'},
#  'Peppermint': {'Addititional_Data': '$3.8M',
#   'Category': 'Top Box Office',
#   'Score': '11%'},
#  'Searching': {'Addititional_Data': '$2.3M',
#   'Category': 'Top Box Office',
#   'Score': '93%'},
#  'Shine': {'Addititional_Data': 'Oct 5',
#   'Category': 'Coming Soon to Theaters',
#   'Score': 'No Score Yet'},
#  'Skyscraper': {'Addititional_Data': '',
#   'Category': 'Top DVD & Streaming Movies',
#   'Score': '46%'},
#  'Smallfoot': {'Addititional_Data': 'Sep 28',
#   'Category': 'Movies Opening This Week',
#   'Score': '76%'},
#  'The Hate U Give': {'Addititional_Data': 'Oct 5',
#   'Category': 'Coming Soon to Theaters',
#   'Score': '100%'},
#  'The House with a Clock in Its Walls': {'Addititional_Data': '$26.7M',
#   'Category': 'Top Box Office',
#   'Score': '67%'},
#  'The Meg': {'Addititional_Data': '$2.4M',
#   'Category': 'Top Box Office',
#   'Score': '46%'},
#  'The Nun': {'Addititional_Data': '$10.1M',
#   'Category': 'Top Box Office',
#   'Score': '27%'},
#  'The Old Man & the Gun': {'Addititional_Data': 'Sep 28',
#   'Category': 'Movies Opening This Week',
#   'Score': '92%'},
#  'The Predator': {'Addititional_Data': '$9.3M',
#   'Category': 'Top Box Office',
#   'Score': '34%'},
#  'The Sinner': {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '96%'},
#  "Tom Clancy's Jack Ryan": {'Addititional_Data': 'Oct 5',
#   'Category': 'Most Popular TV on RT',
#   'Score': '73%'},
#  'Venom': {'Addititional_Data': 'Oct 5',
#   'Category': 'Coming Soon to Theaters',
#   'Score': 'No Score Yet'},
#  'White Boy Rick': {'Addititional_Data': '$5M',
#   'Category': 'Top Box Office',
#   'Score': '59%'}}

# %%
#Store dict object in pandas dataframe
df = pd.DataFrame.from_dict(movie_data, orient = 'index')
#Export pandas dataframe to CSV
df.to_csv('rottentomatoes.csv')

# %% [markdown]
# #### Thank You!
#
# Thank you for working through this tutorial. Please feel free to respond with questions/comments, and let me know how this tutorial can be improved.
